# %%
import os
import re
import logging
import time
from pathlib import Path
from collections import defaultdict
import pandas as pd
import numpy as np
import torch
from torch import multiprocessing as mp
from tqdm import tqdm
import csv

# %%
# ========== CONFIGURATION ==========
BASE_DIR = Path(r"C:/Users/ayush/OneDrive/Desktop/Stories")
CLEANED_DIR = BASE_DIR / "cleaned_files"
TAGGED_DIR = BASE_DIR / "cleaned_files_tagged"
CSV_LOG = BASE_DIR / "tagging_report.csv"
DETAILED_CSV = BASE_DIR / "tag_details.csv"
LOG_FILE = BASE_DIR / "phase2_tagging.log"

# %%
TAGGED_DIR.mkdir(parents=True, exist_ok=True)

# ========== STRUCTURAL TAGS ==========
TAG_PATTERNS = {
    "#chapter_start": re.compile(r"^\s*(CHAPTER|BOOK|PART|SCENE)[\s:.]+[\w\d\s,'\"-]+", re.IGNORECASE),
    "#dialogue": re.compile(r"^\s*[\"'].*[\"']\s*$"),
    "#quote": re.compile(r"^[^a-zA-Z0-9]*[\w\s,'\"“”‘’\-–—]{5,100}[.?!…\"'”]$"),
    "#poem": re.compile(r"^(\s{2,}|\t+).{1,80}$"),
    "#story_within": re.compile(r"\b(Once upon a time|There was a|In a land|Long ago|Far away)\b", re.IGNORECASE)
}

# %%
import os
import re
import csv
import logging
import time
from pathlib import Path
from collections import defaultdict
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import threading

# ========== CONFIG ==========
BASE_DIR = Path(r"C:/Users/ayush/OneDrive/Desktop/Stories")
CLEANED_DIR = BASE_DIR / "cleaned_files"
TAGGED_DIR = BASE_DIR / "cleaned_files_tagged"
CSV_LOG = BASE_DIR / "tagging_report.csv"
DETAILED_CSV = BASE_DIR / "tag_details.csv"
LOG_FILE = BASE_DIR / "phase2_tagging.log"
TAGGED_DIR.mkdir(parents=True, exist_ok=True)

# Thread-safe locking mechanism
DETAILED_LOCK = threading.Lock()

# ========== TAGGING RULES ==========
TAG_PATTERNS = {
    "#chapter_start": re.compile(r"^\s*(CHAPTER|BOOK|PART|SCENE)[\s:.]+[\w\d\s,'\"-]+", re.IGNORECASE),
    "#dialogue": re.compile(r"^\s*[\"\'\u201c\u2018].*[\"\'\u201d\u2019]\s*$"),
    "#poem": re.compile(r"^(\s{2,}|\t+)(?=.{1,80}$).+", re.MULTILINE),
    "#story_within": re.compile(r"\b(Once upon a time|In a land|Long ago|Far away|A tale|There lived|A fable)\b", re.IGNORECASE)
}

# ========== LOGGING ==========
def setup_logging():
    logger = logging.getLogger("GodspeedLogger")
    logger.setLevel(logging.INFO)

    if logger.hasHandlers():
        logger.handlers.clear()

    file_handler = logging.FileHandler(LOG_FILE, mode='w', encoding='utf-8')
    file_handler.setFormatter(logging.Formatter('[%(asctime)s] %(message)s'))
    console_handler = logging.StreamHandler()
    console_handler.setFormatter(logging.Formatter('[%(asctime)s] %(message)s'))

    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    return logger

# ========== TAGGING FUNCTION ==========
def tag_file(file_path: Path) -> dict:
    fname = file_path.name
    tag_counts = defaultdict(int)
    detailed_records = []

    try:
        with file_path.open(encoding="utf-8-sig", errors="replace") as f:
            lines = f.readlines()

        tagged_lines = []
        for idx, line in enumerate(lines):
            stripped = line.strip()
            matched_tag = None

            if stripped:
                for tag, pattern in TAG_PATTERNS.items():
                    if pattern.search(stripped):
                        matched_tag = tag
                        tag_counts[tag] += 1
                        detailed_records.append((fname, idx + 1, tag, stripped[:100] + ("..." if len(stripped) > 100 else "")))
                        break

            if matched_tag:
                tagged_lines.append(matched_tag + "\n")
            tagged_lines.append(line)

        output_path = TAGGED_DIR / fname
        with output_path.open("w", encoding="utf-8-sig") as f:
            f.writelines(tagged_lines)

        if detailed_records:
            with DETAILED_LOCK:
                with open(DETAILED_CSV, "a", encoding="utf-8-sig", newline="") as f:
                    writer = csv.writer(f)
                    if f.tell() == 0:
                        writer.writerow(["File", "Line", "Tag", "Content"])
                    writer.writerows(detailed_records)

        total_lines = len(lines)
        stats = {"file": fname, "status": "success", "total_lines": total_lines}

        for tag in TAG_PATTERNS:
            count = tag_counts.get(tag, 0)
            stats[f"{tag}_count"] = count
            stats[f"{tag}_density"] = round(count / total_lines * 100, 4) if total_lines else 0

        return stats

    except Exception as e:
        return {
            "file": fname,
            "status": "error",
            "error": str(e),
            "total_lines": 0,
            **{f"{tag}_count": 0 for tag in TAG_PATTERNS},
            **{f"{tag}_density": 0.0 for tag in TAG_PATTERNS}
        }

# ========== MAIN DRIVER ==========
def main():
    logger = setup_logging()
    logger.info("\n🚀 GODSPEED TAGGING v7.0 — FINALIZED")

    CSV_LOG.unlink(missing_ok=True)
    DETAILED_CSV.unlink(missing_ok=True)

    try:
        files = list(CLEANED_DIR.glob("*.txt"))
        total_files = len(files)
        if total_files == 0:
            logger.error("❌ No files found in CLEANED_DIR")
            return
        logger.info(f"📦 Files Queued: {total_files}\n")
    except Exception as e:
        logger.error(f"❌ Directory scanning failed: {str(e)}")
        return

    start_time = time.perf_counter()
    processed_files, error_files = 0, 0
    results, tag_totals = [], defaultdict(int)

    with ThreadPoolExecutor(max_workers=min(12, os.cpu_count() * 4)) as executor:
        futures = {executor.submit(tag_file, f): f.name for f in files}

        with tqdm(total=total_files, desc="⚡ Tagging Progress", unit="file", dynamic_ncols=True) as pbar:
            for i, future in enumerate(as_completed(futures)):
                try:
                    result = future.result()
                    results.append(result)
                    if result["status"] == "success":
                        processed_files += 1
                        for tag in TAG_PATTERNS:
                            tag_totals[tag] += result.get(f"{tag}_count", 0)
                    else:
                        error_files += 1
                        logger.error(f"❌ {result['file']}: {result.get('error', 'Unknown error')}")
                except Exception as e:
                    error_files += 1
                    logger.error(f"❌ Crash in processing: {str(e)}")

                if (i + 1) % 100 == 0:
                    logger.info(f"\n📍 INTERMEDIATE STATUS @ {i+1} files:")
                    logger.info(f"  ✅ Processed: {processed_files} | ❌ Errors: {error_files}")
                    for tag, count in tag_totals.items():
                        logger.info(f"  {tag}: {count} total occurrences")

                pbar.update(1)

    try:
        if results:
            pd.DataFrame(results).to_csv(CSV_LOG, index=False, encoding='utf-8-sig')
    except Exception as e:
        logger.error(f"❌ Failed to write CSV report: {str(e)}")

    duration = time.perf_counter() - start_time
    logger.info(f"\n{'✅' if error_files == 0 else '⚠️'} PROCESSING COMPLETE")
    logger.info(f"⏱️  Duration: {duration:.2f}s | ⚡ Speed: {total_files/max(duration, 0.001):.2f} files/s")
    logger.info(f"📊 Processed: {processed_files} | Errors: {error_files}")
    logger.info(f"📈 Tag Summary: {CSV_LOG}")
    logger.info(f"📝 Tag Details: {DETAILED_CSV}")

    logger.info("\n🏷️ FINAL TAG DISTRIBUTION:")
    for tag, count in tag_totals.items():
        logger.info(f"  {tag}: {count} tags")

if __name__ == "__main__":
    main()
# Out:
# [2025-07-29 22:27:40,903]
# 🚀 GODSPEED TAGGING v7.0 — FINALIZED
# [2025-07-29 22:27:41,029] 📦 Files Queued: 9492
#
# ⚡ Tagging Progress:   1%|          | 98/9492 [00:08<17:08,  9.13file/s] [2025-07-29 22:27:51,900]
# 📍 INTERMEDIATE STATUS @ 100 files:
# [2025-07-29 22:27:51,973]   ✅ Processed: 100 | ❌ Errors: 0
# [2025-07-29 22:27:52,115]   #chapter_start: 1805 total occurrences
# [2025-07-29 22:27:52,205]   #dialogue: 6641 total occurrences
# [2025-07-29 22:27:52,391]   #poem: 0 total occurrences
# [2025-07-29 22:27:52,447]   #story_within: 695 total occurrences
# ⚡ Tagging Progress:   2%|▏         | 199/9492 [00:20<10:37, 14.58file/s][2025-07-29 22:28:03,641]
# 📍 INTERMEDIATE STATUS @ 200 files:
# [2025-07-29 22:28:03,710]   ✅ Processed: 200 | ❌ Errors: 0
# [2025-07-29 22:28:03,754]   #chapter_start: 3946 total occurrences
# [2025-07-29 22:28:03,780]   #dialogue: 14281 total occurrences
# [2025-07-29 22:28:03,843]   #poem: 0 total occurrences
# [2025-07-29 22:28:03,941]   #story_within: 1236 total occurrences
# ⚡ Tagging Progress:   3%|▎         | 299/9492 [00:30<12:03, 12.71file/s][2025-07-29 22:28:13,227]
# 📍 INTERMEDIATE STATUS @ 300 files:
# [2025-07-29 22:28:13,531]   ✅ Processed: 300 | ❌ Errors: 0
# [2025-07-29 22:28:14,011]   #chapter_start: 5080 total occurrences
# [2025-07-29 22:28:14,076]   #dialogue: 22489 total occurrences
# [2025-07-29 22:28:14,118]   #poem: 0 total occurrences
# [2025-07-29 22:28:14,154]   #story_within: 1716 total occurrences
# ⚡ Tagging Progress:   4%|▍         | 399/9492 [00:42<18:36,  8.14file/s][2025-07-29 22:28:24,877]
# 📍 INTERMEDIATE STATUS @ 400 files:
# [2025-07-29 22:28:24,913]   ✅ Processed: 400 | ❌ Errors: 0
# [2025-07-29 22:28:24,951]   #chapter_start: 6463 total occurrences
# [2025-07-29 22:28:24,998]   #dialogue: 32281 total occurrences
# [2025-07-29 22:28:25,023]   #poem: 0 total occurrences
# [2025-07-29 22:28:25,037]   #story_within: 2186 total occurrences
# ⚡ Tagging Progress:   5%|▌         | 497/9492 [00:50<06:59, 21.46file/s][2025-07-29 22:28:33,655]
# 📍 INTERMEDIATE STATUS @ 500 files:
# [2025-07-29 22:28:33,710]   ✅ Processed: 500 | ❌ Errors: 0
# [2025-07-29 22:28:33,722]   #chapter_start: 8605 total occurrences
# [2025-07-29 22:28:33,731]   #dialogue: 36671 total occurrences
# [2025-07-29 22:28:33,738]   #poem: 0 total occurrences
# [2025-07-29 22:28:33,764]   #story_within: 2598 total occurrences
# ⚡ Tagging Progress:   6%|▋         | 598/9492 [00:57<09:25, 15.72file/s][2025-07-29 22:28:40,475]
# 📍 INTERMEDIATE STATUS @ 600 files:
# [2025-07-29 22:28:40,523]   ✅ Processed: 600 | ❌ Errors: 0
# [2025-07-29 22:28:40,550]   #chapter_start: 10516 total occurrences
# [2025-07-29 22:28:40,579]   #dialogue: 45397 total occurrences
# [2025-07-29 22:28:40,599]   #poem: 0 total occurrences
# [2025-07-29 22:28:40,638]   #story_within: 2913 total occurrences
# ⚡ Tagging Progress:   7%|▋         | 699/9492 [01:06<11:46, 12.45file/s][2025-07-29 22:28:49,156]
# 📍 INTERMEDIATE STATUS @ 700 files:
# [2025-07-29 22:28:49,252]   ✅ Processed: 700 | ❌ Errors: 0
# [2025-07-29 22:28:49,305]   #chapter_start: 11784 total occurrences
# [2025-07-29 22:28:49,400]   #dialogue: 53410 total occurrences
# [2025-07-29 22:28:49,405]   #poem: 0 total occurrences
# [2025-07-29 22:28:49,499]   #story_within: 3470 total occurrences
# ⚡ Tagging Progress:   8%|▊         | 798/9492 [01:11<07:26, 19.45file/s][2025-07-29 22:28:54,625]
# 📍 INTERMEDIATE STATUS @ 800 files:
# [2025-07-29 22:28:54,703]   ✅ Processed: 800 | ❌ Errors: 0
# [2025-07-29 22:28:54,752]   #chapter_start: 13554 total occurrences
# [2025-07-29 22:28:54,795]   #dialogue: 60815 total occurrences
# [2025-07-29 22:28:54,823]   #poem: 0 total occurrences
# [2025-07-29 22:28:54,921]   #story_within: 3886 total occurrences
# ⚡ Tagging Progress:   9%|▉         | 898/9492 [01:19<08:14, 17.38file/s][2025-07-29 22:29:02,067]
# 📍 INTERMEDIATE STATUS @ 900 files:
# [2025-07-29 22:29:02,202]   ✅ Processed: 900 | ❌ Errors: 0
# [2025-07-29 22:29:02,324]   #chapter_start: 14995 total occurrences
# [2025-07-29 22:29:02,355]   #dialogue: 68455 total occurrences
# [2025-07-29 22:29:02,393]   #poem: 0 total occurrences
# [2025-07-29 22:29:02,472]   #story_within: 4315 total occurrences
# ⚡ Tagging Progress:  11%|█         | 997/9492 [01:26<07:19, 19.34file/s][2025-07-29 22:29:09,203]
# 📍 INTERMEDIATE STATUS @ 1000 files:
# [2025-07-29 22:29:09,224]   ✅ Processed: 1000 | ❌ Errors: 0
# [2025-07-29 22:29:09,381]   #chapter_start: 16588 total occurrences
# [2025-07-29 22:29:09,611]   #dialogue: 72691 total occurrences
# [2025-07-29 22:29:09,822]   #poem: 0 total occurrences
# [2025-07-29 22:29:10,002]   #story_within: 4562 total occurrences
# ⚡ Tagging Progress:  12%|█▏        | 1098/9492 [01:33<11:14, 12.44file/s][2025-07-29 22:29:16,342]
# 📍 INTERMEDIATE STATUS @ 1100 files:
# [2025-07-29 22:29:16,379]   ✅ Processed: 1100 | ❌ Errors: 0
# [2025-07-29 22:29:16,406]   #chapter_start: 18261 total occurrences
# [2025-07-29 22:29:16,417]   #dialogue: 79284 total occurrences
# [2025-07-29 22:29:16,432]   #poem: 0 total occurrences
# [2025-07-29 22:29:16,445]   #story_within: 4925 total occurrences
# ⚡ Tagging Progress:  13%|█▎        | 1197/9492 [01:40<13:26, 10.28file/s][2025-07-29 22:29:23,267]
# 📍 INTERMEDIATE STATUS @ 1200 files:
# [2025-07-29 22:29:23,288]   ✅ Processed: 1200 | ❌ Errors: 0
# [2025-07-29 22:29:23,315]   #chapter_start: 19449 total occurrences
# [2025-07-29 22:29:23,359]   #dialogue: 85963 total occurrences
# [2025-07-29 22:29:23,419]   #poem: 0 total occurrences
# [2025-07-29 22:29:23,441]   #story_within: 5372 total occurrences
# ⚡ Tagging Progress:  14%|█▎        | 1299/9492 [01:47<09:07, 14.96file/s][2025-07-29 22:29:30,211]
# 📍 INTERMEDIATE STATUS @ 1300 files:
# [2025-07-29 22:29:30,214]   ✅ Processed: 1300 | ❌ Errors: 0
# [2025-07-29 22:29:30,218]   #chapter_start: 20673 total occurrences
# [2025-07-29 22:29:30,266]   #dialogue: 95794 total occurrences
# [2025-07-29 22:29:30,298]   #poem: 0 total occurrences
# [2025-07-29 22:29:30,418]   #story_within: 5842 total occurrences
# ⚡ Tagging Progress:  15%|█▍        | 1399/9492 [01:57<09:58, 13.52file/s][2025-07-29 22:29:39,934]
# 📍 INTERMEDIATE STATUS @ 1400 files:
# [2025-07-29 22:29:40,005]   ✅ Processed: 1400 | ❌ Errors: 0
# [2025-07-29 22:29:40,084]   #chapter_start: 22722 total occurrences
# [2025-07-29 22:29:40,113]   #dialogue: 106038 total occurrences
# [2025-07-29 22:29:40,187]   #poem: 0 total occurrences
# [2025-07-29 22:29:40,336]   #story_within: 6270 total occurrences
# ⚡ Tagging Progress:  16%|█▌        | 1496/9492 [02:05<09:20, 14.27file/s][2025-07-29 22:29:48,600]
# 📍 INTERMEDIATE STATUS @ 1500 files:
# [2025-07-29 22:29:48,708]   ✅ Processed: 1500 | ❌ Errors: 0
# [2025-07-29 22:29:48,781]   #chapter_start: 24427 total occurrences
# [2025-07-29 22:29:48,830]   #dialogue: 112189 total occurrences
# [2025-07-29 22:29:48,869]   #poem: 0 total occurrences
# [2025-07-29 22:29:48,897]   #story_within: 6820 total occurrences
# ⚡ Tagging Progress:  17%|█▋        | 1599/9492 [02:13<05:27, 24.11file/s][2025-07-29 22:29:55,799]
# 📍 INTERMEDIATE STATUS @ 1600 files:
# [2025-07-29 22:29:55,974]   ✅ Processed: 1600 | ❌ Errors: 0
# [2025-07-29 22:29:56,038]   #chapter_start: 25835 total occurrences
# [2025-07-29 22:29:56,115]   #dialogue: 119752 total occurrences
# [2025-07-29 22:29:56,122]   #poem: 0 total occurrences
# [2025-07-29 22:29:56,194]   #story_within: 7392 total occurrences
# ⚡ Tagging Progress:  18%|█▊        | 1698/9492 [02:22<08:01, 16.19file/s][2025-07-29 22:30:05,392]
# 📍 INTERMEDIATE STATUS @ 1700 files:
# [2025-07-29 22:30:05,448]   ✅ Processed: 1700 | ❌ Errors: 0
# [2025-07-29 22:30:05,583]   #chapter_start: 27157 total occurrences
# [2025-07-29 22:30:05,601]   #dialogue: 123506 total occurrences
# [2025-07-29 22:30:05,627]   #poem: 0 total occurrences
# [2025-07-29 22:30:05,663]   #story_within: 7758 total occurrences
# ⚡ Tagging Progress:  19%|█▉        | 1796/9492 [02:30<07:57, 16.11file/s][2025-07-29 22:30:12,892]
# 📍 INTERMEDIATE STATUS @ 1800 files:
# [2025-07-29 22:30:13,032]   ✅ Processed: 1800 | ❌ Errors: 0
# [2025-07-29 22:30:13,134]   #chapter_start: 28470 total occurrences
# [2025-07-29 22:30:13,231]   #dialogue: 132680 total occurrences
# [2025-07-29 22:30:13,319]   #poem: 0 total occurrences
# [2025-07-29 22:30:13,384]   #story_within: 8186 total occurrences
# ⚡ Tagging Progress:  20%|██        | 1899/9492 [02:38<08:05, 15.63file/s][2025-07-29 22:30:21,543]
# 📍 INTERMEDIATE STATUS @ 1900 files:
# [2025-07-29 22:30:21,591]   ✅ Processed: 1900 | ❌ Errors: 0
# [2025-07-29 22:30:21,649]   #chapter_start: 29674 total occurrences
# [2025-07-29 22:30:21,747]   #dialogue: 140684 total occurrences
# [2025-07-29 22:30:21,790]   #poem: 0 total occurrences
# [2025-07-29 22:30:21,882]   #story_within: 8586 total occurrences
# ⚡ Tagging Progress:  21%|██        | 1999/9492 [02:47<17:58,  6.95file/s][2025-07-29 22:30:30,356]
# 📍 INTERMEDIATE STATUS @ 2000 files:
# [2025-07-29 22:30:30,396]   ✅ Processed: 2000 | ❌ Errors: 0
# [2025-07-29 22:30:30,425]   #chapter_start: 30916 total occurrences
# [2025-07-29 22:30:30,487]   #dialogue: 146099 total occurrences
# [2025-07-29 22:30:30,586]   #poem: 0 total occurrences
# [2025-07-29 22:30:30,691]   #story_within: 8854 total occurrences
# ⚡ Tagging Progress:  22%|██▏       | 2097/9492 [02:55<08:40, 14.22file/s][2025-07-29 22:30:38,114]
# 📍 INTERMEDIATE STATUS @ 2100 files:
# [2025-07-29 22:30:38,141]   ✅ Processed: 2100 | ❌ Errors: 0
# [2025-07-29 22:30:38,336]   #chapter_start: 31843 total occurrences
# [2025-07-29 22:30:38,474]   #dialogue: 151674 total occurrences
# [2025-07-29 22:30:38,625]   #poem: 0 total occurrences
# [2025-07-29 22:30:38,648]   #story_within: 9347 total occurrences
# ⚡ Tagging Progress:  23%|██▎       | 2196/9492 [03:03<10:18, 11.80file/s][2025-07-29 22:30:46,385]
# 📍 INTERMEDIATE STATUS @ 2200 files:
# [2025-07-29 22:30:46,440]   ✅ Processed: 2200 | ❌ Errors: 0
# [2025-07-29 22:30:46,534]   #chapter_start: 32755 total occurrences
# [2025-07-29 22:30:46,571]   #dialogue: 159742 total occurrences
# [2025-07-29 22:30:46,607]   #poem: 0 total occurrences
# [2025-07-29 22:30:46,635]   #story_within: 9753 total occurrences
# ⚡ Tagging Progress:  24%|██▍       | 2294/9492 [03:12<08:52, 13.53file/s][2025-07-29 22:30:54,916]
# 📍 INTERMEDIATE STATUS @ 2300 files:
# [2025-07-29 22:30:54,988]   ✅ Processed: 2300 | ❌ Errors: 0
# [2025-07-29 22:30:55,024]   #chapter_start: 33591 total occurrences
# [2025-07-29 22:30:55,035]   #dialogue: 169142 total occurrences
# [2025-07-29 22:30:55,042]   #poem: 0 total occurrences
# [2025-07-29 22:30:55,052]   #story_within: 10478 total occurrences
# ⚡ Tagging Progress:  25%|██▌       | 2399/9492 [03:19<08:50, 13.38file/s][2025-07-29 22:31:02,728]
# 📍 INTERMEDIATE STATUS @ 2400 files:
# [2025-07-29 22:31:02,749]   ✅ Processed: 2400 | ❌ Errors: 0
# [2025-07-29 22:31:02,781]   #chapter_start: 34718 total occurrences
# [2025-07-29 22:31:02,820]   #dialogue: 178053 total occurrences
# [2025-07-29 22:31:02,922]   #poem: 0 total occurrences
# [2025-07-29 22:31:03,186]   #story_within: 11236 total occurrences
# ⚡ Tagging Progress:  26%|██▋       | 2499/9492 [03:27<06:05, 19.15file/s][2025-07-29 22:31:10,004]
# 📍 INTERMEDIATE STATUS @ 2500 files:
# [2025-07-29 22:31:10,076]   ✅ Processed: 2500 | ❌ Errors: 0
# [2025-07-29 22:31:10,341]   #chapter_start: 36384 total occurrences
# [2025-07-29 22:31:10,362]   #dialogue: 183102 total occurrences
# [2025-07-29 22:31:10,454]   #poem: 0 total occurrences
# [2025-07-29 22:31:10,522]   #story_within: 11597 total occurrences
# ⚡ Tagging Progress:  27%|██▋       | 2599/9492 [03:34<07:47, 14.75file/s][2025-07-29 22:31:17,161]
# 📍 INTERMEDIATE STATUS @ 2600 files:
# [2025-07-29 22:31:17,187]   ✅ Processed: 2600 | ❌ Errors: 0
# [2025-07-29 22:31:17,256]   #chapter_start: 37559 total occurrences
# [2025-07-29 22:31:17,285]   #dialogue: 191596 total occurrences
# [2025-07-29 22:31:17,402]   #poem: 0 total occurrences
# [2025-07-29 22:31:17,532]   #story_within: 12069 total occurrences
# ⚡ Tagging Progress:  28%|██▊       | 2698/9492 [03:43<09:13, 12.27file/s][2025-07-29 22:31:26,160]
# 📍 INTERMEDIATE STATUS @ 2700 files:
# [2025-07-29 22:31:26,199]   ✅ Processed: 2700 | ❌ Errors: 0
# [2025-07-29 22:31:26,278]   #chapter_start: 38953 total occurrences
# [2025-07-29 22:31:26,315]   #dialogue: 197718 total occurrences
# [2025-07-29 22:31:26,391]   #poem: 0 total occurrences
# [2025-07-29 22:31:26,481]   #story_within: 12584 total occurrences
# ⚡ Tagging Progress:  29%|██▉       | 2799/9492 [03:57<25:18,  4.41file/s][2025-07-29 22:31:40,782]
# 📍 INTERMEDIATE STATUS @ 2800 files:
# [2025-07-29 22:31:40,859]   ✅ Processed: 2800 | ❌ Errors: 0
# [2025-07-29 22:31:40,970]   #chapter_start: 41176 total occurrences
# [2025-07-29 22:31:41,131]   #dialogue: 200869 total occurrences
# [2025-07-29 22:31:41,360]   #poem: 0 total occurrences
# [2025-07-29 22:31:41,380]   #story_within: 12921 total occurrences
# ⚡ Tagging Progress:  31%|███       | 2897/9492 [04:05<05:45, 19.10file/s][2025-07-29 22:31:48,575]
# 📍 INTERMEDIATE STATUS @ 2900 files:
# [2025-07-29 22:31:48,623]   ✅ Processed: 2900 | ❌ Errors: 0
# [2025-07-29 22:31:48,677]   #chapter_start: 43656 total occurrences
# [2025-07-29 22:31:48,699]   #dialogue: 206689 total occurrences
# [2025-07-29 22:31:48,723]   #poem: 0 total occurrences
# [2025-07-29 22:31:48,742]   #story_within: 13318 total occurrences
# ⚡ Tagging Progress:  32%|███▏      | 2999/9492 [04:11<04:15, 25.43file/s][2025-07-29 22:31:54,121]
# 📍 INTERMEDIATE STATUS @ 3000 files:
# [2025-07-29 22:31:54,147]   ✅ Processed: 3000 | ❌ Errors: 0
# [2025-07-29 22:31:54,147]   #chapter_start: 46209 total occurrences
# [2025-07-29 22:31:54,181]   #dialogue: 212393 total occurrences
# [2025-07-29 22:31:54,251]   #poem: 0 total occurrences
# [2025-07-29 22:31:54,271]   #story_within: 13729 total occurrences
# ⚡ Tagging Progress:  33%|███▎      | 3098/9492 [04:17<08:20, 12.77file/s][2025-07-29 22:32:00,540]
# 📍 INTERMEDIATE STATUS @ 3100 files:
# [2025-07-29 22:32:00,595]   ✅ Processed: 3100 | ❌ Errors: 0
# [2025-07-29 22:32:00,632]   #chapter_start: 48412 total occurrences
# [2025-07-29 22:32:00,678]   #dialogue: 217424 total occurrences
# [2025-07-29 22:32:00,738]   #poem: 0 total occurrences
# [2025-07-29 22:32:00,795]   #story_within: 14232 total occurrences
# ⚡ Tagging Progress:  34%|███▎      | 3196/9492 [04:24<05:30, 19.05file/s][2025-07-29 22:32:07,192]
# 📍 INTERMEDIATE STATUS @ 3200 files:
# [2025-07-29 22:32:07,224]   ✅ Processed: 3200 | ❌ Errors: 0
# [2025-07-29 22:32:07,289]   #chapter_start: 49486 total occurrences
# [2025-07-29 22:32:07,412]   #dialogue: 224040 total occurrences
# [2025-07-29 22:32:07,437]   #poem: 0 total occurrences
# [2025-07-29 22:32:07,452]   #story_within: 14683 total occurrences
# ⚡ Tagging Progress:  35%|███▍      | 3296/9492 [04:29<03:58, 26.03file/s][2025-07-29 22:32:12,790]
# 📍 INTERMEDIATE STATUS @ 3300 files:
# [2025-07-29 22:32:12,856]   ✅ Processed: 3300 | ❌ Errors: 0
# [2025-07-29 22:32:12,877]   #chapter_start: 49833 total occurrences
# [2025-07-29 22:32:13,027]   #dialogue: 227566 total occurrences
# [2025-07-29 22:32:13,049]   #poem: 0 total occurrences
# [2025-07-29 22:32:13,072]   #story_within: 14843 total occurrences
# ⚡ Tagging Progress:  36%|███▌      | 3396/9492 [04:36<06:54, 14.69file/s][2025-07-29 22:32:18,935]
# 📍 INTERMEDIATE STATUS @ 3400 files:
# [2025-07-29 22:32:18,952]   ✅ Processed: 3400 | ❌ Errors: 0
# [2025-07-29 22:32:19,070]   #chapter_start: 50467 total occurrences
# [2025-07-29 22:32:19,206]   #dialogue: 229872 total occurrences
# [2025-07-29 22:32:19,274]   #poem: 0 total occurrences
# [2025-07-29 22:32:19,302]   #story_within: 15252 total occurrences
# ⚡ Tagging Progress:  37%|███▋      | 3498/9492 [04:44<08:24, 11.87file/s][2025-07-29 22:32:27,414]
# 📍 INTERMEDIATE STATUS @ 3500 files:
# [2025-07-29 22:32:27,481]   ✅ Processed: 3500 | ❌ Errors: 0
# [2025-07-29 22:32:27,500]   #chapter_start: 52288 total occurrences
# [2025-07-29 22:32:27,611]   #dialogue: 235372 total occurrences
# [2025-07-29 22:32:27,645]   #poem: 0 total occurrences
# [2025-07-29 22:32:27,786]   #story_within: 15693 total occurrences
# ⚡ Tagging Progress:  38%|███▊      | 3597/9492 [04:51<05:04, 19.33file/s][2025-07-29 22:32:33,937]
# 📍 INTERMEDIATE STATUS @ 3600 files:
# [2025-07-29 22:32:33,958]   ✅ Processed: 3600 | ❌ Errors: 0
# [2025-07-29 22:32:34,015]   #chapter_start: 53264 total occurrences
# [2025-07-29 22:32:34,034]   #dialogue: 239499 total occurrences
# [2025-07-29 22:32:34,098]   #poem: 0 total occurrences
# [2025-07-29 22:32:34,186]   #story_within: 16057 total occurrences
# ⚡ Tagging Progress:  39%|███▉      | 3697/9492 [04:58<09:01, 10.70file/s][2025-07-29 22:32:40,977]
# 📍 INTERMEDIATE STATUS @ 3700 files:
# [2025-07-29 22:32:41,017]   ✅ Processed: 3700 | ❌ Errors: 0
# [2025-07-29 22:32:41,030]   #chapter_start: 54672 total occurrences
# [2025-07-29 22:32:41,044]   #dialogue: 245919 total occurrences
# [2025-07-29 22:32:41,141]   #poem: 0 total occurrences
# [2025-07-29 22:32:41,266]   #story_within: 16454 total occurrences
# ⚡ Tagging Progress:  40%|████      | 3797/9492 [05:02<02:57, 32.03file/s][2025-07-29 22:32:45,521]
# 📍 INTERMEDIATE STATUS @ 3800 files:
# [2025-07-29 22:32:45,540]   ✅ Processed: 3800 | ❌ Errors: 0
# [2025-07-29 22:32:45,618]   #chapter_start: 55507 total occurrences
# [2025-07-29 22:32:45,660]   #dialogue: 252763 total occurrences
# [2025-07-29 22:32:45,723]   #poem: 0 total occurrences
# [2025-07-29 22:32:45,845]   #story_within: 16837 total occurrences
# ⚡ Tagging Progress:  41%|████      | 3899/9492 [05:09<10:59,  8.49file/s][2025-07-29 22:32:51,993]
# 📍 INTERMEDIATE STATUS @ 3900 files:
# [2025-07-29 22:32:52,020]   ✅ Processed: 3900 | ❌ Errors: 0
# [2025-07-29 22:32:52,047]   #chapter_start: 56675 total occurrences
# [2025-07-29 22:32:52,138]   #dialogue: 256709 total occurrences
# [2025-07-29 22:32:52,310]   #poem: 0 total occurrences
# [2025-07-29 22:32:52,379]   #story_within: 17359 total occurrences
# ⚡ Tagging Progress:  42%|████▏     | 3998/9492 [05:15<04:13, 21.71file/s][2025-07-29 22:32:58,417]
# 📍 INTERMEDIATE STATUS @ 4000 files:
# [2025-07-29 22:32:58,520]   ✅ Processed: 4000 | ❌ Errors: 0
# [2025-07-29 22:32:58,566]   #chapter_start: 57969 total occurrences
# [2025-07-29 22:32:58,611]   #dialogue: 266210 total occurrences
# [2025-07-29 22:32:58,664]   #poem: 0 total occurrences
# [2025-07-29 22:32:58,670]   #story_within: 17867 total occurrences
# ⚡ Tagging Progress:  43%|████▎     | 4099/9492 [05:21<04:56, 18.16file/s][2025-07-29 22:33:04,528]
# 📍 INTERMEDIATE STATUS @ 4100 files:
# [2025-07-29 22:33:04,579]   ✅ Processed: 4100 | ❌ Errors: 0
# [2025-07-29 22:33:04,626]   #chapter_start: 59207 total occurrences
# [2025-07-29 22:33:04,681]   #dialogue: 271902 total occurrences
# [2025-07-29 22:33:04,739]   #poem: 0 total occurrences
# [2025-07-29 22:33:04,808]   #story_within: 18252 total occurrences
# ⚡ Tagging Progress:  44%|████▍     | 4198/9492 [05:26<04:50, 18.24file/s][2025-07-29 22:33:09,720]
# 📍 INTERMEDIATE STATUS @ 4200 files:
# [2025-07-29 22:33:09,847]   ✅ Processed: 4200 | ❌ Errors: 0
# [2025-07-29 22:33:09,909]   #chapter_start: 60375 total occurrences
# [2025-07-29 22:33:09,965]   #dialogue: 277540 total occurrences
# [2025-07-29 22:33:10,115]   #poem: 0 total occurrences
# [2025-07-29 22:33:10,212]   #story_within: 18657 total occurrences
# ⚡ Tagging Progress:  45%|████▌     | 4294/9492 [05:34<04:49, 17.93file/s][2025-07-29 22:33:17,452]
# 📍 INTERMEDIATE STATUS @ 4300 files:
# [2025-07-29 22:33:17,463]   ✅ Processed: 4300 | ❌ Errors: 0
# [2025-07-29 22:33:17,471]   #chapter_start: 61697 total occurrences
# [2025-07-29 22:33:17,481]   #dialogue: 285760 total occurrences
# [2025-07-29 22:33:17,497]   #poem: 0 total occurrences
# [2025-07-29 22:33:17,510]   #story_within: 19266 total occurrences
# ⚡ Tagging Progress:  46%|████▋     | 4397/9492 [05:42<07:15, 11.70file/s][2025-07-29 22:33:25,324]
# 📍 INTERMEDIATE STATUS @ 4400 files:
# [2025-07-29 22:33:25,343]   ✅ Processed: 4400 | ❌ Errors: 0
# [2025-07-29 22:33:25,476]   #chapter_start: 63158 total occurrences
# [2025-07-29 22:33:25,599]   #dialogue: 300022 total occurrences
# [2025-07-29 22:33:25,664]   #poem: 0 total occurrences
# [2025-07-29 22:33:25,697]   #story_within: 19774 total occurrences
# ⚡ Tagging Progress:  47%|████▋     | 4498/9492 [05:47<03:37, 22.97file/s][2025-07-29 22:33:30,669]
# 📍 INTERMEDIATE STATUS @ 4500 files:
# [2025-07-29 22:33:30,726]   ✅ Processed: 4500 | ❌ Errors: 0
# [2025-07-29 22:33:30,737]   #chapter_start: 64699 total occurrences
# [2025-07-29 22:33:30,847]   #dialogue: 303507 total occurrences
# [2025-07-29 22:33:30,898]   #poem: 0 total occurrences
# [2025-07-29 22:33:30,955]   #story_within: 20177 total occurrences
# ⚡ Tagging Progress:  48%|████▊     | 4593/9492 [05:53<05:30, 14.82file/s][2025-07-29 22:33:36,140]
# 📍 INTERMEDIATE STATUS @ 4600 files:
# [2025-07-29 22:33:36,254]   ✅ Processed: 4600 | ❌ Errors: 0
# [2025-07-29 22:33:36,455]   #chapter_start: 65843 total occurrences
# [2025-07-29 22:33:36,577]   #dialogue: 307213 total occurrences
# [2025-07-29 22:33:36,617]   #poem: 0 total occurrences
# [2025-07-29 22:33:36,633]   #story_within: 20372 total occurrences
# ⚡ Tagging Progress:  49%|████▉     | 4695/9492 [06:00<05:18, 15.05file/s][2025-07-29 22:33:43,063]
# 📍 INTERMEDIATE STATUS @ 4700 files:
# [2025-07-29 22:33:43,101]   ✅ Processed: 4700 | ❌ Errors: 0
# [2025-07-29 22:33:43,123]   #chapter_start: 67240 total occurrences
# [2025-07-29 22:33:43,130]   #dialogue: 313454 total occurrences
# [2025-07-29 22:33:43,140]   #poem: 0 total occurrences
# [2025-07-29 22:33:43,224]   #story_within: 20895 total occurrences
# ⚡ Tagging Progress:  51%|█████     | 4796/9492 [06:06<05:11, 15.06file/s][2025-07-29 22:33:49,011]
# 📍 INTERMEDIATE STATUS @ 4800 files:
# [2025-07-29 22:33:49,022]   ✅ Processed: 4800 | ❌ Errors: 0
# [2025-07-29 22:33:49,081]   #chapter_start: 68344 total occurrences
# [2025-07-29 22:33:49,127]   #dialogue: 318625 total occurrences
# [2025-07-29 22:33:49,148]   #poem: 0 total occurrences
# [2025-07-29 22:33:49,234]   #story_within: 21266 total occurrences
# ⚡ Tagging Progress:  52%|█████▏    | 4899/9492 [06:11<04:44, 16.17file/s][2025-07-29 22:33:54,189]
# 📍 INTERMEDIATE STATUS @ 4900 files:
# [2025-07-29 22:33:54,469]   ✅ Processed: 4900 | ❌ Errors: 0
# [2025-07-29 22:33:54,552]   #chapter_start: 69182 total occurrences
# [2025-07-29 22:33:54,636]   #dialogue: 326252 total occurrences
# [2025-07-29 22:33:54,668]   #poem: 0 total occurrences
# [2025-07-29 22:33:54,692]   #story_within: 21636 total occurrences
# ⚡ Tagging Progress:  53%|█████▎    | 4999/9492 [06:18<03:23, 22.11file/s][2025-07-29 22:34:00,888]
# 📍 INTERMEDIATE STATUS @ 5000 files:
# [2025-07-29 22:34:00,908]   ✅ Processed: 5000 | ❌ Errors: 0
# [2025-07-29 22:34:00,918]   #chapter_start: 70172 total occurrences
# [2025-07-29 22:34:01,003]   #dialogue: 331888 total occurrences
# [2025-07-29 22:34:01,012]   #poem: 0 total occurrences
# [2025-07-29 22:34:01,072]   #story_within: 22099 total occurrences
# ⚡ Tagging Progress:  54%|█████▎    | 5097/9492 [06:22<02:53, 25.35file/s][2025-07-29 22:34:05,503]
# 📍 INTERMEDIATE STATUS @ 5100 files:
# [2025-07-29 22:34:05,509]   ✅ Processed: 5100 | ❌ Errors: 0
# [2025-07-29 22:34:05,518]   #chapter_start: 71040 total occurrences
# [2025-07-29 22:34:05,550]   #dialogue: 335458 total occurrences
# [2025-07-29 22:34:05,611]   #poem: 0 total occurrences
# [2025-07-29 22:34:05,666]   #story_within: 22577 total occurrences
# ⚡ Tagging Progress:  55%|█████▍    | 5199/9492 [06:28<02:11, 32.61file/s][2025-07-29 22:34:10,971]
# 📍 INTERMEDIATE STATUS @ 5200 files:
# [2025-07-29 22:34:10,997]   ✅ Processed: 5200 | ❌ Errors: 0
# [2025-07-29 22:34:11,049]   #chapter_start: 71886 total occurrences
# [2025-07-29 22:34:11,086]   #dialogue: 338918 total occurrences
# [2025-07-29 22:34:11,125]   #poem: 0 total occurrences
# [2025-07-29 22:34:11,137]   #story_within: 23001 total occurrences
# ⚡ Tagging Progress:  56%|█████▌    | 5299/9492 [06:35<05:05, 13.72file/s][2025-07-29 22:34:17,930]
# 📍 INTERMEDIATE STATUS @ 5300 files:
# [2025-07-29 22:34:18,000]   ✅ Processed: 5300 | ❌ Errors: 0
# [2025-07-29 22:34:18,028]   #chapter_start: 72823 total occurrences
# [2025-07-29 22:34:18,064]   #dialogue: 347436 total occurrences
# [2025-07-29 22:34:18,088]   #poem: 0 total occurrences
# [2025-07-29 22:34:18,156]   #story_within: 23648 total occurrences
# ⚡ Tagging Progress:  57%|█████▋    | 5399/9492 [06:42<03:41, 18.46file/s][2025-07-29 22:34:25,275]
# 📍 INTERMEDIATE STATUS @ 5400 files:
# [2025-07-29 22:34:25,323]   ✅ Processed: 5400 | ❌ Errors: 0
# [2025-07-29 22:34:25,450]   #chapter_start: 73536 total occurrences
# [2025-07-29 22:34:25,524]   #dialogue: 354655 total occurrences
# [2025-07-29 22:34:25,532]   #poem: 0 total occurrences
# [2025-07-29 22:34:25,610]   #story_within: 24216 total occurrences
# ⚡ Tagging Progress:  58%|█████▊    | 5496/9492 [06:49<02:59, 22.21file/s][2025-07-29 22:34:32,159]
# 📍 INTERMEDIATE STATUS @ 5500 files:
# [2025-07-29 22:34:32,188]   ✅ Processed: 5500 | ❌ Errors: 0
# [2025-07-29 22:34:32,200]   #chapter_start: 75778 total occurrences
# [2025-07-29 22:34:32,223]   #dialogue: 366665 total occurrences
# [2025-07-29 22:34:32,226]   #poem: 0 total occurrences
# [2025-07-29 22:34:32,295]   #story_within: 24583 total occurrences
# ⚡ Tagging Progress:  59%|█████▉    | 5598/9492 [06:57<10:04,  6.44file/s][2025-07-29 22:34:40,458]
# 📍 INTERMEDIATE STATUS @ 5600 files:
# [2025-07-29 22:34:40,490]   ✅ Processed: 5600 | ❌ Errors: 0
# [2025-07-29 22:34:40,510]   #chapter_start: 77959 total occurrences
# [2025-07-29 22:34:40,660]   #dialogue: 371992 total occurrences
# [2025-07-29 22:34:40,724]   #poem: 0 total occurrences
# [2025-07-29 22:34:40,777]   #story_within: 24926 total occurrences
# ⚡ Tagging Progress:  60%|██████    | 5699/9492 [07:03<03:09, 20.03file/s][2025-07-29 22:34:46,610]
# 📍 INTERMEDIATE STATUS @ 5700 files:
# [2025-07-29 22:34:46,635]   ✅ Processed: 5700 | ❌ Errors: 0
# [2025-07-29 22:34:46,665]   #chapter_start: 79440 total occurrences
# [2025-07-29 22:34:46,681]   #dialogue: 374726 total occurrences
# [2025-07-29 22:34:46,689]   #poem: 0 total occurrences
# [2025-07-29 22:34:46,705]   #story_within: 25194 total occurrences
# ⚡ Tagging Progress:  61%|██████    | 5799/9492 [07:10<04:21, 14.12file/s][2025-07-29 22:34:53,672]
# 📍 INTERMEDIATE STATUS @ 5800 files:
# [2025-07-29 22:34:53,701]   ✅ Processed: 5800 | ❌ Errors: 0
# [2025-07-29 22:34:53,782]   #chapter_start: 80521 total occurrences
# [2025-07-29 22:34:53,796]   #dialogue: 385602 total occurrences
# [2025-07-29 22:34:53,807]   #poem: 0 total occurrences
# [2025-07-29 22:34:53,811]   #story_within: 25683 total occurrences
# ⚡ Tagging Progress:  62%|██████▏   | 5895/9492 [07:19<03:48, 15.71file/s][2025-07-29 22:35:02,713]
# 📍 INTERMEDIATE STATUS @ 5900 files:
# [2025-07-29 22:35:02,792]   ✅ Processed: 5900 | ❌ Errors: 0
# [2025-07-29 22:35:02,936]   #chapter_start: 82475 total occurrences
# [2025-07-29 22:35:02,983]   #dialogue: 396173 total occurrences
# [2025-07-29 22:35:03,033]   #poem: 0 total occurrences
# [2025-07-29 22:35:03,177]   #story_within: 26387 total occurrences
# ⚡ Tagging Progress:  63%|██████▎   | 5999/9492 [07:25<03:01, 19.25file/s][2025-07-29 22:35:08,420]
# 📍 INTERMEDIATE STATUS @ 6000 files:
# [2025-07-29 22:35:08,444]   ✅ Processed: 6000 | ❌ Errors: 0
# [2025-07-29 22:35:08,512]   #chapter_start: 83943 total occurrences
# [2025-07-29 22:35:08,716]   #dialogue: 404027 total occurrences
# [2025-07-29 22:35:08,782]   #poem: 0 total occurrences
# [2025-07-29 22:35:08,814]   #story_within: 26780 total occurrences
# ⚡ Tagging Progress:  64%|██████▍   | 6099/9492 [07:33<04:19, 13.08file/s][2025-07-29 22:35:16,135]
# 📍 INTERMEDIATE STATUS @ 6100 files:
# [2025-07-29 22:35:16,174]   ✅ Processed: 6100 | ❌ Errors: 0
# [2025-07-29 22:35:16,195]   #chapter_start: 85332 total occurrences
# [2025-07-29 22:35:16,210]   #dialogue: 409648 total occurrences
# [2025-07-29 22:35:16,240]   #poem: 0 total occurrences
# [2025-07-29 22:35:16,263]   #story_within: 27268 total occurrences
# ⚡ Tagging Progress:  65%|██████▌   | 6199/9492 [07:41<04:05, 13.41file/s][2025-07-29 22:35:23,968]
# 📍 INTERMEDIATE STATUS @ 6200 files:
# [2025-07-29 22:35:24,021]   ✅ Processed: 6200 | ❌ Errors: 0
# [2025-07-29 22:35:24,060]   #chapter_start: 87276 total occurrences
# [2025-07-29 22:35:24,069]   #dialogue: 418634 total occurrences
# [2025-07-29 22:35:24,093]   #poem: 0 total occurrences
# [2025-07-29 22:35:24,110]   #story_within: 27664 total occurrences
# ⚡ Tagging Progress:  66%|██████▋   | 6299/9492 [07:47<03:25, 15.57file/s][2025-07-29 22:35:30,399]
# 📍 INTERMEDIATE STATUS @ 6300 files:
# [2025-07-29 22:35:30,468]   ✅ Processed: 6300 | ❌ Errors: 0
# [2025-07-29 22:35:30,524]   #chapter_start: 89050 total occurrences
# [2025-07-29 22:35:30,581]   #dialogue: 430250 total occurrences
# [2025-07-29 22:35:30,737]   #poem: 0 total occurrences
# [2025-07-29 22:35:30,752]   #story_within: 28133 total occurrences
# ⚡ Tagging Progress:  67%|██████▋   | 6399/9492 [07:53<03:03, 16.83file/s][2025-07-29 22:35:36,132]
# 📍 INTERMEDIATE STATUS @ 6400 files:
# [2025-07-29 22:35:36,206]   ✅ Processed: 6400 | ❌ Errors: 0
# [2025-07-29 22:35:36,324]   #chapter_start: 90341 total occurrences
# [2025-07-29 22:35:36,386]   #dialogue: 437272 total occurrences
# [2025-07-29 22:35:36,386]   #poem: 0 total occurrences
# [2025-07-29 22:35:36,426]   #story_within: 28543 total occurrences
# ⚡ Tagging Progress:  68%|██████▊   | 6496/9492 [07:59<02:18, 21.62file/s][2025-07-29 22:35:42,004]
# 📍 INTERMEDIATE STATUS @ 6500 files:
# [2025-07-29 22:35:42,022]   ✅ Processed: 6500 | ❌ Errors: 0
# [2025-07-29 22:35:42,082]   #chapter_start: 92549 total occurrences
# [2025-07-29 22:35:42,158]   #dialogue: 449036 total occurrences
# [2025-07-29 22:35:42,158]   #poem: 0 total occurrences
# [2025-07-29 22:35:42,366]   #story_within: 28928 total occurrences
# ⚡ Tagging Progress:  70%|██████▉   | 6598/9492 [08:05<02:51, 16.84file/s][2025-07-29 22:35:48,144]
# 📍 INTERMEDIATE STATUS @ 6600 files:
# [2025-07-29 22:35:48,193]   ✅ Processed: 6600 | ❌ Errors: 0
# [2025-07-29 22:35:48,205]   #chapter_start: 94239 total occurrences
# [2025-07-29 22:35:48,219]   #dialogue: 457390 total occurrences
# [2025-07-29 22:35:48,234]   #poem: 0 total occurrences
# [2025-07-29 22:35:48,254]   #story_within: 29468 total occurrences
# ⚡ Tagging Progress:  71%|███████   | 6696/9492 [08:11<03:27, 13.46file/s][2025-07-29 22:35:54,222]
# 📍 INTERMEDIATE STATUS @ 6700 files:
# [2025-07-29 22:35:54,286]   ✅ Processed: 6700 | ❌ Errors: 0
# [2025-07-29 22:35:54,288]   #chapter_start: 96055 total occurrences
# [2025-07-29 22:35:54,305]   #dialogue: 469521 total occurrences
# [2025-07-29 22:35:54,327]   #poem: 0 total occurrences
# [2025-07-29 22:35:54,341]   #story_within: 29930 total occurrences
# ⚡ Tagging Progress:  72%|███████▏  | 6798/9492 [08:20<02:16, 19.78file/s][2025-07-29 22:36:02,978]
# 📍 INTERMEDIATE STATUS @ 6800 files:
# [2025-07-29 22:36:03,061]   ✅ Processed: 6800 | ❌ Errors: 0
# [2025-07-29 22:36:03,253]   #chapter_start: 98130 total occurrences
# [2025-07-29 22:36:03,260]   #dialogue: 480265 total occurrences
# [2025-07-29 22:36:03,398]   #poem: 0 total occurrences
# [2025-07-29 22:36:03,484]   #story_within: 30664 total occurrences
# ⚡ Tagging Progress:  73%|███████▎  | 6899/9492 [08:29<02:15, 19.19file/s][2025-07-29 22:36:11,993]
# 📍 INTERMEDIATE STATUS @ 6900 files:
# [2025-07-29 22:36:12,056]   ✅ Processed: 6900 | ❌ Errors: 0
# [2025-07-29 22:36:12,161]   #chapter_start: 100480 total occurrences
# [2025-07-29 22:36:12,188]   #dialogue: 489158 total occurrences
# [2025-07-29 22:36:12,283]   #poem: 0 total occurrences
# [2025-07-29 22:36:12,324]   #story_within: 31088 total occurrences
# ⚡ Tagging Progress:  74%|███████▎  | 6997/9492 [08:35<03:16, 12.67file/s][2025-07-29 22:36:18,995]
# 📍 INTERMEDIATE STATUS @ 7000 files:
# [2025-07-29 22:36:19,010]   ✅ Processed: 7000 | ❌ Errors: 0
# [2025-07-29 22:36:19,082]   #chapter_start: 101715 total occurrences
# [2025-07-29 22:36:19,102]   #dialogue: 498667 total occurrences
# [2025-07-29 22:36:19,122]   #poem: 0 total occurrences
# [2025-07-29 22:36:19,161]   #story_within: 31695 total occurrences
# ⚡ Tagging Progress:  75%|███████▍  | 7098/9492 [08:42<03:15, 12.27file/s][2025-07-29 22:36:25,766]
# 📍 INTERMEDIATE STATUS @ 7100 files:
# [2025-07-29 22:36:25,781]   ✅ Processed: 7100 | ❌ Errors: 0
# [2025-07-29 22:36:25,985]   #chapter_start: 103275 total occurrences
# [2025-07-29 22:36:26,045]   #dialogue: 509841 total occurrences
# [2025-07-29 22:36:26,074]   #poem: 0 total occurrences
# [2025-07-29 22:36:26,097]   #story_within: 32201 total occurrences
# ⚡ Tagging Progress:  76%|███████▌  | 7196/9492 [08:49<01:43, 22.17file/s][2025-07-29 22:36:32,527]
# 📍 INTERMEDIATE STATUS @ 7200 files:
# [2025-07-29 22:36:32,552]   ✅ Processed: 7200 | ❌ Errors: 0
# [2025-07-29 22:36:32,566]   #chapter_start: 105094 total occurrences
# [2025-07-29 22:36:32,580]   #dialogue: 517262 total occurrences
# [2025-07-29 22:36:32,585]   #poem: 0 total occurrences
# [2025-07-29 22:36:32,585]   #story_within: 32658 total occurrences
# ⚡ Tagging Progress:  77%|███████▋  | 7297/9492 [09:00<03:49,  9.56file/s][2025-07-29 22:36:43,152]
# 📍 INTERMEDIATE STATUS @ 7300 files:
# [2025-07-29 22:36:43,184]   ✅ Processed: 7300 | ❌ Errors: 0
# [2025-07-29 22:36:43,299]   #chapter_start: 106392 total occurrences
# [2025-07-29 22:36:43,386]   #dialogue: 526813 total occurrences
# [2025-07-29 22:36:43,462]   #poem: 0 total occurrences
# [2025-07-29 22:36:43,534]   #story_within: 33141 total occurrences
# ⚡ Tagging Progress:  78%|███████▊  | 7398/9492 [09:06<02:02, 17.12file/s][2025-07-29 22:36:49,214]
# 📍 INTERMEDIATE STATUS @ 7400 files:
# [2025-07-29 22:36:49,392]   ✅ Processed: 7400 | ❌ Errors: 0
# [2025-07-29 22:36:49,593]   #chapter_start: 108179 total occurrences
# [2025-07-29 22:36:49,621]   #dialogue: 534176 total occurrences
# [2025-07-29 22:36:49,648]   #poem: 0 total occurrences
# [2025-07-29 22:36:49,664]   #story_within: 33471 total occurrences
# ⚡ Tagging Progress:  79%|███████▉  | 7498/9492 [09:12<00:55, 35.72file/s][2025-07-29 22:36:55,396]
# 📍 INTERMEDIATE STATUS @ 7500 files:
# [2025-07-29 22:36:55,405]   ✅ Processed: 7500 | ❌ Errors: 0
# [2025-07-29 22:36:55,420]   #chapter_start: 110102 total occurrences
# [2025-07-29 22:36:55,423]   #dialogue: 539142 total occurrences
# [2025-07-29 22:36:55,439]   #poem: 0 total occurrences
# [2025-07-29 22:36:55,500]   #story_within: 33872 total occurrences
# ⚡ Tagging Progress:  80%|████████  | 7598/9492 [09:18<02:33, 12.36file/s][2025-07-29 22:37:01,001]
# 📍 INTERMEDIATE STATUS @ 7600 files:
# [2025-07-29 22:37:01,037]   ✅ Processed: 7600 | ❌ Errors: 0
# [2025-07-29 22:37:01,187]   #chapter_start: 111083 total occurrences
# [2025-07-29 22:37:01,195]   #dialogue: 542610 total occurrences
# [2025-07-29 22:37:01,203]   #poem: 0 total occurrences
# [2025-07-29 22:37:01,215]   #story_within: 34226 total occurrences
# ⚡ Tagging Progress:  81%|████████  | 7699/9492 [09:24<01:07, 26.67file/s][2025-07-29 22:37:07,012]
# 📍 INTERMEDIATE STATUS @ 7700 files:
# [2025-07-29 22:37:07,032]   ✅ Processed: 7700 | ❌ Errors: 0
# [2025-07-29 22:37:07,086]   #chapter_start: 112383 total occurrences
# [2025-07-29 22:37:07,101]   #dialogue: 546534 total occurrences
# [2025-07-29 22:37:07,213]   #poem: 0 total occurrences
# [2025-07-29 22:37:07,224]   #story_within: 34561 total occurrences
# ⚡ Tagging Progress:  82%|████████▏ | 7799/9492 [09:30<01:22, 20.65file/s][2025-07-29 22:37:13,391]
# 📍 INTERMEDIATE STATUS @ 7800 files:
# [2025-07-29 22:37:13,478]   ✅ Processed: 7800 | ❌ Errors: 0
# [2025-07-29 22:37:13,592]   #chapter_start: 114146 total occurrences
# [2025-07-29 22:37:13,639]   #dialogue: 557831 total occurrences
# [2025-07-29 22:37:13,696]   #poem: 0 total occurrences
# [2025-07-29 22:37:13,753]   #story_within: 35008 total occurrences
# ⚡ Tagging Progress:  83%|████████▎ | 7896/9492 [09:37<01:20, 19.70file/s][2025-07-29 22:37:20,644]
# 📍 INTERMEDIATE STATUS @ 7900 files:
# [2025-07-29 22:37:20,685]   ✅ Processed: 7900 | ❌ Errors: 0
# [2025-07-29 22:37:20,717]   #chapter_start: 116372 total occurrences
# [2025-07-29 22:37:20,724]   #dialogue: 563411 total occurrences
# [2025-07-29 22:37:20,801]   #poem: 0 total occurrences
# [2025-07-29 22:37:20,820]   #story_within: 35490 total occurrences
# ⚡ Tagging Progress:  84%|████████▍ | 7997/9492 [09:45<01:27, 17.03file/s][2025-07-29 22:37:27,843]
# 📍 INTERMEDIATE STATUS @ 8000 files:
# [2025-07-29 22:37:27,883]   ✅ Processed: 8000 | ❌ Errors: 0
# [2025-07-29 22:37:27,903]   #chapter_start: 118316 total occurrences
# [2025-07-29 22:37:27,940]   #dialogue: 579292 total occurrences
# [2025-07-29 22:37:27,962]   #poem: 0 total occurrences
# [2025-07-29 22:37:28,008]   #story_within: 36027 total occurrences
# ⚡ Tagging Progress:  85%|████████▌ | 8098/9492 [09:51<00:57, 24.29file/s][2025-07-29 22:37:34,061]
# 📍 INTERMEDIATE STATUS @ 8100 files:
# [2025-07-29 22:37:34,092]   ✅ Processed: 8100 | ❌ Errors: 0
# [2025-07-29 22:37:34,127]   #chapter_start: 119994 total occurrences
# [2025-07-29 22:37:34,165]   #dialogue: 588796 total occurrences
# [2025-07-29 22:37:34,185]   #poem: 0 total occurrences
# [2025-07-29 22:37:34,196]   #story_within: 36401 total occurrences
# ⚡ Tagging Progress:  86%|████████▋ | 8196/9492 [09:56<00:50, 25.47file/s][2025-07-29 22:37:38,944]
# 📍 INTERMEDIATE STATUS @ 8200 files:
# [2025-07-29 22:37:39,022]   ✅ Processed: 8200 | ❌ Errors: 0
# [2025-07-29 22:37:39,046]   #chapter_start: 121194 total occurrences
# [2025-07-29 22:37:39,105]   #dialogue: 594510 total occurrences
# [2025-07-29 22:37:39,127]   #poem: 0 total occurrences
# [2025-07-29 22:37:39,142]   #story_within: 36809 total occurrences
# ⚡ Tagging Progress:  87%|████████▋ | 8294/9492 [10:01<00:56, 21.32file/s][2025-07-29 22:37:44,105]
# 📍 INTERMEDIATE STATUS @ 8300 files:
# [2025-07-29 22:37:44,114]   ✅ Processed: 8300 | ❌ Errors: 0
# [2025-07-29 22:37:44,119]   #chapter_start: 123010 total occurrences
# [2025-07-29 22:37:44,139]   #dialogue: 601408 total occurrences
# [2025-07-29 22:37:44,166]   #poem: 0 total occurrences
# [2025-07-29 22:37:44,210]   #story_within: 37134 total occurrences
# ⚡ Tagging Progress:  88%|████████▊ | 8398/9492 [10:04<00:55, 19.65file/s][2025-07-29 22:37:47,411]
# 📍 INTERMEDIATE STATUS @ 8400 files:
# [2025-07-29 22:37:47,462]   ✅ Processed: 8400 | ❌ Errors: 0
# [2025-07-29 22:37:47,466]   #chapter_start: 123855 total occurrences
# [2025-07-29 22:37:47,477]   #dialogue: 605734 total occurrences
# [2025-07-29 22:37:47,509]   #poem: 0 total occurrences
# [2025-07-29 22:37:47,620]   #story_within: 37414 total occurrences
# ⚡ Tagging Progress:  90%|████████▉ | 8499/9492 [10:10<00:56, 17.52file/s][2025-07-29 22:37:52,726]
# 📍 INTERMEDIATE STATUS @ 8500 files:
# [2025-07-29 22:37:52,746]   ✅ Processed: 8500 | ❌ Errors: 0
# [2025-07-29 22:37:52,755]   #chapter_start: 125027 total occurrences
# [2025-07-29 22:37:52,779]   #dialogue: 615761 total occurrences
# [2025-07-29 22:37:52,803]   #poem: 0 total occurrences
# [2025-07-29 22:37:52,807]   #story_within: 37763 total occurrences
# ⚡ Tagging Progress:  91%|█████████ | 8597/9492 [10:14<00:36, 24.55file/s][2025-07-29 22:37:57,722]
# 📍 INTERMEDIATE STATUS @ 8600 files:
# [2025-07-29 22:37:57,765]   ✅ Processed: 8600 | ❌ Errors: 0
# [2025-07-29 22:37:57,798]   #chapter_start: 126651 total occurrences
# [2025-07-29 22:37:57,819]   #dialogue: 623563 total occurrences
# [2025-07-29 22:37:57,880]   #poem: 0 total occurrences
# [2025-07-29 22:37:58,015]   #story_within: 38147 total occurrences
# ⚡ Tagging Progress:  92%|█████████▏| 8697/9492 [10:24<01:05, 12.20file/s][2025-07-29 22:38:06,842]
# 📍 INTERMEDIATE STATUS @ 8700 files:
# [2025-07-29 22:38:06,923]   ✅ Processed: 8700 | ❌ Errors: 0
# [2025-07-29 22:38:06,967]   #chapter_start: 130438 total occurrences
# [2025-07-29 22:38:06,990]   #dialogue: 633872 total occurrences
# [2025-07-29 22:38:07,027]   #poem: 0 total occurrences
# [2025-07-29 22:38:07,050]   #story_within: 38697 total occurrences
# ⚡ Tagging Progress:  93%|█████████▎| 8799/9492 [10:30<00:50, 13.75file/s][2025-07-29 22:38:13,702]
# 📍 INTERMEDIATE STATUS @ 8800 files:
# [2025-07-29 22:38:13,728]   ✅ Processed: 8800 | ❌ Errors: 0
# [2025-07-29 22:38:13,754]   #chapter_start: 131678 total occurrences
# [2025-07-29 22:38:13,795]   #dialogue: 640833 total occurrences
# [2025-07-29 22:38:13,822]   #poem: 0 total occurrences
# [2025-07-29 22:38:13,840]   #story_within: 39145 total occurrences
# ⚡ Tagging Progress:  94%|█████████▎| 8898/9492 [10:38<00:42, 13.92file/s][2025-07-29 22:38:21,199]
# 📍 INTERMEDIATE STATUS @ 8900 files:
# [2025-07-29 22:38:21,225]   ✅ Processed: 8900 | ❌ Errors: 0
# [2025-07-29 22:38:21,237]   #chapter_start: 133464 total occurrences
# [2025-07-29 22:38:21,284]   #dialogue: 654352 total occurrences
# [2025-07-29 22:38:21,302]   #poem: 0 total occurrences
# [2025-07-29 22:38:21,307]   #story_within: 39715 total occurrences
# ⚡ Tagging Progress:  95%|█████████▍| 8997/9492 [10:44<00:54,  9.05file/s][2025-07-29 22:38:27,596]
# 📍 INTERMEDIATE STATUS @ 9000 files:
# [2025-07-29 22:38:27,633]   ✅ Processed: 9000 | ❌ Errors: 0
# [2025-07-29 22:38:27,648]   #chapter_start: 135431 total occurrences
# [2025-07-29 22:38:27,759]   #dialogue: 671317 total occurrences
# [2025-07-29 22:38:27,773]   #poem: 0 total occurrences
# [2025-07-29 22:38:27,869]   #story_within: 40215 total occurrences
# ⚡ Tagging Progress:  96%|█████████▌| 9098/9492 [10:51<00:23, 16.56file/s][2025-07-29 22:38:34,636]
# 📍 INTERMEDIATE STATUS @ 9100 files:
# [2025-07-29 22:38:34,670]   ✅ Processed: 9100 | ❌ Errors: 0
# [2025-07-29 22:38:34,821]   #chapter_start: 136638 total occurrences
# [2025-07-29 22:38:34,973]   #dialogue: 685935 total occurrences
# [2025-07-29 22:38:35,050]   #poem: 0 total occurrences
# [2025-07-29 22:38:35,183]   #story_within: 40530 total occurrences
# ⚡ Tagging Progress:  97%|█████████▋| 9198/9492 [10:59<00:20, 14.21file/s][2025-07-29 22:38:42,779]
# 📍 INTERMEDIATE STATUS @ 9200 files:
# [2025-07-29 22:38:42,835]   ✅ Processed: 9200 | ❌ Errors: 0
# [2025-07-29 22:38:42,856]   #chapter_start: 138867 total occurrences
# [2025-07-29 22:38:42,899]   #dialogue: 695107 total occurrences
# [2025-07-29 22:38:42,914]   #poem: 0 total occurrences
# [2025-07-29 22:38:42,947]   #story_within: 41008 total occurrences
# ⚡ Tagging Progress:  98%|█████████▊| 9297/9492 [11:06<00:10, 19.36file/s][2025-07-29 22:38:49,676]
# 📍 INTERMEDIATE STATUS @ 9300 files:
# [2025-07-29 22:38:49,757]   ✅ Processed: 9300 | ❌ Errors: 0
# [2025-07-29 22:38:49,858]   #chapter_start: 140519 total occurrences
# [2025-07-29 22:38:49,903]   #dialogue: 703507 total occurrences
# [2025-07-29 22:38:49,917]   #poem: 0 total occurrences
# [2025-07-29 22:38:50,010]   #story_within: 41615 total occurrences
# ⚡ Tagging Progress:  99%|█████████▉| 9398/9492 [11:13<00:03, 24.83file/s][2025-07-29 22:38:56,161]
# 📍 INTERMEDIATE STATUS @ 9400 files:
# [2025-07-29 22:38:56,192]   ✅ Processed: 9400 | ❌ Errors: 0
# [2025-07-29 22:38:56,233]   #chapter_start: 141787 total occurrences
# [2025-07-29 22:38:56,281]   #dialogue: 710054 total occurrences
# [2025-07-29 22:38:56,364]   #poem: 0 total occurrences
# [2025-07-29 22:38:56,383]   #story_within: 42024 total occurrences
# ⚡ Tagging Progress: 100%|██████████| 9492/9492 [11:17<00:00, 14.02file/s]
# [2025-07-29 22:38:59,906]
# ✅ PROCESSING COMPLETE
# [2025-07-29 22:38:59,907] ⏱️  Duration: 678.87s | ⚡ Speed: 13.98 files/s
# [2025-07-29 22:38:59,909] 📊 Processed: 9492 | Errors: 0
# [2025-07-29 22:38:59,910] 📈 Tag Summary: C:\Users\ayush\OneDrive\Desktop\Stories\tagging_report.csv
# [2025-07-29 22:38:59,911] 📝 Tag Details: C:\Users\ayush\OneDrive\Desktop\Stories\tag_details.csv
# [2025-07-29 22:38:59,912]
# 🏷️ FINAL TAG DISTRIBUTION:
# [2025-07-29 22:38:59,913]   #chapter_start: 141820 tags
# [2025-07-29 22:38:59,914]   #dialogue: 710112 tags
# [2025-07-29 22:38:59,916]   #poem: 0 tags
# [2025-07-29 22:38:59,917]   #story_within: 42025 tags

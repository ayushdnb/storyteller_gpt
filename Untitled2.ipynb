# %%
import os
import re
import hashlib
import shutil
import logging
from pathlib import Path
from chardet import detect
import pandas as pd
import unicodedata

# ========== CONFIGURATION ==========
BASE_DIR = Path(r"C:\Users\ayush\OneDrive\Desktop\Stories")
CLEANED_DIR = BASE_DIR / "cleaned_files"
RAW_DIR = BASE_DIR
LOG_DIR = CLEANED_DIR / "cleaning_phase_log"
DUP_LOG = LOG_DIR / "duplicates_log.txt"
CSV_LOG = LOG_DIR / "cleaning_report.csv"

# Create required directories if they don't exist
for dir_path in [CLEANED_DIR, LOG_DIR]:
    dir_path.mkdir(parents=True, exist_ok=True)

# ========== PRE-COMPILED REGEX PATTERNS ==========
# For normalize_text
ILLUSTRATION_PAT = re.compile(r"\[Illustration:.*?\]", re.IGNORECASE|re.DOTALL)
PAGE_PAT = re.compile(r"-?\[?Page\s*\d+\]?", re.IGNORECASE)
START_MARKER_PAT = re.compile(r"\*{3,}.*?START.*?\*{3,}", re.IGNORECASE|re.DOTALL)
END_MARKER_PAT = re.compile(r"\*{3,}.*?END.*?\*{3,}", re.IGNORECASE|re.DOTALL)
PRODUCTION_CREDIT_PAT = re.compile(r"^\s*\*{3,}.*?Produced by.*$", re.IGNORECASE|re.MULTILINE)
END_NOTICE_PAT = re.compile(r"^\s*End of (the )?Project Gutenberg.*$", re.IGNORECASE|re.MULTILINE)
HYPHEN_REJOIN_PAT = re.compile(r"(\S)-\n(\S)")
EXCESS_NEWLINE_PAT = re.compile(r"\n{3,}")
WHITESPACE_PAT = re.compile(r"[ \t]+")

# For extract_metadata
METADATA_PATTERNS = {
    "PGID": re.compile(r'PG(?:ID)?:?\s*(\d{3,})', re.IGNORECASE),
    "Title": re.compile(r'Title:?\s*([^\n]+)', re.IGNORECASE),
    "Author": re.compile(r'Author:?\s*([^\n]+)', re.IGNORECASE),
    "ReleaseDate": re.compile(r'Release\s*Date:?\s*([^\n]+)', re.IGNORECASE),
    "Language": re.compile(r'Language:?\s*([^\n]+)', re.IGNORECASE)
}

# For filename sanitization
INVALID_CHARS_PAT = re.compile(r'[\\/*?:"<>|]')

# ========== ROBUST LOGGING SETUP ==========
log_formatter = logging.Formatter('[%(asctime)s] %(levelname)s: %(message)s')
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# File handler
file_handler = logging.FileHandler(
    LOG_DIR / "phase1_cleaning.log", 
    mode='w', 
    encoding='utf-8'
)
file_handler.setFormatter(log_formatter)
logger.addHandler(file_handler)

# Console handler
console_handler = logging.StreamHandler()
console_handler.setFormatter(log_formatter)
logger.addHandler(console_handler)

# ========== TRACKING STATS ==========
report_data = []
seen_hashes = {}
file_counter = 0
processed_files = 0
duplicates_found = 0
error_files = 0

# ========== OPTIMIZED UTILITY FUNCTIONS ==========
def sanitize_filename(name):
    """Sanitize filenames by removing invalid characters"""
    return INVALID_CHARS_PAT.sub("", name).strip()

def normalize_text(text):
    """Optimized text normalization with pre-compiled patterns"""
    # Remove Project Gutenberg artifacts
    text = ILLUSTRATION_PAT.sub("", text)
    text = PAGE_PAT.sub("", text)
    text = START_MARKER_PAT.sub("", text)
    text = END_MARKER_PAT.sub("", text)
    text = PRODUCTION_CREDIT_PAT.sub("", text)
    text = END_NOTICE_PAT.sub("", text)
    
    # Structural improvements
    text = HYPHEN_REJOIN_PAT.sub(r"\1\2", text)  # Rejoin hyphenated words
    text = EXCESS_NEWLINE_PAT.sub("\n\n", text)   # Reduce excessive newlines
    text = WHITESPACE_PAT.sub(" ", text)          # Collapse whitespace
    text = text.replace("--", "—")               # Em-dash conversion
    
    # Special character handling
    char_map = {
        "æ": "ae",    # U+00e6
        "œ": "oe",    # U+0153
        "ß": "ss",    # U+00df
        "½": "1/2",   # U+00bd
        "“": '"',     # U+201c
        "”": '"',     # U+201d
        "‘": "'",     # U+2018
        "’": "'"      # U+2019
    }
    
    for char, replacement in char_map.items():
        text = text.replace(char, replacement)
    
    # Normalize unicode characters
    return unicodedata.normalize('NFKC', text).strip()

def extract_metadata(text):
    """Optimized metadata extraction with pre-compiled patterns"""
    metadata_text = text[:5000]  # Only examine first 5K characters
    metadata = {}
    
    for key, pattern in METADATA_PATTERNS.items():
        match = pattern.search(metadata_text)
        result = match.group(1).strip() if match else ""
        # Validate and truncate metadata
        if result and len(result) <= 150:
            metadata[key] = result
        else:
            metadata[key] = "Unknown"
    
    return metadata

# ========== MAIN CLEANING PROCESS ==========
logging.info("🚀 Starting Phase 1 Cleaning...")
all_files = list(RAW_DIR.rglob("*.txt"))
total_files = len(all_files)
logging.info(f"📂 Total files detected: {total_files}\n")

with open(DUP_LOG, 'w', encoding='utf-8') as dup_log:
    for file_path in all_files:
        file_counter += 1
        file_stats = {
            "Original Filename": file_path.name,
            "PGID": "N/A",
            "Title": "N/A",
            "Author": "N/A",
            "Encoding": "Unknown",
            "Original Size (KB)": round(file_path.stat().st_size / 1024, 2),
            "Status": "Pending"
        }
        
        logging.info(f"[{file_counter}/{total_files}] Processing: {file_path.name}")
        
        try:
            # ===== SECURITY CHECK =====
            file_size = file_path.stat().st_size
            if file_size > 10 * 1024 * 1024:  # 10MB limit
                raise ValueError("File exceeds size limit (10MB)")
                
            # ===== SINGLE READ OPERATION =====
            binary_data = file_path.read_bytes()
            
            # ===== DUPLICATE DETECTION =====
            sha256 = hashlib.sha256(binary_data).hexdigest()
            file_stats["SHA256"] = sha256
                
            if sha256 in seen_hashes:
                dup_log.write(f"REMOVED: {file_path.name} (duplicate of {seen_hashes[sha256]})\n")
                duplicates_found += 1
                file_stats["Status"] = "Duplicate"
                report_data.append(file_stats)
                continue
                
            seen_hashes[sha256] = file_path.name

            # ===== CONTENT PROCESSING =====
            # Detect encoding from sample
            sample = binary_data[:50000]
            encoding = detect(sample)['encoding'] or 'utf-8'
            file_stats["Encoding"] = encoding
            
            # Decode content
            try:
                content = binary_data.decode(encoding, errors='replace')
            except UnicodeDecodeError:
                content = binary_data.decode('utf-8', errors='replace')
                
            if not content.strip():
                raise ValueError("Empty file after reading")
                
            # Extract metadata
            metadata = extract_metadata(content)
            for key in ["PGID", "Title", "Author"]:
                file_stats[key] = metadata.get(key, "Unknown")
                
            # Normalize content
            content = normalize_text(content)
            
            # ===== FINAL STRUCTURE =====
            safe_title = sanitize_filename(metadata['Title'])
            output_file = CLEANED_DIR / f"{metadata['PGID']}_{safe_title}_clean.txt"
            
            # Handle duplicate filenames
            if output_file.exists():
                counter = 1
                while output_file.exists():
                    output_file = CLEANED_DIR / f"{metadata['PGID']}_{safe_title}_clean_{counter}.txt"
                    counter += 1
                    
            with open(output_file, 'w', encoding='utf-8-sig') as out:
                out.write(
                    f"[DOC_START]\n"
                    f"# PGID: {metadata['PGID']}\n"
                    f"# Title: {metadata['Title']}\n"
                    f"# Author: {metadata['Author']}\n"
                    f"# Release Date: {metadata.get('ReleaseDate', 'Unknown')}\n"
                    f"# Language: {metadata.get('Language', 'Unknown')}\n\n"
                    f"{content}\n"
                    f"[DOC_END]"
                )
                
            processed_files += 1
            file_stats["Status"] = "Processed"
            
        except Exception as e:
            error_files += 1
            logging.error(f"❌ Error processing {file_path.name}: {str(e)}")
            file_stats["Status"] = f"Error: {str(e)}"
            
        report_data.append(file_stats)

# ========== FINALIZATION & REPORTING ==========
logging.info("\n📊 Generating final reports...")
try:
    report_df = pd.DataFrame(report_data)
    column_order = [
        "Original Filename", "Status", "PGID", "Title", "Author", 
        "SHA256", "Encoding", "Original Size (KB)"
    ]
    report_df = report_df.reindex(columns=column_order)
    report_df.to_csv(CSV_LOG, index=False, encoding='utf-8-sig')
except Exception as e:
    logging.critical(f"Failed to generate CSV report: {str(e)}")

# Final summary
logging.info("\n✅ Phase 1 Cleaning Complete")
logging.info(f"📂 Total Files Scanned: {total_files}")
logging.info(f"✅ Successfully Processed: {processed_files}")
logging.info(f"🚫 Duplicates Skipped: {duplicates_found}")
logging.info(f"❗ Errors Encountered: {error_files}")
logging.info(f"📄 Detailed report saved to: {CSV_LOG}")
logging.info(f"📓 Duplicates log saved to: {DUP_LOG}")
# Out:
# [2025-07-28 18:41:16,063] INFO: 🚀 Starting Phase 1 Cleaning...
# [2025-07-28 18:41:16,162] INFO: 📂 Total files detected: 9530
#
# [2025-07-28 18:41:16,164] INFO: [1/9530] Processing: 01 Harry Potter and the Sorcerers Stone.txt
# [2025-07-28 18:41:16,322] INFO: [2/9530] Processing: 02 Harry Potter and the Chamber of Secrets.txt
# [2025-07-28 18:41:16,494] INFO: [3/9530] Processing: 03 Harry Potter and the Prisoner of Azkaban.txt
# [2025-07-28 18:41:16,688] INFO: [4/9530] Processing: 04 Harry Potter and the Goblet of Fire.txt
# [2025-07-28 18:41:17,016] INFO: [5/9530] Processing: 05 Harry Potter and the Order of the Phoenix.txt
# [2025-07-28 18:41:17,599] INFO: [6/9530] Processing: 06 Harry Potter and the Half-Blood Prince.txt
# [2025-07-28 18:41:18,815] INFO: [7/9530] Processing: 07 Harry Potter and the Deathly Hallows.txt
# [2025-07-28 18:41:19,447] INFO: [8/9530] Processing: 1000 Mythological Characters Briefly Described.txt
# [2025-07-28 18:41:19,568] INFO: [9/9530] Processing: 10004_the_warriors__by_anna_robertson_brown_li.txt
# [2025-07-28 18:41:19,692] INFO: [10/9530] Processing: 10011_365_foreign_dishes__by_unknown_author.txt
# [2025-07-28 18:41:19,766] INFO: [11/9530] Processing: 1001_divine_comedy__inferno__by_dante_alighie.txt
# [2025-07-28 18:41:19,873] INFO: [12/9530] Processing: 1002_divine_comedy__purgatory__by_dante_aligh.txt
# [2025-07-28 18:41:20,058] INFO: [13/9530] Processing: 1003_divine_comedy__paradise__by_dante_alighi.txt
# [2025-07-28 18:41:20,196] INFO: [14/9530] Processing: 10042_the_child_under_eight__by_e__r__murray_a.txt
# [2025-07-28 18:41:20,382] INFO: [15/9530] Processing: 10044_chronicles_of_canada__volume_12_of_32__t.txt
# [2025-07-28 18:41:20,558] INFO: [16/9530] Processing: 10046_salute_to_adventurers__by_john_buchan.txt
# [2025-07-28 18:41:20,766] INFO: [17/9530] Processing: 1004_divine_comedy__complete__by_dante_alighi.txt
# [2025-07-28 18:41:21,113] INFO: [18/9530] Processing: 10053_la_vampire__by_paul_h__c__feval.txt
# [2025-07-28 18:41:21,317] INFO: [19/9530] Processing: 10055_hamburgische_dramaturgie__by_gotthold_ep.txt
# [2025-07-28 18:41:21,778] INFO: [20/9530] Processing: 10056_chinese_literature__by_anonymous.txt
# [2025-07-28 18:41:21,955] INFO: [21/9530] Processing: 10058_the_divine_office__by_rev__e__j__quigley.txt
# [2025-07-28 18:41:22,101] INFO: [22/9530] Processing: 1005_divine_comedy__hell__by_dante_alighieri.txt
# [2025-07-28 18:41:22,188] INFO: [23/9530] Processing: 10069_account_of_the_romansh_language__by_jose.txt
# [2025-07-28 18:41:22,234] INFO: [24/9530] Processing: 1006_divine_comedy__purgatory__by_dante_aligh.txt
# [2025-07-28 18:41:22,321] INFO: [25/9530] Processing: 10070_stories_of_great_americans_for_little_am.txt
# [2025-07-28 18:41:22,413] INFO: [26/9530] Processing: 10075_a_narrative_of_the_life_and_adventures_o.txt
# [2025-07-28 18:41:22,461] INFO: [27/9530] Processing: 10076_lister_s_great_adventure__by_harold_bind.txt
# [2025-07-28 18:41:22,642] INFO: [28/9530] Processing: 1007_divine_comedy__paradise__by_dante_alighi.txt
# [2025-07-28 18:41:22,797] INFO: [29/9530] Processing: 10082_the_hampstead_mystery__by_john_r__watson.txt
# [2025-07-28 18:41:23,057] INFO: [30/9530] Processing: 10085_Moorish Literature Comprising Romantic Ballads, Tales of the Berbers, Stories of the Kabyles, Folk-L.txt
# [2025-07-28 18:41:23,263] INFO: [31/9530] Processing: 10089_elves_and_heroes__by_donald_a__mackenzie.txt
# [2025-07-28 18:41:23,331] INFO: [32/9530] Processing: 1008_divine_comedy__complete__by_dante_alighi.txt
# [2025-07-28 18:41:23,610] INFO: [33/9530] Processing: 10095_the_twilight_of_the_gods__and_other_tale.txt
# [2025-07-28 18:41:23,778] INFO: [34/9530] Processing: 10096_the_trojan_women__by_euripides.txt
# [2025-07-28 18:41:23,842] INFO: [35/9530] Processing: 10130_the_works_of_charles_and_mary_lamb__vol_.txt
# [2025-07-28 18:41:24,217] INFO: [36/9530] Processing: 10148_The Merry Adventures of Robin Hood.txt
# [2025-07-28 18:41:24,424] INFO: [37/9530] Processing: 10148_the_merry_adventures_of_robin_hood__by_h.txt
# [2025-07-28 18:41:24,692] INFO: [38/9530] Processing: 10165_Across the Zodiac The Story of a Wrecked Record.txt
# [2025-07-28 18:41:25,002] INFO: [39/9530] Processing: 1017_The Soul of Man under Socialism.txt
# [2025-07-28 18:41:25,085] INFO: [40/9530] Processing: 101_The Hacker Crackdown Law and Disorder on the Electronic Frontier.txt
# [2025-07-28 18:41:25,266] INFO: [41/9530] Processing: 10214_introduction_to_the_philosophy_and_writi.txt
# [2025-07-28 18:41:25,344] INFO: [42/9530] Processing: 10315_persian_literature__volume_1__comprising.txt
# [2025-07-28 18:41:25,571] INFO: [43/9530] Processing: 10316_roy_blakeley_s_adventures_in_camp__by_pe.txt
# [2025-07-28 18:41:25,655] INFO: [44/9530] Processing: 10321_Dragon's blood.txt
# [2025-07-28 18:41:25,770] INFO: [45/9530] Processing: 10335_children_s_rights__by_kate_douglas_wiggi.txt
# [2025-07-28 18:41:25,895] INFO: [46/9530] Processing: 10360_kitty_s_class_day_and_other_stories__by_.txt
# [2025-07-28 18:41:26,076] INFO: [47/9530] Processing: 10366_freedom_s_battle__by_mahatma_gandhi.txt
# [2025-07-28 18:41:26,261] INFO: [48/9530] Processing: 1036_Joe Wilson and His Mates.txt
# [2025-07-28 18:41:26,419] INFO: [49/9530] Processing: 10376_american_indian_stories__by_zitkala_sa.txt
# [2025-07-28 18:41:26,490] INFO: [50/9530] Processing: 10380_bible_stories_and_religious_classics__by.txt
# [2025-07-28 18:41:26,737] INFO: [51/9530] Processing: 10381_The History of a Crime The Testimony of an Eye-Witness.txt
# [2025-07-28 18:41:26,987] INFO: [52/9530] Processing: 10383_the_maternal_management_of_children__in_.txt
# [2025-07-28 18:41:27,098] INFO: [53/9530] Processing: 10387_the_real_america_in_romance__volume_6__a.txt
# [2025-07-28 18:41:27,230] INFO: [54/9530] Processing: 10398_the_american_child__by_elizabeth_mccrack.txt
# [2025-07-28 18:41:27,297] INFO: [55/9530] Processing: 10417_Love, Life & Work Being a Book of Opinions Reasonably Good-Natured Concerning How to Attain the High.txt
# [2025-07-28 18:41:27,352] INFO: [56/9530] Processing: 10419_The Forest Monster of Oz.txt
# [2025-07-28 18:41:27,419] INFO: [57/9530] Processing: 10440_tutt_and_mr__tutt__by_arthur_train.txt
# [2025-07-28 18:41:27,522] INFO: [58/9530] Processing: 10446_the_green_flag__by_arthur_conan_doyle.txt
# [2025-07-28 18:41:27,645] INFO: [59/9530] Processing: 10449_burnham_breaker__by_homer_greene.txt
# [2025-07-28 18:41:27,831] INFO: [60/9530] Processing: 10454_tales_for_young_and_old__by_various.txt
# [2025-07-28 18:41:27,991] INFO: [61/9530] Processing: 10458_Three short works The Dance of Death, the Legend of Saint Julian the Hospitaller, a Simple Soul..txt
# [2025-07-28 18:41:28,085] INFO: [62/9530] Processing: 10459_the_celtic_twilight__by_w__b__yeats.txt
# [2025-07-28 18:41:28,226] INFO: [63/9530] Processing: 10463_the_little_house_in_the_fairy_wood__by_e.txt
# [2025-07-28 18:41:28,380] INFO: [64/9530] Processing: 10464_a_child_s_anti_slavery_book__by_various.txt
# [2025-07-28 18:41:28,481] INFO: [65/9530] Processing: 10466_little_saint_elizabeth_and_other_stories.txt
# [2025-07-28 18:41:28,589] INFO: [66/9530] Processing: 10472_arthurian_chronicles__roman_de_brut__by_.txt
# [2025-07-28 18:41:28,802] INFO: [67/9530] Processing: 10477_Beacon Lights of History, Volume 01 The Old Pagan Civilizations.txt
# [2025-07-28 18:41:29,075] INFO: [68/9530] Processing: 10483_short_stories_old_and_new__by_various.txt
# [2025-07-28 18:41:29,371] INFO: [69/9530] Processing: 10490_the_golden_legend__by_henry_wadsworth_lo.txt
# [2025-07-28 18:41:29,502] INFO: [70/9530] Processing: 10506_romance_de_lobos__comedia_barbara__by_ra.txt
# [2025-07-28 18:41:29,610] INFO: [71/9530] Processing: 10508_the_sorrows_of_a_show_girl__by_kenneth_m.txt
# [2025-07-28 18:41:29,762] INFO: [72/9530] Processing: 10517_Government and Rebellion A Sermon Delivered in the North Broad Street Presbyterian Church, Sunday Mo.txt
# [2025-07-28 18:41:29,862] INFO: [73/9530] Processing: 10519_Mercy Philbrick's Choice.txt
# [2025-07-28 18:41:30,071] INFO: [74/9530] Processing: 10523_alcestis__by_euripides.txt
# [2025-07-28 18:41:30,157] INFO: [75/9530] Processing: 10541_children_s_classics_in_dramatic_form__by.txt
# [2025-07-28 18:41:30,257] INFO: [76/9530] Processing: 10548_the_westcotes__by_arthur_thomas_quiller_.txt
# [2025-07-28 18:41:30,348] INFO: [77/9530] Processing: 10549_a_romance_of_the_republic__by_lydia_mari.txt
# [2025-07-28 18:41:30,551] INFO: [78/9530] Processing: 10564_fairy_gold__by_w__w__jacobs.txt
# [2025-07-28 18:41:30,595] INFO: [79/9530] Processing: 10581_uncle_bernac__by_arthur_conan_doyle.txt
# [2025-07-28 18:41:30,717] INFO: [80/9530] Processing: 10588_seeing_europe_with_famous_authors__volum.txt
# [2025-07-28 18:41:30,833] INFO: [81/9530] Processing: 10592_adventures_in_friendship__by_david_grays.txt
# [2025-07-28 18:41:30,929] INFO: [82/9530] Processing: 10605_adventures_in_contentment__by_david_gray.txt
# [2025-07-28 18:41:31,024] INFO: [83/9530] Processing: 10608_the_turquoise_cup__and__the_desert__by_a.txt
# [2025-07-28 18:41:31,085] INFO: [84/9530] Processing: 10624_three_john_silence_stories__by_algernon_.txt
# [2025-07-28 18:41:31,209] INFO: [85/9530] Processing: 10625_A Concise Dictionary of Middle English from A.D. 1150 to 1580.txt
# [2025-07-28 18:41:31,578] INFO: [86/9530] Processing: 10628_Andrew Golding A Tale of the Great Plague.txt
# [2025-07-28 18:41:31,695] INFO: [87/9530] Processing: 1064_The Masque of the Red Death.txt
# [2025-07-28 18:41:31,748] INFO: [88/9530] Processing: 10659_three_more_john_silence_stories__by_alge.txt
# [2025-07-28 18:41:31,849] INFO: [89/9530] Processing: 10661_A Selection from the Discourses of Epictetus with the Encheiridion.txt
# [2025-07-28 18:41:31,958] INFO: [90/9530] Processing: 10661_selection_from_the_discourses_of_epictet.txt
# [2025-07-28 18:41:32,067] INFO: [91/9530] Processing: 10665_Life, letters, and Epicurean philosophy of Ninon de L'Enclos, the celebrated beauty of the seventeen.txt
# [2025-07-28 18:41:32,209] INFO: [92/9530] Processing: 10665_life__letters__and_epicurean_philosophy_.txt
# [2025-07-28 18:41:32,404] INFO: [93/9530] Processing: 10677_biographical_memorials_of_james_oglethor.txt
# [2025-07-28 18:41:32,593] INFO: [94/9530] Processing: 10700_the_history_of_england_from_the_first_in.txt
# [2025-07-28 18:41:33,007] INFO: [95/9530] Processing: 10713_The Bullitt Mission to Russia Testimony before the Committee on Foreign Relations, United States Sen.txt
# [2025-07-28 18:41:33,121] INFO: [96/9530] Processing: 10714_the_art_of_literature__by_arthur_schopen.txt
# [2025-07-28 18:41:33,217] INFO: [97/9530] Processing: 10715_counsels_and_maxims__by_arthur_schopenha.txt
# [2025-07-28 18:41:33,358] INFO: [98/9530] Processing: 10716_The Epic An Essay.txt
# [2025-07-28 18:41:33,452] INFO: [99/9530] Processing: 10716_the_epic__by_lascelles_abercrombie.txt
# [2025-07-28 18:41:33,527] INFO: [100/9530] Processing: 10731_the_essays_of_arthur_schopenhauer__the_a.txt
# [2025-07-28 18:41:33,647] INFO: [101/9530] Processing: 10732_the_essays_of_arthur_schopenhauer__studi.txt
# [2025-07-28 18:41:33,750] INFO: [102/9530] Processing: 10735_christmas_eve_on_lonesome_and_other_stor.txt
# [2025-07-28 18:41:33,846] INFO: [103/9530] Processing: 10736_children_of_the_frost__by_jack_london.txt
# [2025-07-28 18:41:34,001] INFO: [104/9530] Processing: 10739_the_essays_of_arthur_schopenhauer__by_ar.txt
# [2025-07-28 18:41:34,086] INFO: [105/9530] Processing: 10741_essays_of_arthur_schopenhauer__the_wisdo.txt
# [2025-07-28 18:41:34,232] INFO: [106/9530] Processing: 10741_The Essays of Arthur Schopenhauer the Wisdom of Life.txt
# [2025-07-28 18:41:34,352] INFO: [107/9530] Processing: 10744_Men, Women, and Ghosts.txt
# [2025-07-28 18:41:34,520] INFO: [108/9530] Processing: 10744_men__women__and_ghosts__by_elizabeth_stu.txt
# [2025-07-28 18:41:34,690] INFO: [109/9530] Processing: 10747_Chantecler Play in Four Acts.txt
# [2025-07-28 18:41:34,803] INFO: [110/9530] Processing: 10747_chantecler__by_edmond_rostand.txt
# [2025-07-28 18:41:34,902] INFO: [111/9530] Processing: 10765_thrilling_adventures_by_land_and_sea__by.txt
# [2025-07-28 18:41:35,107] INFO: [112/9530] Processing: 10771_philippine_folklore_stories__by_john_mau.txt
# [2025-07-28 18:41:35,148] INFO: [113/9530] Processing: 10773_ancient_and_modern_physics__by_thomas_e_.txt
# [2025-07-28 18:41:35,205] INFO: [114/9530] Processing: 10775_le_horla_and_other_stories__by_guy_de_ma.txt
# [2025-07-28 18:41:35,321] INFO: [115/9530] Processing: 10800_the_anatomy_of_melancholy__by_democritus.txt
# [2025-07-28 18:41:36,523] INFO: [116/9530] Processing: 10806_the_sword_of_welleran_and_other_stories_.txt
# [2025-07-28 18:41:36,628] INFO: [117/9530] Processing: 10814_legends__tales_and_poems__by_gustavo_ado.txt
# [2025-07-28 18:41:36,811] INFO: [118/9530] Processing: 1081_Dead Souls.txt
# [2025-07-28 18:41:37,067] INFO: [119/9530] Processing: 10824_un_tournoi_a_romans_en_1484__by_ulysse_c.txt
# [2025-07-28 18:41:37,109] INFO: [120/9530] Processing: 10828_roman_history__books_1_3__by_titus_liviu.txt
# [2025-07-28 18:41:37,298] INFO: [121/9530] Processing: 10832_Carnacki, the Ghost Finder.txt
# [2025-07-28 18:41:37,415] INFO: [122/9530] Processing: 10832_carnacki__the_ghost_finder__by_william_h.txt
# [2025-07-28 18:41:37,544] INFO: [123/9530] Processing: 10833_the_essays_of_arthur_schopenhauer__relig.txt
# [2025-07-28 18:41:37,621] INFO: [124/9530] Processing: 10835_dr__johnson_s_works__life__poems__and_ta.txt
# [2025-07-28 18:41:37,755] INFO: [125/9530] Processing: 10837_The Soul of Democracy The Philosophy of the World War in Relation to Human Liberty.txt
# [2025-07-28 18:41:37,836] INFO: [126/9530] Processing: 10837_the_soul_of_democracy__by_edward_howard_.txt
# [2025-07-28 18:41:37,924] INFO: [127/9530] Processing: 10842_the_life_of_captain_james_cook__by_arthu.txt
# [2025-07-28 18:41:38,050] INFO: [128/9530] Processing: 10847_the_maids_tragedy__by_francis_beaumont_a.txt
# [2025-07-28 18:41:38,136] INFO: [129/9530] Processing: 10857_My Native Land The United States its Wonders, its Beauties, and its People; with Descriptive Notes, .txt
# [2025-07-28 18:41:38,326] INFO: [130/9530] Processing: 10877_the_tragedies_of_the_medici__by_edgcumbe.txt
# [2025-07-28 18:41:38,469] INFO: [131/9530] Processing: 10887_babylonian_and_assyrian_literature__by_a.txt
# [2025-07-28 18:41:38,655] INFO: [132/9530] Processing: 10888_arthur_hamilton__and_his_dog__by_anonymo.txt
# [2025-07-28 18:41:38,721] INFO: [133/9530] Processing: 10889_the_life_and_romances_of_mrs__eliza_hayw.txt
# [2025-07-28 18:41:38,888] INFO: [134/9530] Processing: 10891_algonquin_indian_tales__by_egerton_r__yo.txt
# [2025-07-28 18:41:39,051] INFO: [135/9530] Processing: 10911_buried_alive__a_tale_of_these_days__by_a.txt
# [2025-07-28 18:41:39,191] INFO: [136/9530] Processing: 10915_the_girl_s_cabinet_of_instructive_and_mo.txt
# [2025-07-28 18:41:39,230] INFO: [137/9530] Processing: 10916_parent_and_child_vol__3__child_study_and.txt
# [2025-07-28 18:41:39,344] INFO: [138/9530] Processing: 1091_heroes_and_hero_worship__by_thomas_carly.txt
# [2025-07-28 18:41:39,501] INFO: [139/9530] Processing: 10926_saxe_holm_s_stories__by_helen_hunt_jacks.txt
# [2025-07-28 18:41:39,662] INFO: [140/9530] Processing: 10930_the_buccaneer_farmer__by_harold_bindloss.txt
# [2025-07-28 18:41:39,839] INFO: [141/9530] Processing: 10935_the_wonderful_adventures_of_nils__by_sel.txt
# [2025-07-28 18:41:40,135] INFO: [142/9530] Processing: 10941_jumalainen_naeytelmae__helvetti__by_dant.txt
# [2025-07-28 18:41:40,240] INFO: [143/9530] Processing: 10947_the_best_american_humorous_short_stories.txt
# [2025-07-28 18:41:40,474] INFO: [144/9530] Processing: 10948_the_stories_of_the_three_burglars__by_fr.txt
# [2025-07-28 18:41:40,549] INFO: [145/9530] Processing: 10949_the_romance_of_zion_chapel__3rd__ed___by.txt
# [2025-07-28 18:41:40,635] INFO: [146/9530] Processing: 10966_the_ghost_pirates__by_william_hope_hodgs.txt
# [2025-07-28 18:41:40,727] INFO: [147/9530] Processing: 1097_Mrs. Warren's Profession.txt
# [2025-07-28 18:41:40,865] INFO: [148/9530] Processing: 10981_child_s_new_story_book__anonymous.txt
# [2025-07-28 18:41:40,899] INFO: [149/9530] Processing: 10987_the_adventures_of_little_bewildered_henr.txt
# [2025-07-28 18:41:40,931] INFO: [150/9530] Processing: 10988_the_devil_s_admiral__by_frederick_ferdin.txt
# [2025-07-28 18:41:41,086] INFO: [151/9530] Processing: 10999_tales_of_bengal__by_s__b__banerjea.txt
# [2025-07-28 18:41:41,214] INFO: [152/9530] Processing: 11000_An Old Babylonian Version of the Gilgamesh Epic.txt
# [2025-07-28 18:41:41,308] INFO: [153/9530] Processing: 11000_an_old_babylonian_version_of_the_gilgame.txt
# [2025-07-28 18:41:41,404] INFO: [154/9530] Processing: 11008_antwerp_to_gallipoli__by_arthur_ruhl.txt
# [2025-07-28 18:41:41,636] INFO: [155/9530] Processing: 11014_christmas_in_legend_and_story__by_elva_s.txt
# [2025-07-28 18:41:41,751] INFO: [156/9530] Processing: 11016_port_of_adventure__by_charles_n__william.txt
# [2025-07-28 18:41:41,977] INFO: [157/9530] Processing: 11027_grimm_s_fairy_stories__by_jacob_grimm_an.txt
# [2025-07-28 18:41:42,071] INFO: [158/9530] Processing: 11028_philippine_folk_tales__by_carla_kern_bay.txt
# [2025-07-28 18:41:42,178] INFO: [159/9530] Processing: 11029_american_hero_myths__by_daniel_g__brinto.txt
# [2025-07-28 18:41:42,307] INFO: [160/9530] Processing: 11032_wilson_s_tales_of_the_borders_and_of_sco.txt
# [2025-07-28 18:41:42,477] INFO: [161/9530] Processing: 11036_legendes_normandes__by_gaston_lavalley.txt
# [2025-07-28 18:41:42,584] INFO: [162/9530] Processing: 11045_the_ghost_ship__by_richard_middleton.txt
# [2025-07-28 18:41:42,688] INFO: [163/9530] Processing: 11053_Minnie's Sacrifice.txt
# [2025-07-28 18:41:42,779] INFO: [164/9530] Processing: 11053_minnie_s_sacrifice__by_frances_ellen_wat.txt
# [2025-07-28 18:41:42,863] INFO: [165/9530] Processing: 11057_the_wife_of_his_youth_and_other_stories_.txt
# [2025-07-28 18:41:43,026] INFO: [166/9530] Processing: 11066_graf_von_loeben_and_the_legend_of_lorele.txt
# [2025-07-28 18:41:43,095] INFO: [167/9530] Processing: 11068_the_spirit_of_the_age__by_william_hazlit.txt
# [2025-07-28 18:41:43,256] INFO: [168/9530] Processing: 11072_jumalainen_naeytelmae__kiirastuli__by_da.txt
# [2025-07-28 18:41:43,346] INFO: [169/9530] Processing: 11079_Essays in Rebellion.txt
# [2025-07-28 18:41:43,605] INFO: [170/9530] Processing: 11082_Old Saint Paul's A Tale of the Plague and the Fire.txt
# [2025-07-28 18:41:43,983] INFO: [171/9530] Processing: 11092_the_history_of_tom_thumb_and_other_stori.txt
# [2025-07-28 18:41:44,023] INFO: [172/9530] Processing: 11096_tales_of_ind__by_t__ramakrishna.txt
# [2025-07-28 18:41:44,088] INFO: [173/9530] Processing: 11101_coleridge_s_ancient_mariner_and_select_p.txt
# [2025-07-28 18:41:44,157] INFO: [174/9530] Processing: 11110_a_countess_from_canada__by_bessie_marcha.txt
# [2025-07-28 18:41:44,327] INFO: [175/9530] Processing: 11129_uncle_humphrey_s_stories__by_various.txt
# [2025-07-28 18:41:44,378] INFO: [176/9530] Processing: 1113_A Midsummer Night's Dream.txt
# [2025-07-28 18:41:44,425] INFO: [177/9530] Processing: 11144_somewhere_in_france_and_other_stories__b.txt
# [2025-07-28 18:41:44,506] INFO: [178/9530] Processing: 11146_The Expedition of the Donner Party and its Tragic Fate.txt
# [2025-07-28 18:41:44,665] INFO: [179/9530] Processing: 11146_the_expedition_of_the_donner_party_and_i.txt
# [2025-07-28 18:41:44,837] INFO: [180/9530] Processing: 1114_The Merchant of Venice.txt
# [2025-07-28 18:41:44,897] INFO: [181/9530] Processing: 1114_the_merchant_of_venice__by_william_shake.txt
# [2025-07-28 18:41:44,958] INFO: [182/9530] Processing: 11153_no_hero__by_e__w__hornung.txt
# [2025-07-28 18:41:45,085] INFO: [183/9530] Processing: 11156_bed_time_stories__buddy_and_brighteyes_p.txt
# [2025-07-28 18:41:45,193] INFO: [184/9530] Processing: 11160_a_cotswold_village__by_j__arthur_gibbs.txt
# [2025-07-28 18:41:45,380] INFO: [185/9530] Processing: 11165_wild_wings__a_romance_of_youth__by_marga.txt
# [2025-07-28 18:41:45,569] INFO: [186/9530] Processing: 11166_For Gold or Soul The Story of a Great Department Store.txt
# [2025-07-28 18:41:45,670] INFO: [187/9530] Processing: 11166_for_gold_or_soul___by_lurana_w__sheldon.txt
# [2025-07-28 18:41:45,819] INFO: [188/9530] Processing: 11167_deccan_nursery_tales__by_c__a__kincaid.txt
# [2025-07-28 18:41:45,905] INFO: [189/9530] Processing: 11179_seeing_europe_with_famous_authors__vol__.txt
# [2025-07-28 18:41:46,015] INFO: [190/9530] Processing: 11188_The Temptation of Samuel Burge Captains All, Book 8..txt
# [2025-07-28 18:41:46,208] INFO: [191/9530] Processing: 11189_The Madness of Mr. Lister Captains All, Book 9..txt
# [2025-07-28 18:41:46,362] INFO: [192/9530] Processing: 11208_de_legende_en_de_heldhaftige__vroolijke_.txt
# [2025-07-28 18:41:46,627] INFO: [193/9530] Processing: 11228_The Marrow of Tradition.txt
# [2025-07-28 18:41:46,800] INFO: [194/9530] Processing: 11239_life_and_adventures_of_robinson_crusoe_o.txt
# [2025-07-28 18:41:47,026] INFO: [195/9530] Processing: 11241_wee_ones__bible_stories__by_anonymous.txt
# [2025-07-28 18:41:47,067] INFO: [196/9530] Processing: 11247_the_exploits_of_brigadier_gerard__by_art.txt
# [2025-07-28 18:41:47,312] INFO: [197/9530] Processing: 11248_The Delights of Wisdom Pertaining to Conjugial Love To Which is Added The Pleasures of Insanity Pert.txt
# [2025-07-28 18:41:47,810] INFO: [198/9530] Processing: 11252_martin_hewitt__investigator__by_arthur_m.txt
# [2025-07-28 18:41:47,928] INFO: [199/9530] Processing: 11263_the_adventures_of_a_special_corresponden.txt
# [2025-07-28 18:41:48,061] INFO: [200/9530] Processing: 11277_egyptian_ideas_of_the_future_life__by_e_.txt
# [2025-07-28 18:41:48,163] INFO: [201/9530] Processing: 11278_folk_tales_of_napoleon__by_honore_de_bal.txt
# [2025-07-28 18:41:48,212] INFO: [202/9530] Processing: 11283_plays_of_gods_and_men__by_lord_dunsany.txt
# [2025-07-28 18:41:48,295] INFO: [203/9530] Processing: 11308_the_book_of_enterprise_and_adventure__by.txt
# [2025-07-28 18:41:48,366] INFO: [204/9530] Processing: 11310_hindu_tales_from_the_sanskrit__by_s__m__.txt
# [2025-07-28 18:41:48,460] INFO: [205/9530] Processing: 11319_the_fairy_godmothers_and_other_tales__by.txt
# [2025-07-28 18:41:48,538] INFO: [206/9530] Processing: 11334_wilson_s_tales_of_the_borders_and_of_sco.txt
# [2025-07-28 18:41:48,681] INFO: [207/9530] Processing: 11339_aesop_s_fables__by_aesop.txt
# [2025-07-28 18:41:48,775] INFO: [208/9530] Processing: 11346_the_saint_s_tragedy__by_charles_kingsley.txt
# [2025-07-28 18:41:48,883] INFO: [209/9530] Processing: 11356_a_tale_of_one_city__the_new_birmingham__.txt
# [2025-07-28 18:41:48,973] INFO: [210/9530] Processing: 11360_sacred_and_profane_love__by_e__arnold_be.txt
# [2025-07-28 18:41:49,122] INFO: [211/9530] Processing: 11368_stories_of_inventors__by_russell_doubled.txt
# [2025-07-28 18:41:49,208] INFO: [212/9530] Processing: 11396_faedra__by_herman_bang.txt
# [2025-07-28 18:41:49,309] INFO: [213/9530] Processing: 11400_mystic_isles_of_the_south_seas__by_fredr.txt
# [2025-07-28 18:41:49,615] INFO: [214/9530] Processing: 11413_the_refugees__by_arthur_conan_doyle.txt
# [2025-07-28 18:41:49,828] INFO: [215/9530] Processing: 11431_character_sketches_of_romance__fiction_a.txt
# [2025-07-28 18:41:50,194] INFO: [216/9530] Processing: 11436_stories_by_american_authors__vol__1__by_.txt
# [2025-07-28 18:41:50,280] INFO: [217/9530] Processing: 11437_stories_by_american_authors__vol__5__by_.txt
# [2025-07-28 18:41:50,374] INFO: [218/9530] Processing: 11440_tales_of_three_hemispheres__by_lord_duns.txt
# [2025-07-28 18:41:50,437] INFO: [219/9530] Processing: 11451_the_rome_express__by_arthur_griffiths.txt
# [2025-07-28 18:41:50,544] INFO: [220/9530] Processing: 11452_stories_by_american_authors__vol__6__by_.txt
# [2025-07-28 18:41:50,666] INFO: [221/9530] Processing: 11461_Armenian Literature Comprising Poetry, Drama, Folk-lore and Classic Traditions; Translated into Engl.txt
# [2025-07-28 18:41:50,766] INFO: [222/9530] Processing: 11474_deep_waters__part_4__sam_s_ghost__by_w__.txt
# [2025-07-28 18:41:50,811] INFO: [223/9530] Processing: 11496_poetry__by_arthur_thomas_quiller_couch.txt
# [2025-07-28 18:41:50,861] INFO: [224/9530] Processing: 11501_laughing_bill_hyde_and_other_stories__by.txt
# [2025-07-28 18:41:51,025] INFO: [225/9530] Processing: 11512_o__henry_memorial_award_prize_stories_of.txt
# [2025-07-28 18:41:51,226] INFO: [226/9530] Processing: 11514_balcony_stories__by_grace_e__king.txt
# [2025-07-28 18:41:51,306] INFO: [227/9530] Processing: 11531_The Life of Marie de Medicis, Queen of France, Consort of Henri IV, and Regent of the Kingdom under .txt
# [2025-07-28 18:41:51,530] INFO: [228/9530] Processing: 11547_blackfoot_lodge_tales__by_george_bird_gr.txt
# [2025-07-28 18:41:51,724] INFO: [229/9530] Processing: 11592_children_s_hour_with_red_riding_hood_and.txt
# [2025-07-28 18:41:51,756] INFO: [230/9530] Processing: 11600_The Life of Marie de Medicis, Queen of France, Consort of Henri IV, and Regent of the Kingdom under .txt
# [2025-07-28 18:41:51,987] INFO: [231/9530] Processing: 11601_The Life of Marie de Medicis, Queen of France, Consort of Henri IV, and Regent of the Kingdom under .txt
# [2025-07-28 18:41:52,188] INFO: [232/9530] Processing: 11603_the_house_of_cobwebs_and_other_stories__.txt
# [2025-07-28 18:41:52,303] INFO: [233/9530] Processing: 11610_Madam Crowl's Ghost and the Dead Sexton.txt
# [2025-07-28 18:41:52,352] INFO: [234/9530] Processing: 11610_madam_crowl_s_ghost_and_the_dead_sexton_.txt
# [2025-07-28 18:41:52,394] INFO: [235/9530] Processing: 11623_the_dramatic_works_of_john_dryden__vol__.txt
# [2025-07-28 18:41:52,574] INFO: [236/9530] Processing: 11633_parsifal__a_drama_by_wagner_as_retold_by.txt
# [2025-07-28 18:41:52,614] INFO: [237/9530] Processing: 11655_Fate Knocks at the Door A Novel.txt
# [2025-07-28 18:41:52,825] INFO: [238/9530] Processing: 11655_fate_knocks_at_the_door__by_will_levingt.txt
# [2025-07-28 18:41:52,977] INFO: [239/9530] Processing: 11656_the_great_shadow_and_other_napoleonic_ta.txt
# [2025-07-28 18:41:53,056] INFO: [240/9530] Processing: 11658_williams_anthology__compiled_by_edwin_pa.txt
# [2025-07-28 18:41:53,149] INFO: [241/9530] Processing: 11671_the_rudder_grangers_abroad_and_other_sto.txt
# [2025-07-28 18:41:53,221] INFO: [242/9530] Processing: 11682_the_soul_of_the_war__by_philip_gibbs.txt
# [2025-07-28 18:41:53,370] INFO: [243/9530] Processing: 11690_calvert_of_strathore__by_carter_goodloe.txt
# [2025-07-28 18:41:53,496] INFO: [244/9530] Processing: 11696_the_food_of_the_gods_and_how_it_came_to_.txt
# [2025-07-28 18:41:53,596] INFO: [245/9530] Processing: 11699_J. S. Le Fanu's Ghostly Tales, Volume 1.txt
# [2025-07-28 18:41:53,638] INFO: [246/9530] Processing: 11699_j__s__le_fanu_s_ghostly_tales__vol__1__b.txt
# [2025-07-28 18:41:53,680] INFO: [247/9530] Processing: 11700_j__s__le_fanu_s_ghostly_tales__vol__2__b.txt
# [2025-07-28 18:41:53,714] INFO: [248/9530] Processing: 11703_the_swiss_family_robinson__or_adventures.txt
# [2025-07-28 18:41:53,854] INFO: [249/9530] Processing: 11721_o__henry_memorial_award_prize_stories_of.txt
# [2025-07-28 18:41:54,005] INFO: [250/9530] Processing: 11738_hindoo_tales__translated_by_p__w__jacob.txt
# [2025-07-28 18:41:54,077] INFO: [251/9530] Processing: 11750_j__s__le_fanu_s_ghostly_tales__vol__3__b.txt
# [2025-07-28 18:41:54,150] INFO: [252/9530] Processing: 11752_Chivalry Dizain des Reines.txt
# [2025-07-28 18:41:54,230] INFO: [253/9530] Processing: 11859_isaac_t__hopper__by_l__maria_child.txt
# [2025-07-28 18:41:54,375] INFO: [254/9530] Processing: 11866_the_life_and_most_surprising_adventures_.txt
# [2025-07-28 18:41:54,532] INFO: [255/9530] Processing: 11870_the_country_of_the_blind__and_other_stor.txt
# [2025-07-28 18:41:54,756] INFO: [256/9530] Processing: 11877_monkey_jack_and_other_stories__by_variou.txt
# [2025-07-28 18:41:54,794] INFO: [257/9530] Processing: 11894_the_mahabharata_of_krishna_dwaipayana_vy.txt
# [2025-07-28 18:41:55,009] INFO: [258/9530] Processing: 11897_on_the_indian_sect_of_the_jainas__by_joh.txt
# [2025-07-28 18:41:55,061] INFO: [259/9530] Processing: 11898_seeing_europe_with_famous_authors__vol__.txt
# [2025-07-28 18:41:55,178] INFO: [260/9530] Processing: 11911_the_silent_isle__by_arthur_christopher_b.txt
# [2025-07-28 18:41:55,346] INFO: [261/9530] Processing: 11915_the_adventures_of_mr__mocker__by_thornto.txt
# [2025-07-28 18:41:55,406] INFO: [262/9530] Processing: 11930_more_fables__by_george_ade.txt
# [2025-07-28 18:41:55,463] INFO: [263/9530] Processing: 11934_primitive_love_and_love_stories__by_henr.txt
# [2025-07-28 18:41:55,945] INFO: [264/9530] Processing: 11935_mysticism_in_english_literature__by_caro.txt
# [2025-07-28 18:41:56,012] INFO: [265/9530] Processing: 11937_The symbolism of Freemasonry  $b Illustrating and explaining its science and philosophy, its legends.txt
# [2025-07-28 18:41:56,754] INFO: [266/9530] Processing: 11938_folklore_of_the_santal_parganas__by_ceci.txt
# [2025-07-28 18:41:56,953] INFO: [267/9530] Processing: 11945_essays_of_schopenhauer__by_arthur_schope.txt
# [2025-07-28 18:41:57,066] INFO: [268/9530] Processing: 11949_master_tales_of_mystery__volume_3__colle.txt
# [2025-07-28 18:41:57,323] INFO: [269/9530] Processing: 11977_chronicles_of_canada__vol__13_of_32__the.txt
# [2025-07-28 18:41:57,388] INFO: [270/9530] Processing: 11984_A Pluralistic Universe Hibbert Lectures at Manchester College on the Present Situation in Philosophy.txt
# [2025-07-28 18:41:57,501] INFO: [271/9530] Processing: 11987_by_advice_of_counsel__by_arthur_train.txt
# [2025-07-28 18:41:57,604] INFO: [272/9530] Processing: 11990_shakespeare_s_insomnia__and_the_causes_t.txt
# [2025-07-28 18:41:57,636] INFO: [273/9530] Processing: 12005_les_chants_de_maldoror__by_comte_de_laut.txt
# [2025-07-28 18:41:57,768] INFO: [274/9530] Processing: 12006_A Handbook to Agra and the Taj, Sikandra, Fatehpur-Sikri and the Neighbourhood.txt
# [2025-07-28 18:41:57,829] INFO: [275/9530] Processing: 12007_cousin_hatty_s_hymns_and_twilight_storie.txt
# [2025-07-28 18:41:57,864] INFO: [276/9530] Processing: 12016_The Merchant of Berlin An Historical Novel.txt
# [2025-07-28 18:41:58,092] INFO: [277/9530] Processing: 12016_the_merchant_of_berlin__by_l_muhlbach.txt
# [2025-07-28 18:41:58,320] INFO: [278/9530] Processing: 12028_The Uttermost Farthing A Savant's Vendetta.txt
# [2025-07-28 18:41:58,437] INFO: [279/9530] Processing: 12047_legends_of_the_madonna_as_represented_in.txt
# [2025-07-28 18:41:58,745] INFO: [280/9530] Processing: 12058_the_mahabharata_of_krishna_dwaipayana_vy.txt
# [2025-07-28 18:41:58,877] INFO: [281/9530] Processing: 12067_the_bee_man_of_orn_and_other_fanciful_ta.txt
# [2025-07-28 18:41:58,998] INFO: [282/9530] Processing: 12069_Joe Tilden's Recipes for Epicures.txt
# [2025-07-28 18:41:59,048] INFO: [283/9530] Processing: 12069_joe_tilden_s_recipes_for_epicures__by_jo.txt
# [2025-07-28 18:41:59,104] INFO: [284/9530] Processing: 12082_Color Images from Mars Rovers Spirit and Opportunity.txt
# [2025-07-28 18:41:59,141] INFO: [285/9530] Processing: 12086_eastern_shame_girl_and_others__by_charle.txt
# [2025-07-28 18:41:59,207] INFO: [286/9530] Processing: 12088_Composition-Rhetoric.txt
# [2025-07-28 18:41:59,416] INFO: [287/9530] Processing: 12094_o_henry_memorial_award_prize_stories_of_.txt
# [2025-07-28 18:41:59,557] INFO: [288/9530] Processing: 12096_Bushido, the Soul of Japan.txt
# [2025-07-28 18:41:59,637] INFO: [289/9530] Processing: 12096_bushido__the_soul_of_japan__by_inazo_nit.txt
# [2025-07-28 18:41:59,737] INFO: [290/9530] Processing: 1209_history_of_the_conquest_of_peru__by_will.txt
# [2025-07-28 18:42:00,094] INFO: [291/9530] Processing: 12103_the_tale_of_mrs__tiggy_winkle__by_beatri.txt
# [2025-07-28 18:42:00,120] INFO: [292/9530] Processing: 12106_Old Gorgon Graham More Letters from a Self-Made Merchant to His Son.txt
# [2025-07-28 18:42:00,199] INFO: [293/9530] Processing: 12116_struwwelpeter__merry_stories_and_funny_p.txt
# [2025-07-28 18:42:00,228] INFO: [294/9530] Processing: 12137_la_legende_des_siecles__by_victor_hugo.txt
# [2025-07-28 18:42:00,347] INFO: [295/9530] Processing: 12140_roman_farm_management__by_marcus_porcius.txt
# [2025-07-28 18:42:00,501] INFO: [296/9530] Processing: 12144_the_continental_classics__vol__18__myste.txt
# [2025-07-28 18:42:00,672] INFO: [297/9530] Processing: 12162_The Communes of Lombardy from the VI. to the X. Century An Investigation of the Causes Which Led to .txt
# [2025-07-28 18:42:00,726] INFO: [298/9530] Processing: 12186_The Principles of Masonic Law A Treatise on the Constitutional Laws, Usages and Landmarks of Freemas.txt
# [2025-07-28 18:42:01,403] INFO: [299/9530] Processing: 12190_the_adventures_of_captain_horn__by_frank.txt
# [2025-07-28 18:42:01,577] INFO: [300/9530] Processing: 1219_An Essay on Comedy and the Uses of the Comic Spirit.txt
# [2025-07-28 18:42:01,622] INFO: [301/9530] Processing: 12211_odd_craft__part_11__a_spirit_of_avarice_.txt
# [2025-07-28 18:42:01,654] INFO: [302/9530] Processing: 12218_pastoral_poetry_and_pastoral_drama__by_w.txt
# [2025-07-28 18:42:01,896] INFO: [303/9530] Processing: 12219_ancient_nahuatl_poetry__by_daniel_g__bri.txt
# [2025-07-28 18:42:01,978] INFO: [304/9530] Processing: 1221_A Preliminary Revision of the North American Species of Cactus, Anhalonium, and Lophophora.txt
# [2025-07-28 18:42:02,065] INFO: [305/9530] Processing: 12225_tales_of_lonely_trails__by_zane_grey.txt
# [2025-07-28 18:42:02,255] INFO: [306/9530] Processing: 12226_what_eight_million_women_want__by_rheta_.txt
# [2025-07-28 18:42:02,341] INFO: [307/9530] Processing: 12227_child_s_first_picture_book__by_anonymous.txt
# [2025-07-28 18:42:02,365] INFO: [308/9530] Processing: 12236_Death Valley in '49 Important chapter of California pioneer history. The autobiography of a pioneer,.txt
# [2025-07-28 18:42:02,586] INFO: [309/9530] Processing: 12250_contes_choisis_de_la_famille__by_les_fre.txt
# [2025-07-28 18:42:02,622] INFO: [310/9530] Processing: 12255_The Egyptian Conception of Immortality The Ingersoll Lecture, 1911.txt
# [2025-07-28 18:42:02,663] INFO: [311/9530] Processing: 12255_the_egyptian_conception_of_immortality__.txt
# [2025-07-28 18:42:02,710] INFO: [312/9530] Processing: 12261_Balder the Beautiful, Volume I. A Study in Magic and Religion the Golden Bough, Part VII., The; Fire.txt
# [2025-07-28 18:42:02,950] INFO: [313/9530] Processing: 12264_father_payne__by_arthur_christopher_bens.txt
# [2025-07-28 18:42:03,149] INFO: [314/9530] Processing: 12270_the_doomswoman__by_gertrude_franklin_hor.txt
# [2025-07-28 18:42:03,237] INFO: [315/9530] Processing: 12277_the_delectable_duchy__by_arthur_thomas_q.txt
# [2025-07-28 18:42:03,332] INFO: [316/9530] Processing: 12283_The Soul of a Child.txt
# [2025-07-28 18:42:03,441] INFO: [317/9530] Processing: 12283_the_soul_of_a_child__by_edwin_bjorkman.txt
# [2025-07-28 18:42:03,550] INFO: [318/9530] Processing: 12288_witchcraft_delusion_in_colonial_connecti.txt
# [2025-07-28 18:42:03,625] INFO: [319/9530] Processing: 12293_old_cookery_books_and_ancient_cuisine__b.txt
# [2025-07-28 18:42:03,704] INFO: [320/9530] Processing: 12303_Fated to Be Free A Novel.txt
# [2025-07-28 18:42:03,926] INFO: [321/9530] Processing: 12303_fated_to_be_free__by_jean_ingelow.txt
# [2025-07-28 18:42:04,210] INFO: [322/9530] Processing: 12309_love_affairs_of_the_courts_of_europe__by.txt
# [2025-07-28 18:42:04,368] INFO: [323/9530] Processing: 12313_pictures_of_sweden__by_hans_christian_an.txt
# [2025-07-28 18:42:04,446] INFO: [324/9530] Processing: 12315_shanty_the_blacksmith__a_tale_of_other_t.txt
# [2025-07-28 18:42:04,508] INFO: [325/9530] Processing: 12316_true_tilda__by_arthur_thomas_quiller_cou.txt
# [2025-07-28 18:42:04,650] INFO: [326/9530] Processing: 12320_Civilization and Beyond Learning from History.txt
# [2025-07-28 18:42:04,815] INFO: [327/9530] Processing: 12321_rudimental_divine_science__by_mary_baker.txt
# [2025-07-28 18:42:04,856] INFO: [328/9530] Processing: 12333_the_mahabharata_of_krishna_dwaipayana_vy.txt
# [2025-07-28 18:42:05,191] INFO: [329/9530] Processing: 12336_brown_wolf_and_other_jack_london_stories.txt
# [2025-07-28 18:42:05,321] INFO: [330/9530] Processing: 12343_The Art of Iugling or Legerdemaine Wherein is Deciphered All the Conueyances of Legerdemaine and Iug.txt
# [2025-07-28 18:42:05,369] INFO: [331/9530] Processing: 12345_Friday, the Thirteenth A Novel.txt
# [2025-07-28 18:42:05,455] INFO: [332/9530] Processing: 12346_a_roman_singer__by_f__marion_crawford.txt
# [2025-07-28 18:42:05,602] INFO: [333/9530] Processing: 12355_the_constitutional_development_of_japan_.txt
# [2025-07-28 18:42:05,648] INFO: [334/9530] Processing: 12364_The United States in the Light of Prophecy Or, an Exposition of Rev. 1311-17.txt
# [2025-07-28 18:42:05,717] INFO: [335/9530] Processing: 12364_the_united_states_in_the_light_of_prophe.txt
# [2025-07-28 18:42:05,790] INFO: [336/9530] Processing: 12369_library_of_the_world_s_best_literature__.txt
# [2025-07-28 18:42:06,082] INFO: [337/9530] Processing: 12370_bagh_o_bahar__or_tales_of_the_four_darwe.txt
# [2025-07-28 18:42:06,241] INFO: [338/9530] Processing: 12380_two_thousand_miles_on_an_automobile__by_.txt
# [2025-07-28 18:42:06,419] INFO: [339/9530] Processing: 12384_battle_pieces_and_aspects_of_the_war__by.txt
# [2025-07-28 18:42:06,499] INFO: [340/9530] Processing: 1239_the_spirit_of_the_border__by_zane_grey.txt
# [2025-07-28 18:42:06,661] INFO: [341/9530] Processing: 12404_seeing_europe_with_famous_authors__vol__.txt
# [2025-07-28 18:42:06,773] INFO: [342/9530] Processing: 12409_The Story of the Philippines Natural Riches, Industrial Resources, Statistics of Productions, Commer.txt
# [2025-07-28 18:42:07,071] INFO: [343/9530] Processing: 12417_fishin__jimmy__by_annie_trumbull_slosson.txt
# [2025-07-28 18:42:07,105] INFO: [344/9530] Processing: 12419_frontier_stories__by_bret_harte.txt
# [2025-07-28 18:42:07,341] INFO: [345/9530] Processing: 12444_toaster_s_handbook__compiled_by_peggy_ed.txt
# [2025-07-28 18:42:07,615] INFO: [346/9530] Processing: 12445_the_water_witch__or__the_skimmer_of_the_.txt
# [2025-07-28 18:42:07,869] INFO: [347/9530] Processing: 12454_France at War On the Frontier of Civilization.txt
# [2025-07-28 18:42:07,918] INFO: [348/9530] Processing: 12455_legends_of_the_middle_ages__by_h_a__guer.txt
# [2025-07-28 18:42:08,111] INFO: [349/9530] Processing: 12458_the_talisman__by_george_borrow.txt
# [2025-07-28 18:42:08,144] INFO: [350/9530] Processing: 12480_Clairvoyance and Occult Powers.txt
# [2025-07-28 18:42:08,273] INFO: [351/9530] Processing: 12481_hero_tales_of_the_far_north__by_jacob_a_.txt
# [2025-07-28 18:42:08,389] INFO: [352/9530] Processing: 12509_the_moon_rock__by_arthur_j__rees.txt
# [2025-07-28 18:42:08,548] INFO: [353/9530] Processing: 12518_the_adventures_of_a_forty_niner__by_dani.txt
# [2025-07-28 18:42:08,653] INFO: [354/9530] Processing: 12523_crusaders_of_new_france__a_chronicle_of_.txt
# [2025-07-28 18:42:08,788] INFO: [355/9530] Processing: 1253_A Simple Soul.txt
# [2025-07-28 18:42:08,920] INFO: [356/9530] Processing: 12545_Traditions of the Tinguian a Study in Philippine Folk-Lore.txt
# [2025-07-28 18:42:09,148] INFO: [357/9530] Processing: 12546_jumalainen_naeytelmae_i_iii__by_dante.txt
# [2025-07-28 18:42:09,486] INFO: [358/9530] Processing: 12547_jumalainen_naeytelmae__paratiisi__by_dan.txt
# [2025-07-28 18:42:09,609] INFO: [359/9530] Processing: 12555_the_tragedy_of_the_korosko__by_arthur_co.txt
# [2025-07-28 18:42:09,756] INFO: [360/9530] Processing: 12577_strange_true_stories_of_louisiana__by_ge.txt
# [2025-07-28 18:42:09,960] INFO: [361/9530] Processing: 12578_Shakespeare's play of the Merchant of Venice Arranged for Representation at the Princess's Theatre, .txt
# [2025-07-28 18:42:10,024] INFO: [362/9530] Processing: 12578_the_merchant_of_venice__by_william_shake.txt
# [2025-07-28 18:42:10,083] INFO: [363/9530] Processing: 12591_tiger_and_tom_and_other_stories_for_boys.txt
# [2025-07-28 18:42:10,177] INFO: [364/9530] Processing: 12592_J. S. Le Fanu's Ghostly Tales, Volume 5.txt
# [2025-07-28 18:42:10,245] INFO: [365/9530] Processing: 12592_j__s__le_fanu_s_ghostly_tales__volume_5.txt
# [2025-07-28 18:42:10,317] INFO: [366/9530] Processing: 12621_The Book of Dreams and Ghosts.txt
# [2025-07-28 18:42:10,468] INFO: [367/9530] Processing: 12621_the_book_of_dreams_and_ghosts__by_andrew.txt
# [2025-07-28 18:42:10,620] INFO: [368/9530] Processing: 12623_the_life_and_adventures_of_robinson_crus.txt
# [2025-07-28 18:42:11,068] INFO: [369/9530] Processing: 12630_the_adventures_of_old_mr__toad__by_thorn.txt
# [2025-07-28 18:42:11,122] INFO: [370/9530] Processing: 12632_yesterdays_with_authors__by_james_t__fie.txt
# [2025-07-28 18:42:11,382] INFO: [371/9530] Processing: 12638_Public Lands and Agrarian Laws of the Roman Republic.txt
# [2025-07-28 18:42:11,450] INFO: [372/9530] Processing: 12638_public_lands_and_agrarian_laws_of_the_ro.txt
# [2025-07-28 18:42:11,514] INFO: [373/9530] Processing: 12647_j__s__le_fanu_s_ghostly_tales__volume_4.txt
# [2025-07-28 18:42:11,586] INFO: [374/9530] Processing: 12649_analyzing_character__by_katherine_m__h__.txt
# [2025-07-28 18:42:11,827] INFO: [375/9530] Processing: 12651_the_humour_of_homer_and_other_essays__by.txt
# [2025-07-28 18:42:11,992] INFO: [376/9530] Processing: 12671_an_easter_disciple__by_arthur_benton_san.txt
# [2025-07-28 18:42:12,033] INFO: [377/9530] Processing: 12675_sketches_and_tales_illustrative_of_life_.txt
# [2025-07-28 18:42:12,113] INFO: [378/9530] Processing: 12680_children_of_the_ghetto__by_israel_zangwi.txt
# [2025-07-28 18:42:12,403] INFO: [379/9530] Processing: 1269_The soul of a bishop.txt
# [2025-07-28 18:42:12,563] INFO: [380/9530] Processing: 12732_short_stories__by_various.txt
# [2025-07-28 18:42:12,680] INFO: [381/9530] Processing: 12743_the_author_s_craft__by_arnold_bennett.txt
# [2025-07-28 18:42:12,733] INFO: [382/9530] Processing: 12753_the_legends_of_king_arthur_and_his_knigh.txt
# [2025-07-28 18:42:12,915] INFO: [383/9530] Processing: 12758_library_of_the_world_s_best_mystery_and_.txt
# [2025-07-28 18:42:13,080] INFO: [384/9530] Processing: 12763_Every Soul Hath Its Song.txt
# [2025-07-28 18:42:13,216] INFO: [385/9530] Processing: 12763_every_soul_hath_its_song__by_fannie_hurs.txt
# [2025-07-28 18:42:13,353] INFO: [386/9530] Processing: 12788_library_of_the_world_s_best_literature__.txt
# [2025-07-28 18:42:13,666] INFO: [387/9530] Processing: 12798_by_rock_and_pool_on_an_austral_shore__an.txt
# [2025-07-28 18:42:13,710] INFO: [388/9530] Processing: 12814_philippine_folk_tales__by_various.txt
# [2025-07-28 18:42:13,792] INFO: [389/9530] Processing: 12816_the_devil_s_pool__by_george_sand.txt
# [2025-07-28 18:42:13,870] INFO: [390/9530] Processing: 12827_The Rising of the Red Man A Romance of the Louis Riel Rebellion.txt
# [2025-07-28 18:42:14,005] INFO: [391/9530] Processing: 12828_two_ghostly_mysteries__by_joseph_sherida.txt
# [2025-07-28 18:42:14,074] INFO: [392/9530] Processing: 12833_what_dreams_may_come__by_gertrude_frankl.txt
# [2025-07-28 18:42:14,152] INFO: [393/9530] Processing: 12836_good_stories_from_the_ladies__home_journ.txt
# [2025-07-28 18:42:14,208] INFO: [394/9530] Processing: 12842_a_fairy_tale_in_two_acts__taken_from_sha.txt
# [2025-07-28 18:42:14,246] INFO: [395/9530] Processing: 12850_a_philological_essay_concerning_the_pygm.txt
# [2025-07-28 18:42:14,323] INFO: [396/9530] Processing: 12851_folk_tales_from_the_russian__by_various.txt
# [2025-07-28 18:42:14,372] INFO: [397/9530] Processing: 12852_Creation and Its Records A Brief Statement of Christian Belief with Reference to Modern Facts and An.txt
# [2025-07-28 18:42:14,470] INFO: [398/9530] Processing: 12852_creation_and_its_records__by_b__h__baden.txt
# [2025-07-28 18:42:14,571] INFO: [399/9530] Processing: 12859_ensign_knightley_and_other_stories__by_a.txt
# [2025-07-28 18:42:14,706] INFO: [400/9530] Processing: 12864_a_collection_of_college_words_and_custom.txt
# [2025-07-28 18:42:15,049] INFO: [401/9530] Processing: 12867_the_banquet__il_convito___by_dante_aligh.txt
# [2025-07-28 18:42:15,209] INFO: [402/9530] Processing: 12875_life_in_the_roman_world_of_nero_and_st__.txt
# [2025-07-28 18:42:15,374] INFO: [403/9530] Processing: 12882_Minstrelsy of the Scottish Border, Volume 2 (of 3) Consisting of Historical and Romantic Ballads, Co.txt
# [2025-07-28 18:42:15,501] INFO: [404/9530] Processing: 1288_Dream Days.txt
# [2025-07-28 18:42:15,595] INFO: [405/9530] Processing: 12890_Elizabethan Demonology An Essay in Illustration of the Belief in the Existence of Devils, and the Po.txt
# [2025-07-28 18:42:15,667] INFO: [406/9530] Processing: 12890_elizabethan_demonology__by_thomas_alfred.txt
# [2025-07-28 18:42:15,741] INFO: [407/9530] Processing: 12892_Simon Magus An Essay on the Founder of Simonianism Based on the Ancient Sources With a Re-Evaluation.txt
# [2025-07-28 18:42:15,806] INFO: [408/9530] Processing: 12894_sacred_books_of_the_east__by_various.txt
# [2025-07-28 18:42:16,078] INFO: [409/9530] Processing: 1289_Three Ghost Stories.txt
# [2025-07-28 18:42:16,122] INFO: [410/9530] Processing: 1289_three_ghost_stories__by_charles_dickens.txt
# [2025-07-28 18:42:16,169] INFO: [411/9530] Processing: 12909_romance_of_the_rabbit__by_francis_jammes.txt
# [2025-07-28 18:42:16,226] INFO: [412/9530] Processing: 12910_early_britain__roman_britain__by_edward_.txt
# [2025-07-28 18:42:16,350] INFO: [413/9530] Processing: 12915_the_white_devil__by_john_webster.txt
# [2025-07-28 18:42:16,404] INFO: [414/9530] Processing: 12920_the_goldfish___by_arthur_train.txt
# [2025-07-28 18:42:16,497] INFO: [415/9530] Processing: 12923_the_laird_s_luck_and_other_fireside_tale.txt
# [2025-07-28 18:42:16,615] INFO: [416/9530] Processing: 12931_the_daredevil__by_maria_thompson_daviess.txt
# [2025-07-28 18:42:16,708] INFO: [417/9530] Processing: 12932_four_max_carrados_detective_stories__by_.txt
# [2025-07-28 18:42:16,777] INFO: [418/9530] Processing: 12933_Little Journeys to the Homes of the Great - Volume 01 Little Journeys to the Homes of Good Men and G.txt
# [2025-07-28 18:42:16,879] INFO: [419/9530] Processing: 12956_A History of Indian Philosophy, Volume 1.txt
# [2025-07-28 18:42:17,185] INFO: [420/9530] Processing: 12959_newton_forster__or_the_merchant_service_.txt
# [2025-07-28 18:42:17,374] INFO: [421/9530] Processing: 12967_memoirs_and_historical_chronicles_of_the.txt
# [2025-07-28 18:42:17,528] INFO: [422/9530] Processing: 12983_rescuing_the_czar__by_james_p__smythe.txt
# [2025-07-28 18:42:17,615] INFO: [423/9530] Processing: 12986_the_card__a_story_of_adventure_in_the_fi.txt
# [2025-07-28 18:42:17,711] INFO: [424/9530] Processing: 12991_the_uncrowned_king__by_harold_bell_wrigh.txt
# [2025-07-28 18:42:17,742] INFO: [425/9530] Processing: 12995_the_matador_of_the_five_towns_and_other_.txt
# [2025-07-28 18:42:17,874] INFO: [426/9530] Processing: 13015_tales_of_old_japan__by_algernon_bertram_.txt
# [2025-07-28 18:42:18,062] INFO: [427/9530] Processing: 13028_library_of_the_world_s_best_literature__.txt
# [2025-07-28 18:42:18,318] INFO: [428/9530] Processing: 13051_sketches_of_japanese_manners_and_customs.txt
# [2025-07-28 18:42:18,363] INFO: [429/9530] Processing: 13059_le_cap_au_diable__legende_canadienne__by.txt
# [2025-07-28 18:42:18,404] INFO: [430/9530] Processing: 13060_persian_literature__volume_2__comprising.txt
# [2025-07-28 18:42:18,473] INFO: [431/9530] Processing: 1307_The Magic Skin.txt
# [2025-07-28 18:42:18,635] INFO: [432/9530] Processing: 13096_le_heros_de_chateauguay__by_laurent_oliv.txt
# [2025-07-28 18:42:18,675] INFO: [433/9530] Processing: 1309_the_spirit_of_place__and_other_essays__b.txt
# [2025-07-28 18:42:18,722] INFO: [434/9530] Processing: 13122_trois_heros_de_la_colonie_de_montreal__b.txt
# [2025-07-28 18:42:18,757] INFO: [435/9530] Processing: 13125_deer_godchild__by_marguerite_bernard_and.txt
# [2025-07-28 18:42:18,797] INFO: [436/9530] Processing: 13126_the_king_s_daughter_and_other_stories_fo.txt
# [2025-07-28 18:42:18,866] INFO: [437/9530] Processing: 13137_the_secret_of_dreams__by_yacki_raizizun.txt
# [2025-07-28 18:42:18,896] INFO: [438/9530] Processing: 13138_the_forgotten_threshold__by_arthur_middl.txt
# [2025-07-28 18:42:18,928] INFO: [439/9530] Processing: 13143_mystic_christianity__by_yogi_ramacharaka.txt
# [2025-07-28 18:42:19,034] INFO: [440/9530] Processing: 13152_the_firm_of_girdlestone__by_arthur_conan.txt
# [2025-07-28 18:42:19,212] INFO: [441/9530] Processing: 13164_murtovarkaus__roinilan_talossa__by_minna.txt
# [2025-07-28 18:42:19,288] INFO: [442/9530] Processing: 13165_papin_perhe__han_on_sysmasta__spiritisti.txt
# [2025-07-28 18:42:19,366] INFO: [443/9530] Processing: 13172_true_stories_of_crime_from_the_district_.txt
# ...
# [2025-07-28 19:03:40,394] INFO: [9353/9530] Processing: Keep Your Shape.txt
# [2025-07-28 19:03:40,430] INFO: [9354/9530] Processing: Key Out of Time.txt
# [2025-07-28 19:03:40,571] INFO: [9355/9530] Processing: Korean folk tales.txt
# [2025-07-28 19:03:40,722] INFO: [9356/9530] Processing: Krishna-Dwaipayana Vyasa Translated into English Prose.txt
# [2025-07-28 19:03:41,032] INFO: [9357/9530] Processing: Krishna-Dwaipayana Vyasa, Volume 1.txt
# [2025-07-28 19:03:42,172] INFO: [9358/9530] Processing: L'île mystérieuse.txt
# [2025-07-28 19:03:42,698] INFO: [9359/9530] Processing: Legends & Romances of Brittany.txt
# [2025-07-28 19:03:42,996] INFO: [9360/9530] Processing: Little Brother.txt
# [2025-07-28 19:03:43,328] INFO: [9361/9530] Processing: Longevity.txt
# [2025-07-28 19:03:43,381] INFO: [9362/9530] Processing: Magic.txt
# [2025-07-28 19:03:43,412] INFO: [9363/9530] Processing: Manuscript of the Thirteenth Century.txt
# [2025-07-28 19:03:43,647] INFO: [9364/9530] Processing: Masters of Space.txt
# [2025-07-28 19:03:43,681] INFO: [9365/9530] Processing: Matter of Proportion.txt
# [2025-07-28 19:03:43,721] INFO: [9366/9530] Processing: Ministry of Disturbance.txt
# [2025-07-28 19:03:43,793] INFO: [9367/9530] Processing: My Fair Planet.txt
# [2025-07-28 19:03:43,844] INFO: [9368/9530] Processing: Myths & Legends of Japan.txt
# [2025-07-28 19:03:44,108] INFO: [9369/9530] Processing: Myths and Legends of China.txt
# [2025-07-28 19:03:44,150] INFO: [9370/9530] Processing: Myths of Babylonia and Assyria.txt
# [2025-07-28 19:03:44,568] INFO: [9371/9530] Processing: Myths of the Cherokee.txt
# [2025-07-28 19:03:45,141] INFO: [9372/9530] Processing: n Old Babylonian Version of the Gilgamesh Epic.txt
# [2025-07-28 19:03:45,165] INFO: [9373/9530] Processing: Native Son.txt
# [2025-07-28 19:03:45,199] INFO: [9374/9530] Processing: Occasion ... for Disaster.txt
# [2025-07-28 19:03:45,336] INFO: [9375/9530] Processing: Oedipus the King; Oedipus at Colonus; Antigone.txt
# [2025-07-28 19:03:45,446] INFO: [9376/9530] Processing: Off on a Comet! a Journey through Planetary Space.txt
# [2025-07-28 19:03:45,672] INFO: [9377/9530] Processing: Old Greek Stories.txt
# [2025-07-28 19:03:45,765] INFO: [9378/9530] Processing: Old Mr. Wiley.txt
# [2025-07-28 19:03:45,800] INFO: [9379/9530] Processing: Omens and Superstitions of Southern India.txt
# [2025-07-28 19:03:45,962] INFO: [9380/9530] Processing: Omnilingual.txt
# [2025-07-28 19:03:46,009] INFO: [9381/9530] Processing: One Man's Poison.txt
# [2025-07-28 19:03:46,040] INFO: [9382/9530] Processing: Out of the Dark Nebula.txt
# [2025-07-28 19:03:46,079] INFO: [9383/9530] Processing: Pele and HiiakaA Myth From Hawaii.txt
# [2025-07-28 19:03:46,233] INFO: [9384/9530] Processing: percy_jackson_book_1.txt
# [2025-07-28 19:03:46,447] INFO: [9385/9530] Processing: percy_jackson_book_2.txt
# [2025-07-28 19:03:46,928] INFO: [9386/9530] Processing: percy_jackson_book_3.txt
# [2025-07-28 19:03:47,162] INFO: [9387/9530] Processing: percy_jackson_book_4.txt
# [2025-07-28 19:03:47,323] INFO: [9388/9530] Processing: percy_jackson_book_5.txt
# [2025-07-28 19:03:47,634] INFO: [9389/9530] Processing: Peter Pan.txt
# [2025-07-28 19:03:47,731] INFO: [9390/9530] Processing: Philippine Folk Tales.txt
# [2025-07-28 19:03:47,824] INFO: [9391/9530] Processing: Philippine Folk-Lore.txt
# [2025-07-28 19:03:47,847] INFO: [9392/9530] Processing: Plague Ship.txt
# [2025-07-28 19:03:47,874] INFO: [9393/9530] Processing: Plutarch Lives of the noble Grecians and Romans.txt
# [2025-07-28 19:03:48,186] INFO: [9394/9530] Processing: Prometheus Bound and the Seven Against Thebes.txt
# [2025-07-28 19:03:48,256] INFO: [9395/9530] Processing: Pygmalion's Spectacles.txt
# [2025-07-28 19:03:48,299] INFO: [9396/9530] Processing: R.U.R. (Rossum's Universal Robots).txt
# [2025-07-28 19:03:48,393] INFO: [9397/9530] Processing: Ramayan.txt
# [2025-07-28 19:03:49,070] INFO: [9398/9530] Processing: Red Nails.txt
# [2025-07-28 19:03:49,126] INFO: [9399/9530] Processing: Rip Van Winkle.txt
# [2025-07-28 19:03:49,159] INFO: [9400/9530] Processing: sample_verified.txt
# [2025-07-28 19:03:49,162] ERROR: ❌ Error processing sample_verified.txt: File exceeds size limit (10MB)
# [2025-07-28 19:03:49,164] INFO: [9401/9530] Processing: Second Variety.txt
# [2025-07-28 19:03:49,211] INFO: [9402/9530] Processing: Shadows in the Moonlight.txt
# [2025-07-28 19:03:49,239] INFO: [9403/9530] Processing: Skylark Three.txt
# [2025-07-28 19:03:49,260] INFO: [9404/9530] Processing: South-African Folk-Tales.txt
# [2025-07-28 19:03:49,313] INFO: [9405/9530] Processing: Space Station 1.txt
# [2025-07-28 19:03:49,402] INFO: [9406/9530] Processing: Star Born.txt
# [2025-07-28 19:03:49,522] INFO: [9407/9530] Processing: Star Hunter.txt
# [2025-07-28 19:03:49,629] INFO: [9408/9530] Processing: START OF THE PROJECT GUTENBERG EBO.txt
# [2025-07-28 19:03:49,772] INFO: [9409/9530] Processing: Stories and Studies of Strange Things.txt
# [2025-07-28 19:03:49,865] INFO: [9410/9530] Processing: Stories of Enchantment.txt
# [2025-07-28 19:03:49,886] INFO: [9411/9530] Processing: Stories of Super-Science February 1930.txt
# [2025-07-28 19:03:50,056] INFO: [9412/9530] Processing: Storm Over Warlock.txt
# [2025-07-28 19:03:50,079] INFO: [9413/9530] Processing: Supermind.txt
# [2025-07-28 19:03:50,199] INFO: [9414/9530] Processing: Tales From Jókai.txt
# [2025-07-28 19:03:50,361] INFO: [9415/9530] Processing: Tales of Old Japan.txt
# [2025-07-28 19:03:50,596] INFO: [9416/9530] Processing: Tales of Space and Time.txt
# [2025-07-28 19:03:50,718] INFO: [9417/9530] Processing: Tales of the Sun; or, Folklore of Southern India.txt
# [2025-07-28 19:03:50,819] INFO: [9418/9530] Processing: Tarrano the Conqueror.txt
# [2025-07-28 19:03:50,918] INFO: [9419/9530] Processing: test.txt
# [2025-07-28 19:03:50,998] INFO: [9420/9530] Processing: The Agamemnon of Aeschylus.txt
# [2025-07-28 19:03:51,042] INFO: [9421/9530] Processing: The Age of Fable.txt
# [2025-07-28 19:03:51,233] INFO: [9422/9530] Processing: The Arabian Nights Their Best-known Tales.txt
# [2025-07-28 19:03:51,534] INFO: [9423/9530] Processing: The Ballad of the White Horse.txt
# [2025-07-28 19:03:51,582] INFO: [9424/9530] Processing: The Bible, King James Version, Complete.txt
# [2025-07-28 19:03:52,173] INFO: [9425/9530] Processing: The Birth of the War-God A Poem by Kálidása.txt
# [2025-07-28 19:03:52,198] INFO: [9426/9530] Processing: The Blue Bird A Fairy Play in Six Acts.txt
# [2025-07-28 19:03:52,269] INFO: [9427/9530] Processing: The Chessmen of Mars.txt
# [2025-07-28 19:03:52,432] INFO: [9428/9530] Processing: The Children of Odin The Book of Northern Myths.txt
# [2025-07-28 19:03:52,547] INFO: [9429/9530] Processing: The Chinese Fairy Book.txt
# [2025-07-28 19:03:52,807] INFO: [9430/9530] Processing: The Colors of Space.txt
# [2025-07-28 19:03:52,928] INFO: [9431/9530] Processing: The Country of the Blind, and Other Stories.txt
# [2025-07-28 19:03:53,279] INFO: [9432/9530] Processing: The Danish History, Books I-IX.txt
# [2025-07-28 19:03:53,594] INFO: [9433/9530] Processing: The Dark Door.txt
# [2025-07-28 19:03:53,644] INFO: [9434/9530] Processing: The Dark Goddess.txt
# [2025-07-28 19:03:53,694] INFO: [9435/9530] Processing: The Dark Other.txt
# [2025-07-28 19:03:53,818] INFO: [9436/9530] Processing: The Defiant Agents.txt
# [2025-07-28 19:03:53,934] INFO: [9437/9530] Processing: The Doomsman.txt
# [2025-07-28 19:03:54,082] INFO: [9438/9530] Processing: The Door in the Wall, and Other Stories.txt
# [2025-07-28 19:03:54,186] INFO: [9439/9530] Processing: The Doorway.txt
# [2025-07-28 19:03:54,223] INFO: [9440/9530] Processing: The Dunwich Horror.txt
# [2025-07-28 19:03:54,242] INFO: [9441/9530] Processing: The Egyptian Book of the dead.txt
# [2025-07-28 19:03:54,471] INFO: [9442/9530] Processing: The Eyes Have It.txt
# [2025-07-28 19:03:54,502] INFO: [9443/9530] Processing: The fire of Asshurbanipal.txt
# [2025-07-28 19:03:54,547] INFO: [9444/9530] Processing: The Folk-Tales of the Magyars.txt
# [2025-07-28 19:03:54,931] INFO: [9445/9530] Processing: The Glory of Ippling.txt
# [2025-07-28 19:03:54,985] INFO: [9446/9530] Processing: The Gods of Mars.txt
# [2025-07-28 19:03:55,151] INFO: [9447/9530] Processing: The Golden Maiden, and other folk tales and fairy stories told in Armenia.txt
# [2025-07-28 19:03:55,272] INFO: [9448/9530] Processing: The Hanging Stranger.txt
# [2025-07-28 19:03:55,322] INFO: [9449/9530] Processing: The haunter of the dark.txt
# [2025-07-28 19:03:55,373] INFO: [9450/9530] Processing: The Holes Around Mars.txt
# [2025-07-28 19:03:55,428] INFO: [9451/9530] Processing: The Hour of the Dragon.txt
# [2025-07-28 19:03:55,472] INFO: [9452/9530] Processing: The House of the Wolfings.txt
# [2025-07-28 19:03:55,612] INFO: [9453/9530] Processing: The House on the Borderland.txt
# [2025-07-28 19:03:55,749] INFO: [9454/9530] Processing: The Hyborian Age.txt
# [2025-07-28 19:03:55,779] INFO: [9455/9530] Processing: The Invisible Man A Grotesque Romance.txt
# [2025-07-28 19:03:55,898] INFO: [9456/9530] Processing: The island of Doctor Moreau.txt
# [2025-07-28 19:03:55,999] INFO: [9457/9530] Processing: The Kama Sutra of Vatsyayana.txt
# [2025-07-28 19:03:56,152] INFO: [9458/9530] Processing: The King in Yellow.txt
# [2025-07-28 19:03:56,319] INFO: [9459/9530] Processing: The Land That Time Forgot.txt
# [2025-07-28 19:03:56,404] INFO: [9460/9530] Processing: The Lani People.txt
# [2025-07-28 19:03:56,524] INFO: [9461/9530] Processing: The Legends and Myths of Hawaii.txt
# [2025-07-28 19:03:56,931] INFO: [9462/9530] Processing: The Legends of King Arthur and His Knights.txt
# [2025-07-28 19:03:57,118] INFO: [9463/9530] Processing: The Literature of the Ancient Egyptians.txt
# [2025-07-28 19:03:57,335] INFO: [9464/9530] Processing: The Lost Continent.txt
# [2025-07-28 19:03:57,416] INFO: [9465/9530] Processing: The Lost World.txt
# [2025-07-28 19:03:57,553] INFO: [9466/9530] Processing: The Mahabharata of Krishna-Dwaipayana Vyasa, Volume 1.txt
# [2025-07-28 19:03:57,587] INFO: [9467/9530] Processing: The Mahabharata of Krishna-Dwaipayana Vyasa, Volume 2.txt
# [2025-07-28 19:03:58,905] INFO: [9468/9530] Processing: The Mahabharata of Krishna-Dwaipayana Vyasa, Volume 3.txt
# [2025-07-28 19:04:00,731] INFO: [9469/9530] Processing: The Mahabharata of Krishna-Dwaipayana Vyasa, Volume 4.txt
# [2025-07-28 19:04:01,459] INFO: [9470/9530] Processing: The Man from Time.txt
# [2025-07-28 19:04:01,510] INFO: [9471/9530] Processing: The Man the Martians Made.txt
# [2025-07-28 19:04:01,553] INFO: [9472/9530] Processing: The Man Who Was Thursday A Nightmare.txt
# [2025-07-28 19:04:01,670] INFO: [9473/9530] Processing: The Marching Morons.txt
# [2025-07-28 19:04:01,716] INFO: [9474/9530] Processing: The Merry Adventures of Robin Hood.txt
# [2025-07-28 19:04:01,748] INFO: [9475/9530] Processing: The Metamorphoses of Ovid.txt
# [2025-07-28 19:04:02,022] INFO: [9476/9530] Processing: The miniature menace.txt
# [2025-07-28 19:04:02,086] INFO: [9477/9530] Processing: The Misplaced Battleship.txt
# [2025-07-28 19:04:02,145] INFO: [9478/9530] Processing: The Most Sentimental Man.txt
# [2025-07-28 19:04:02,182] INFO: [9479/9530] Processing: The Mysterious Island.txt
# [2025-07-28 19:04:02,539] INFO: [9480/9530] Processing: The Night Land.txt
# [2025-07-28 19:04:02,874] INFO: [9481/9530] Processing: The Night of the Long Knives.txt
# [2025-07-28 19:04:02,959] INFO: [9482/9530] Processing: The Orkneyinga Saga.txt
# [2025-07-28 19:04:03,227] INFO: [9483/9530] Processing: The People of the Black Circle.txt
# [2025-07-28 19:04:03,262] INFO: [9484/9530] Processing: The Piebald Hippogriff.txt
# [2025-07-28 19:04:03,313] INFO: [9485/9530] Processing: The Planet Savers.txt
# [2025-07-28 19:04:03,399] INFO: [9486/9530] Processing: The Putnam Tradition.txt
# [2025-07-28 19:04:03,433] INFO: [9487/9530] Processing: The Skull.txt
# [2025-07-28 19:04:03,481] INFO: [9488/9530] Processing: The Sky Trap.txt
# [2025-07-28 19:04:03,533] INFO: [9489/9530] Processing: The Slayer of Souls.txt
# [2025-07-28 19:04:03,669] INFO: [9490/9530] Processing: The Sorrows of Satan.txt
# [2025-07-28 19:04:03,909] INFO: [9491/9530] Processing: The Sound of Silence.txt
# [2025-07-28 19:04:03,942] INFO: [9492/9530] Processing: The Stolen Bacillus and Other Incidents.txt
# [2025-07-28 19:04:04,042] INFO: [9493/9530] Processing: The Story of the Three Little Pigs.txt
# [2025-07-28 19:04:04,075] INFO: [9494/9530] Processing: The Tempest.txt
# [2025-07-28 19:04:04,146] INFO: [9495/9530] Processing: The Three Impostors; or, The Transmutations.txt
# [2025-07-28 19:04:04,252] INFO: [9496/9530] Processing: The Time Machine.txt
# [2025-07-28 19:04:04,326] INFO: [9497/9530] Processing: The Time Traders.txt
# [2025-07-28 19:04:04,522] INFO: [9498/9530] Processing: The Undersea Tube.txt
# [2025-07-28 19:04:04,574] INFO: [9499/9530] Processing: The Vampyre; a Tale.txt
# [2025-07-28 19:04:04,645] INFO: [9500/9530] Processing: The Variable Man.txt
# [2025-07-28 19:04:04,726] INFO: [9501/9530] Processing: The Vibration Wasps.txt
# [2025-07-28 19:04:04,767] INFO: [9502/9530] Processing: The Vilbar Party.txt
# [2025-07-28 19:04:04,808] INFO: [9503/9530] Processing: The Violet Fairy Book.txt
# [2025-07-28 19:04:05,012] INFO: [9504/9530] Processing: The Vortex Blaster.txt
# [2025-07-28 19:04:05,041] INFO: [9505/9530] Processing: The War of the Worlds.txt
# [2025-07-28 19:04:05,072] INFO: [9506/9530] Processing: The warlord of Mars.txt
# [2025-07-28 19:04:05,099] INFO: [9507/9530] Processing: The Wendigo.txt
# [2025-07-28 19:04:05,162] INFO: [9508/9530] Processing: The Wind in the Willows.txt
# [2025-07-28 19:04:05,292] INFO: [9509/9530] Processing: The Wonderful Wizard of Oz.txt
# [2025-07-28 19:04:05,386] INFO: [9510/9530] Processing: The Works of Edgar Allan Poe — Volume 1.txt
# [2025-07-28 19:04:05,580] INFO: [9511/9530] Processing: The Works of Edgar Allan Poe — Volume 2.txt
# [2025-07-28 19:04:05,832] INFO: [9512/9530] Processing: The Works of Edgar Allan Poe, The Raven Edition.txt
# [2025-07-28 19:04:06,597] INFO: [9513/9530] Processing: The World Set Free.txt
# [2025-07-28 19:04:06,766] INFO: [9514/9530] Processing: Thin Edge.txt
# [2025-07-28 19:04:06,820] INFO: [9515/9530] Processing: Through the Looking-Glass.txt
# [2025-07-28 19:04:06,907] INFO: [9516/9530] Processing: Thuvia, Maid of Mars.txt
# [2025-07-28 19:04:07,004] INFO: [9517/9530] Processing: Time Crime.txt
# [2025-07-28 19:04:07,078] INFO: [9518/9530] Processing: train.txt
# [2025-07-28 19:04:07,455] INFO: [9519/9530] Processing: Translations of Shakuntala and Other Works.txt
# [2025-07-28 19:04:07,581] INFO: [9520/9530] Processing: Triplanetary.txt
# [2025-07-28 19:04:07,616] INFO: [9521/9530] Processing: Twelve Stories and a Dream.txt
# [2025-07-28 19:04:07,819] INFO: [9522/9530] Processing: Twenty Thousand Leagues under the Sea.txt
# [2025-07-28 19:04:08,036] INFO: [9523/9530] Processing: Twenty Thousand Leagues Under the Seas An Underwater Tour of the World.txt
# [2025-07-28 19:04:08,327] INFO: [9524/9530] Processing: Ultima Thule.txt
# [2025-07-28 19:04:08,398] INFO: [9525/9530] Processing: Upanishads.txt
# [2025-07-28 19:04:08,470] INFO: [9526/9530] Processing: val.txt
# [2025-07-28 19:04:08,571] INFO: [9527/9530] Processing: Vikram and the VampireClassic Hindu Tales of Adventure, Magic, and Romance.txt
# [2025-07-28 19:04:08,774] INFO: [9528/9530] Processing: With the Night Mail A Story of 2000 A.D..txt
# [2025-07-28 19:04:08,850] INFO: [9529/9530] Processing: Wizard.txt
# [2025-07-28 19:04:08,904] INFO: [9530/9530] Processing: Year of the Big Thaw.txt
# [2025-07-28 19:04:08,953] INFO:
# 📊 Generating final reports...
# [2025-07-28 19:04:09,085] INFO:
# ✅ Phase 1 Cleaning Complete
# [2025-07-28 19:04:09,088] INFO: 📂 Total Files Scanned: 9530
# [2025-07-28 19:04:09,091] INFO: ✅ Successfully Processed: 9492
# [2025-07-28 19:04:09,093] INFO: 🚫 Duplicates Skipped: 32
# [2025-07-28 19:04:09,097] INFO: ❗ Errors Encountered: 6
# [2025-07-28 19:04:09,100] INFO: 📄 Detailed report saved to: C:\Users\ayush\OneDrive\Desktop\Stories\cleaned_files\cleaning_phase_log\cleaning_report.csv
# [2025-07-28 19:04:09,103] INFO: 📓 Duplicates log saved to: C:\Users\ayush\OneDrive\Desktop\Stories\cleaned_files\cleaning_phase_log\duplicates_log.txt

# %%
import os
import logging
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.cluster import MiniBatchKMeans
from sklearn.decomposition import TruncatedSVD
import re
import shutil
import gc
import time
from contextlib import suppress
from concurrent.futures import ThreadPoolExecutor, as_completed

# ====== CONFIG ======
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

BASE_DIR = Path(r"C:/Users/ayush/OneDrive/Desktop/Stories")
CLEANED_DIR = BASE_DIR / "cleaned_files"
SPLIT_DIR = BASE_DIR / "split"
TRAIN_DIR = SPLIT_DIR / "train"
VAL_DIR = SPLIT_DIR / "val"
REJECTED_DIR = SPLIT_DIR / "rejected"
LOG_DIR = SPLIT_DIR / "split_logs"

for d in [TRAIN_DIR, VAL_DIR, REJECTED_DIR, LOG_DIR]:
    d.mkdir(parents=True, exist_ok=True)

logging.basicConfig(
    level=logging.INFO,
    format='[%(asctime)s] %(levelname)s: %(message)s',
    handlers=[
        logging.FileHandler(LOG_DIR / "split_pipeline.log", mode='w', encoding='utf-8'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger()

# ====== CONSTANTS & PATTERNS ======
DOC_PATTERN = re.compile(r'\[DOC_START\](.*?)\[DOC_END\]', re.DOTALL)
TOKEN_PATTERN = re.compile(r'\b\w{2,}\b')
MIN_TOKENS = 5

# ====== UTILS ======
def copy_task(src, dest):
    try:
        shutil.copy(src, dest)
        return True, src.name, None
    except Exception as e:
        return False, src.name, str(e)

def parallel_copy(file_paths, target_dir, max_workers=8):
    logger.info(f"🛠️ Copying {len(file_paths)} files to {target_dir.name}")
    start_time = time.time()
    tasks = [(src, target_dir / src.name) for src in file_paths]

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(copy_task, src, dest) for src, dest in tasks]
        success_count = 0
        for future in as_completed(futures):
            try:
                success, filename, error = future.result()
                if success:
                    success_count += 1
                else:
                    logger.error(f"❌ Failed: {filename} - {error}")
                    reject_path = REJECTED_DIR / filename
                    with suppress(Exception):
                        shutil.copy(CLEANED_DIR / filename, reject_path)
            except Exception as e:
                logger.exception(f"🔥 Unhandled future exception: {str(e)}")

    elapsed = time.time() - start_time
    logger.info(f"📆 Copied {success_count}/{len(file_paths)} files in {elapsed:.2f}s")
    return success_count

def process_file(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            file_content = f.read()
            match = DOC_PATTERN.search(file_content)
            if not match:
                return None, file_path, 'missing_DOC_TAG'
            content = match.group(1)
            tokens = TOKEN_PATTERN.findall(content)
            if len(tokens) < MIN_TOKENS:
                return None, file_path, 'low_token_count'
            return ' '.join(tokens), file_path, len(tokens)
    except Exception as e:
        return None, file_path, str(e)

# ====== MAIN ======
def main():
    global_start = time.time()
    logger.info("🚀 Starting hyper-optimized document processing pipeline")

    logger.info("🔍 Scanning and preprocessing files...")
    start_scan = time.time()
    files = list(CLEANED_DIR.glob("*_clean.txt"))
    logger.info(f"📂 Found {len(files)} files")

    valid_texts = []
    valid_paths = []
    token_counts = []
    rejected_paths = []
    low_token_count = 0
    error_count = 0
    missing_tag_count = 0

    with ThreadPoolExecutor(max_workers=os.cpu_count() * 2) as executor:
        futures = {executor.submit(process_file, f): f for f in files}
        for i, future in enumerate(as_completed(futures)):
            try:
                text, file_path, result = future.result()
            except Exception as e:
                logger.error(f"🔥 Crash in file: {futures[future].name} | Exception: {str(e)}")
                rejected_paths.append(futures[future])
                error_count += 1
                continue

            if text is None:
                rejected_paths.append(file_path)
                if result == 'low_token_count':
                    low_token_count += 1
                elif result == 'missing_DOC_TAG':
                    missing_tag_count += 1
                else:
                    error_count += 1
                    logger.debug(f"🚨 Error in {file_path.name}: {result}")
            else:
                valid_texts.append(text)
                valid_paths.append(file_path)
                token_counts.append(result)

            if (i + 1) % 1000 == 0:
                logger.info(f"⏱️ Processed {i+1}/{len(files)} files")

    if rejected_paths:
        parallel_copy(rejected_paths, REJECTED_DIR)

    scan_time = time.time() - start_scan
    logger.info(f"✅ Preprocessing complete: Valid={len(valid_texts)} | Rejected={len(rejected_paths)} (low tokens={low_token_count}, missing tags={missing_tag_count}, other errors={error_count}) in {scan_time:.2f}s")

    if not valid_texts:
        logger.warning("🛑 No valid documents found. Exiting early.")
        return

    logger.info("⚡ Vectorizing text data...")
    start_vec = time.time()
    vectorizer = HashingVectorizer(
        n_features=2**16,
        ngram_range=(1, 2),
        alternate_sign=False,
        norm=None,
        dtype=np.float32
    )
    X = vectorizer.transform(valid_texts)
    del valid_texts
    gc.collect()

    logger.info("🌀 Performing dimensionality reduction...")
    svd = TruncatedSVD(n_components=48, algorithm='arpack', random_state=RANDOM_SEED)
    X_reduced = svd.fit_transform(X)
    logger.info(f"⭐ Explained variance: {svd.explained_variance_ratio_.sum():.4f}")
    del X
    gc.collect()

    vec_time = time.time() - start_vec
    logger.info(f"📊 Vectorized {X_reduced.shape[0]} docs in {vec_time:.2f}s")

    logger.info("🧩 Clustering documents...")
    start_cluster = time.time()
    n_clusters = min(50, max(8, len(valid_paths) // 100))
    kmeans = MiniBatchKMeans(
        n_clusters=n_clusters,
        batch_size=4096,
        compute_labels=True,
        random_state=RANDOM_SEED,
        n_init='auto'
    )
    labels = kmeans.fit_predict(X_reduced)
    del X_reduced
    gc.collect()

    cluster_time = time.time() - start_cluster
    logger.info(f"🏷️ Clustered {len(valid_paths)} docs in {cluster_time:.2f}s")

    logger.info("✂️ Performing stratified split...")
    df = pd.DataFrame({
        'path': valid_paths,
        'cluster': labels,
        'token_count': token_counts
    })

    train_paths = []
    val_paths = []
    for cluster_id in range(n_clusters):
        cluster_df = df[df['cluster'] == cluster_id]
        if len(cluster_df) <= 1:
            train_paths.extend(cluster_df['path'].tolist())
            continue
        cluster_df = cluster_df.sample(frac=1, random_state=RANDOM_SEED)
        split_idx = int(len(cluster_df) * 0.9)
        train_paths.extend(cluster_df.iloc[:split_idx]['path'].tolist())
        val_paths.extend(cluster_df.iloc[split_idx:]['path'].tolist())

    logger.info(f"✅ Split complete: Train={len(train_paths)} | Val={len(val_paths)}")
    del df, labels
    gc.collect()

    parallel_copy(train_paths, TRAIN_DIR)
    parallel_copy(val_paths, VAL_DIR)

    total_time = time.time() - global_start
    logger.info(f"🎉 Total processing time: {total_time:.2f}s")
    logger.info(f"📊 Final counts: Train={len(train_paths)}, Val={len(val_paths)}, Rejected={len(rejected_paths)}")

if __name__ == "__main__":
    main()
# Out:
# [2025-07-29 00:11:41,998] INFO: 🚀 Starting hyper-optimized document processing pipeline
# [2025-07-29 00:11:41,999] INFO: 🔍 Scanning and preprocessing files...
# [2025-07-29 00:11:42,058] INFO: 📂 Found 8644 files
# [2025-07-29 00:13:55,990] INFO: ⏱️ Processed 1000/8644 files
# [2025-07-29 00:13:56,271] INFO: ⏱️ Processed 2000/8644 files
# [2025-07-29 00:13:57,154] INFO: ⏱️ Processed 3000/8644 files
# [2025-07-29 00:13:57,664] INFO: ⏱️ Processed 4000/8644 files
# [2025-07-29 00:14:06,719] INFO: ⏱️ Processed 5000/8644 files
# [2025-07-29 00:14:35,619] INFO: ⏱️ Processed 6000/8644 files
# [2025-07-29 00:15:05,576] INFO: ⏱️ Processed 7000/8644 files
# [2025-07-29 00:15:33,047] INFO: ⏱️ Processed 8000/8644 files
# [2025-07-29 00:15:49,004] INFO: ✅ Preprocessing complete: Valid=8644 | Rejected=0 (low tokens=0, missing tags=0, other errors=0) in 247.00s
# [2025-07-29 00:15:49,005] INFO: ⚡ Vectorizing text data...
# [2025-07-29 00:27:02,950] INFO: 🌀 Performing dimensionality reduction...
# [2025-07-29 00:27:55,058] INFO: ⭐ Explained variance: 0.9734
# [2025-07-29 00:27:55,332] INFO: 📊 Vectorized 8644 docs in 726.33s
# [2025-07-29 00:27:55,333] INFO: 🧩 Clustering documents...
# [2025-07-29 00:27:58,726] INFO: 🏷️ Clustered 8644 docs in 3.39s
# [2025-07-29 00:27:58,727] INFO: ✂️ Performing stratified split...
# [2025-07-29 00:27:58,787] INFO: ✅ Split complete: Train=7762 | Val=882
# [2025-07-29 00:27:58,907] INFO: 🛠️ Copying 7762 files to train
# [2025-07-29 00:28:09,357] INFO: 📆 Copied 7762/7762 files in 10.45s
# [2025-07-29 00:28:09,381] INFO: 🛠️ Copying 882 files to val
# [2025-07-29 00:28:10,654] INFO: 📆 Copied 882/882 files in 1.27s
# [2025-07-29 00:28:10,659] INFO: 🎉 Total processing time: 988.66s
# [2025-07-29 00:28:10,660] INFO: 📊 Final counts: Train=7762, Val=882, Rejected=0

# %%
import os
import logging
from pathlib import Path
from datetime import datetime

# ======================= CONFIG (Must match prior script) =======================
RANDOM_SEED = 42
BASE_DIR = Path(r"C:/Users/ayush/OneDrive/Desktop/Stories")
SPLIT_DIR = BASE_DIR / "split"
TRAIN_DIR = SPLIT_DIR / "train"
VAL_DIR = SPLIT_DIR / "val"
LOG_DIR = SPLIT_DIR / "split_logs"
MERGE_OUTPUT_DIR = BASE_DIR / "training_data" / "train_bulk_txt"
MERGED_TRAIN_FILE = MERGE_OUTPUT_DIR / "merged_train.txt"
MERGED_VAL_FILE = MERGE_OUTPUT_DIR / "merged_val.txt"

MERGE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# ======================= LOGGING =======================
logging.basicConfig(
    level=logging.INFO,
    format='[%(asctime)s] %(levelname)s: %(message)s',
    handlers=[
        logging.FileHandler(LOG_DIR / "merge_pipeline.log", mode='w', encoding='utf-8'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger("MERGE")

# ======================= MERGE FUNCTION =======================
def merge_texts(source_dir: Path, output_path: Path, label: str):
    logger.info(f"📦 Merging all .txt files in {source_dir} for [{label.upper()}]...")
    files = sorted(source_dir.glob("*.txt"))
    total_size = 0
    merged_count = 0

    with open(output_path, 'w', encoding='utf-8') as outfile:
        for file in files:
            try:
                with open(file, 'r', encoding='utf-8') as f:
                    content = f.read().strip()
                    if content:
                        outfile.write(content + '\n')
                        merged_count += 1
                        total_size += len(content.encode('utf-8'))
                    else:
                        logger.warning(f"⚠️ Empty file skipped: {file.name}")
            except Exception as e:
                logger.error(f"❌ Failed to read {file.name}: {e}")

    logger.info(f"✅ Merged {merged_count} files → {output_path.name} ({total_size / 1024:.2f} KB)")

# ======================= EXECUTION =======================
def main():
    logger.info("🚀 Starting merge script (post split pipeline)")
    start_time = datetime.now()

    if not TRAIN_DIR.exists():
        logger.error(f"❌ Train directory not found: {TRAIN_DIR}")
    else:
        merge_texts(TRAIN_DIR, MERGED_TRAIN_FILE, "train")

    if not VAL_DIR.exists():
        logger.error(f"❌ Val directory not found: {VAL_DIR}")
    else:
        merge_texts(VAL_DIR, MERGED_VAL_FILE, "val")

    elapsed = (datetime.now() - start_time).total_seconds()
    logger.info(f"🏁 Merging complete in {elapsed:.2f} seconds")

if __name__ == '__main__':
    main()
# Out:
# [2025-07-29 09:00:39,828] INFO: 🚀 Starting merge script (post split pipeline)
# [2025-07-29 09:00:39,830] INFO: 📦 Merging all .txt files in C:\Users\ayush\OneDrive\Desktop\Stories\split\train for [TRAIN]...
# [2025-07-29 09:03:11,819] INFO: ✅ Merged 7762 files → merged_train.txt (2954239.10 KB)
# [2025-07-29 09:03:11,825] INFO: 📦 Merging all .txt files in C:\Users\ayush\OneDrive\Desktop\Stories\split\val for [VAL]...
# [2025-07-29 09:03:28,787] INFO: ✅ Merged 882 files → merged_val.txt (339923.38 KB)
# [2025-07-29 09:03:28,787] INFO: 🏁 Merging complete in 168.96 seconds

# %%
2+2
# Out:
# 4

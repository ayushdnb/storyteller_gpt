# %%
from pathlib import Path
import os
import re
import logging
import shutil
import hashlib
import pandas as pd
from chardet import detect

# === CONFIGURATION ===
BASE_DIR = Path(r"C:\Users\ayush\OneDrive\Desktop\Stories")
RAW_DIR = BASE_DIR 
CLEANED_DIR = BASE_DIR / "cleaned_phase1"
CORRUPTED_DIR = CLEANED_DIR/ "corrupted_files"
META_CSV = CLEANED_DIR/ "file_meta_phase1.csv"
LOG_FILE = CLEANED_DIR/"phase1_cleaning.log"

# === SETUP ===
CLEANED_DIR.mkdir(parents=True, exist_ok=True)
CORRUPTED_DIR.mkdir(parents=True, exist_ok=True)

logging.basicConfig(
    level=logging.INFO,
    format='[%(asctime)s] %(levelname)s: %(message)s',
    handlers=[
        logging.FileHandler(LOG_FILE, mode='w', encoding='utf-8'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger()

# === STRIP GUTENBERG NOISE ===
def strip_gutenberg_noise(text):
    # Handle empty files immediately
    if not text:
        return ""
    
    # Improved patterns with explicit project gutenberg markers
    start_pattern = r"\*\*\*\s*START\s+OF\s+(THIS|THE)\s+PROJECT\s+GUTENBERG.+?\*\*\*"
    end_pattern = r"\*\*\*\s*END\s+OF\s+(THIS|THE)\s+PROJECT\s+GUTENBERG.+?\*\*\*"
    
    # Use DOTALL flag to match across lines
    start_match = re.search(start_pattern, text, re.IGNORECASE | re.DOTALL)
    end_match = re.search(end_pattern, text, re.IGNORECASE | re.DOTALL)
    
    # Handle overlapping matches
    if start_match and end_match and start_match.end() > end_match.start():
        # Only remove start if markers overlap
        return text[start_match.end():].strip()
    
    if start_match:
        text = text[start_match.end():]
        
    if end_match:
        text = text[:end_match.start()]
        
    return text.strip()

# === DETECT ENCODING ===
def detect_encoding(filepath):
    try:
        with open(filepath, 'rb') as f:
            return detect(f.read(10000))['encoding'] or 'utf-8'
    except Exception as e:
        logger.error(f"Encoding detection failed for {filepath.name}: {e}")
        return 'utf-8'

# === CLEAN FILE ===
def clean_file(src_path, dest_path):
    try:
        # Handle empty files
        if src_path.stat().st_size == 0:
            raise ValueError("File is empty (0 bytes)")
            
        encoding = detect_encoding(src_path)
        
        # Read with fallback encodings
        try:
            with open(src_path, 'r', encoding=encoding, errors='replace') as f:
                raw_text = f.read()
        except UnicodeDecodeError:
            # Try fallback encodings
            for alt_enc in ['utf-16', 'latin-1', 'iso-8859-1', 'cp1252']:
                try:
                    with open(src_path, 'r', encoding=alt_enc, errors='replace') as f:
                        raw_text = f.read()
                    encoding = alt_enc  # Update encoding
                    break
                except:
                    continue
            else:
                raise UnicodeDecodeError("All encoding attempts failed")

        clean_text = strip_gutenberg_noise(raw_text)
        
        # Handle files with no gutenberg markers
        if clean_text == raw_text.strip():
            logger.warning(f"⚠️ No Gutenberg markers found in {src_path.name}")
            
        # Normalize whitespace (preserve paragraph breaks)
        clean_text = re.sub(r"[^\S\n]+", " ", clean_text)  # Compress non-newline whitespace
        clean_text = re.sub(r"\n{3,}", "\n\n", clean_text)  # Reduce excessive newlines
        clean_text = clean_text.strip()

        # Write processed file
        with open(dest_path, 'w', encoding='utf-8') as f:
            f.write(clean_text)

        return {
            "filename": src_path.name,
            "status": "cleaned",
            "encoding": encoding,
            "original_size": len(raw_text),
            "cleaned_size": len(clean_text),
            "char_diff": len(raw_text) - len(clean_text),
            "hash": hashlib.md5(clean_text.encode('utf-8')).hexdigest()
        }
    except Exception as e:
        logger.error(f"❌ Error cleaning {src_path.name}: {str(e)}")
        try:
            if src_path.exists():
                shutil.copy(src_path, CORRUPTED_DIR / src_path.name)
        except Exception as copy_error:
            logger.error(f"❌ Failed to copy corrupted file: {copy_error}")
            
        return {
            "filename": src_path.name,
            "status": "corrupted",
            "error_type": str(type(e).__name__),
            "error_msg": str(e),
            "encoding": None,
            "original_size": None,
            "cleaned_size": None,
            "char_diff": None,
            "hash": None
        }

# === MAIN PIPELINE ===
def run_phase1_cleaning():
    all_files = list(RAW_DIR.glob("*.txt"))
    total_files = len(all_files)
    logger.info(f"📁 Total raw files detected: {total_files}")
    meta_records = []

    for i, file_path in enumerate(all_files, 1):
        logger.info(f"🧹 Processing file {i}/{total_files}: {file_path.name}")
        dest_path = CLEANED_DIR / file_path.name
        record = clean_file(file_path, dest_path)
        meta_records.append(record)
        
        # Periodic saving
        if i % 100 == 0 or i == total_files:
            pd.DataFrame(meta_records).to_csv(META_CSV, index=False)
            logger.info(f"💾 Saved metadata checkpoint ({i} files processed)")

    # Final save
    pd.DataFrame(meta_records).to_csv(META_CSV, index=False)
    
    # Generate summary report
    cleaned_count = sum(1 for r in meta_records if r['status'] == 'cleaned')
    corrupted_count = sum(1 for r in meta_records if r['status'] == 'corrupted')
    
    logger.info(f"✅ Phase 1 cleaning complete")
    logger.info(f"📊 Results: {cleaned_count} cleaned, {corrupted_count} corrupted")
    logger.info(f"💾 Metadata saved to {META_CSV}")

if __name__ == "__main__":
    try:
        run_phase1_cleaning()
    except Exception as e:
        logger.critical(f"🛑 Fatal pipeline error: {str(e)}", exc_info=True)

# %%
from pathlib import Path
import os
import logging
import hashlib
import pandas as pd
import random
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# === CONFIGURATION ===
BASE_DIR = Path(r"C:\Users\ayush\OneDrive\Desktop\Stories")
CLEANED_DIR = BASE_DIR / "cleaned_phase1"
TAGGED_DIR = BASE_DIR / "tagged_phase2"
TAG_MATRIX_CSV = BASE_DIR / "tag_matrix.csv"
ENTROPY_CSV = BASE_DIR / "tag_entropy.csv"
PHASE2_LOG = BASE_DIR / "phase2_tagging.log"
TAG_DETAILS_FILE = BASE_DIR / "tagging_summary.txt"
TAG_DENSITY_PNG = BASE_DIR / "tag_density_heatmap.png"
TAG_FREQ_PNG = BASE_DIR / "tag_frequency_plot.png"

# Import 100+ TAG_MAP separately or define here directly if needed
TAG_MAP = {
    # Structural / Narrative Anchors
    "#chapter_start": [],
    "#chapter_end": [],
    "#dialogue": ["said", "replied", "asked", "shouted", "whispered", "murmured", "exclaimed"],
    "#story_within": ["legend", "myth", "tale", "fable"],
    "#poem": ["verse", "stanza", "rhyme", "lyric"],
    "#quote": ["wisdom", "truth", "saying", "motto"],

    # Power Themes
    "#battle": ["sword", "blood", "clash", "siege", "arrow", "enemy", "war", "blade"],
    "#magic": ["spell", "sorcery", "wizard", "enchantment", "hex", "conjure", "potion"],
    "#curse": ["curse", "cursed", "blight", "bane", "doom", "mark"],
    "#prophecy": ["prophecy", "vision", "fate", "destiny", "omen", "oracle", "seer"],
    "#ritual": ["ritual", "ceremony", "chant", "offering", "sacrifice"],
    "#transformation": ["transform", "shapeshift", "reborn", "metamorphosis", "become"],
    "#vision": ["hallucination", "dream", "foresight", "premonition"],
    "#curse_break": ["liberated", "cleansed", "shattered spell", "redemption"],

    # Characters & Archetypes
    "#hero": ["hero", "champion", "savior", "redeemer"],
    "#villain": ["villain", "tyrant", "usurper", "corrupt", "nemesis"],
    "#mentor": ["mentor", "teacher", "sage", "elder"],
    "#outsider": ["stranger", "exile", "outcast", "wanderer"],
    "#title": ["king", "queen", "lord", "emperor", "high priest", "warlord"],

    # World Building
    "#place": ["fortress", "temple", "forest", "island", "valley", "realm", "village", "citadel"],
    "#noble_house": ["house", "clan", "dynasty", "lineage"],
    "#artifact": ["amulet", "scepter", "relic", "blade", "chalice", "scroll"],
    "#weapon": ["dagger", "spear", "sword", "bow", "axe"],
    "#creature": ["dragon", "beast", "wolf", "golem", "giant", "serpent"],
    "#god": ["god", "goddess", "divine", "pantheon", "deity"],
    "#element": ["fire", "water", "air", "earth", "ice", "lightning"],

    # Plot Devices & Themes
    "#death": ["corpse", "dead", "slain", "sacrifice", "funeral", "mourning"],
    "#betrayal": ["betray", "traitor", "deceive", "oath broken"],
    "#alliance": ["treaty", "pact", "truce", "union"],
    "#rebellion": ["revolt", "rebels", "uprising", "insurgents"],
    "#trial": ["judgment", "court", "accused", "guilty", "verdict"],
    "#oath": ["vow", "oath", "promise", "pledge"],
    "#revenge": ["vengeance", "payback", "retribution", "grudge"],

    # Social Constructs
    "#lineage": ["ancestor", "descendant", "bloodline", "heir"],
    "#legacy": ["legacy", "remains", "inheritance", "echo"],
    "#festival": ["festival", "feast", "celebration", "banquet"],
    "#law": ["decree", "edict", "rule", "commandment"],
    "#funeral": ["rites", "cremation", "burial", "mourning"],

    # Emotions & Conflict
    "#love": ["love", "desire", "affection", "passion"],
    "#grief": ["grief", "sorrow", "lament", "weep"],
    "#hope": ["hope", "light", "faith", "miracle"],
    "#fear": ["fear", "terror", "dread", "panic"],
    "#madness": ["madness", "insane", "lunacy", "deranged"],

    # Time & Space
    "#past": ["ancient", "old", "forgotten", "before"],
    "#future": ["forthcoming", "will", "soon", "destined"],
    "#present": ["now", "current", "this day"],
    "#travel": ["journey", "voyage", "path", "wander"],
    "#portal": ["portal", "gate", "doorway", "rift"],

    # Abstract / Cosmic
    "#fate": ["fate", "destiny", "threads", "woven"],
    "#chaos": ["chaos", "entropy", "discord", "anarchy"],
    "#order": ["order", "harmony", "balance", "structure"],
    "#void": ["void", "emptiness", "nothingness", "abyss"],
    "#creation": ["birth", "creation", "beginning", "genesis"],
    "#apocalypse": ["end", "apocalypse", "collapse", "cataclysm"],

    # Meta / Non-narrative
    "#editor_note": [],
    "#annotation": [],
    "#translation_note": []
} 


ALL_TAGS = list(TAG_MAP.keys()) + ["#chapter_start", "#chapter_end"]
TAG_COLUMNS = [tag for tag in ALL_TAGS if tag not in ("#chapter_start", "#chapter_end")]
TAGGED_DIR.mkdir(parents=True, exist_ok=True)

logging.basicConfig(
    level=logging.INFO,
    format='[%(asctime)s] %(levelname)s: %(message)s',
    handlers=[
        logging.FileHandler(PHASE2_LOG, mode='w', encoding='utf-8'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger()

def inject_tags(text):
    paragraphs = [p.strip() for p in text.split("\n\n") if p.strip()]
    tagged_lines = ["#chapter_start"]
    log_lines = []
    for i, para in enumerate(paragraphs):
        tags = {tag for tag, triggers in TAG_MAP.items() if any(t in para.lower() for t in triggers)}
        if not tags and i % 5 == 0:
            tags.add(random.choice(ALL_TAGS))
            log_lines.append(f"✨ Forced tag in paragraph {i}: {tags}")
        log_lines.append(f"📌 Para {i+1}/{len(paragraphs)} → Tags: {', '.join(tags) if tags else 'None'}")
        tagged_lines.extend(sorted(tags))
        tagged_lines.append(para)
    tagged_lines.append("#chapter_end")
    return "\n".join(tagged_lines), log_lines

def get_file_hash(text):
    return hashlib.md5(text.encode("utf-8")).hexdigest()

def visualize_tags(df):
    logger.info("📈 Generating tag frequency bar plot...")
    tag_counts = df[TAG_COLUMNS].sum().sort_values(ascending=False)
    tag_counts.plot(kind='bar', figsize=(12, 5), title='Tag Frequency')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(TAG_FREQ_PNG)
    plt.close()

    logger.info("🌡️ Generating tag density heatmap...")
    sns.heatmap(df[TAG_COLUMNS].astype(bool), cmap="YlGnBu", cbar=False)
    plt.title("Tag Density Heatmap")
    plt.xlabel("Tags")
    plt.ylabel("Files")
    plt.tight_layout()
    plt.savefig(TAG_DENSITY_PNG)
    plt.close()

def main():
    records, logs = [], []
    all_files = sorted(CLEANED_DIR.glob("*.txt"))
    total_files = len(all_files)
    logger.info(f"📂 Total files to process: {total_files}")

    for idx, file in enumerate(all_files, 1):
        logger.info(f"🚧 Step {idx}/{total_files}: Processing {file.name}")
        try:
            with open(file, encoding='utf-8') as f:
                content = f.read()
            tagged, lines = inject_tags(content)
            with open(TAGGED_DIR / file.name, 'w', encoding='utf-8') as out:
                out.write(tagged)
            counts = Counter(l for l in tagged.splitlines() if l.startswith("#"))
            record = {"filename": file.name, "hash": get_file_hash(tagged)}
            record.update({tag: counts.get(tag, 0) for tag in ALL_TAGS})
            records.append(record)
            logs.append(f"✅ {file.name}: {sum(counts.values())} tags\n" + "\n".join(lines))
            logger.info(f"✅ Tags added: {sum(counts.values())}, Unique: {len(counts)}")
        except Exception as e:
            logs.append(f"❌ {file.name} failed: {e}")
            logger.error(f"❌ Failed to process {file.name}: {e}")

    df = pd.DataFrame(records)
    df.to_csv(TAG_MATRIX_CSV, index=False)
    df["unique_tags"] = df[TAG_COLUMNS].astype(bool).sum(axis=1)
    df[["filename", "unique_tags"]].to_csv(ENTROPY_CSV, index=False)
    visualize_tags(df)

    with open(TAG_DETAILS_FILE, 'w', encoding='utf-8') as f:
        f.write("\n\n".join(logs))

    logger.info("\n🎯 PHASE 2 TAGGING + VISUALIZATION COMPLETE")
    logger.info(f"📊 Tag matrix CSV saved to: {TAG_MATRIX_CSV}")
    logger.info(f"📈 Entropy CSV saved to: {ENTROPY_CSV}")
    logger.info(f"📝 Summary log saved to: {TAG_DETAILS_FILE}")
    logger.info(f"🖼️ Visuals saved to: {TAG_FREQ_PNG}, {TAG_DENSITY_PNG}")

if __name__ == "__main__":
    main()
# Out:
# [2025-07-26 23:39:53,090] INFO: 📂 Total files to process: 7524
# [2025-07-26 23:39:53,091] INFO: 🚧 Step 1/7524: Processing 01 Harry Potter and the Sorcerers Stone.txt
# [2025-07-26 23:39:53,746] INFO: ✅ Tags added: 4165, Unique: 57
# [2025-07-26 23:39:53,746] INFO: 🚧 Step 2/7524: Processing 02 Harry Potter and the Chamber of Secrets.txt
# [2025-07-26 23:39:54,485] INFO: ✅ Tags added: 4931, Unique: 59
# [2025-07-26 23:39:54,485] INFO: 🚧 Step 3/7524: Processing 03 Harry Potter and the Prisoner of Azkaban.txt
# [2025-07-26 23:39:55,465] INFO: ✅ Tags added: 6240, Unique: 59
# [2025-07-26 23:39:55,465] INFO: 🚧 Step 4/7524: Processing 04 Harry Potter and the Goblet of Fire.txt
# [2025-07-26 23:39:57,012] INFO: ✅ Tags added: 11293, Unique: 59
# [2025-07-26 23:39:57,012] INFO: 🚧 Step 5/7524: Processing 05 Harry Potter and the Order of the Phoenix.txt
# [2025-07-26 23:39:58,375] INFO: ✅ Tags added: 15658, Unique: 59
# [2025-07-26 23:39:58,375] INFO: 🚧 Step 6/7524: Processing 06 Harry Potter and the Half-Blood Prince.txt
# [2025-07-26 23:39:59,928] INFO: ✅ Tags added: 9960, Unique: 59
# [2025-07-26 23:39:59,928] INFO: 🚧 Step 7/7524: Processing 07 Harry Potter and the Deathly Hallows.txt
# [2025-07-26 23:40:01,579] INFO: ✅ Tags added: 11117, Unique: 59
# [2025-07-26 23:40:01,579] INFO: 🚧 Step 8/7524: Processing 1000 Mythological Characters Briefly Described.txt
# [2025-07-26 23:40:01,844] INFO: ✅ Tags added: 1818, Unique: 59
# [2025-07-26 23:40:01,844] INFO: 🚧 Step 9/7524: Processing 10004_the_warriors__by_anna_robertson_brown_li.txt
# [2025-07-26 23:40:02,173] INFO: ✅ Tags added: 3013, Unique: 59
# [2025-07-26 23:40:02,173] INFO: 🚧 Step 10/7524: Processing 10011_365_foreign_dishes__by_unknown_author.txt
# [2025-07-26 23:40:02,326] INFO: ✅ Tags added: 1166, Unique: 59
# [2025-07-26 23:40:02,326] INFO: 🚧 Step 11/7524: Processing 1001_divine_comedy__inferno__by_dante_alighie.txt
# [2025-07-26 23:40:02,714] INFO: ✅ Tags added: 2798, Unique: 59
# [2025-07-26 23:40:02,714] INFO: 🚧 Step 12/7524: Processing 1002_divine_comedy__purgatory__by_dante_aligh.txt
# [2025-07-26 23:40:03,201] INFO: ✅ Tags added: 2936, Unique: 59
# [2025-07-26 23:40:03,203] INFO: 🚧 Step 13/7524: Processing 1003_divine_comedy__paradise__by_dante_alighi.txt
# [2025-07-26 23:40:03,576] INFO: ✅ Tags added: 2958, Unique: 59
# [2025-07-26 23:40:03,576] INFO: 🚧 Step 14/7524: Processing 10042_the_child_under_eight__by_e__r__murray_a.txt
# [2025-07-26 23:40:04,065] INFO: ✅ Tags added: 3723, Unique: 59
# [2025-07-26 23:40:04,065] INFO: 🚧 Step 15/7524: Processing 10044_chronicles_of_canada__volume_12_of_32__t.txt
# [2025-07-26 23:40:04,430] INFO: ✅ Tags added: 2775, Unique: 59
# [2025-07-26 23:40:04,430] INFO: 🚧 Step 16/7524: Processing 10046_salute_to_adventurers__by_john_buchan.txt
# [2025-07-26 23:40:05,064] INFO: ✅ Tags added: 5713, Unique: 59
# [2025-07-26 23:40:05,065] INFO: 🚧 Step 17/7524: Processing 1004_divine_comedy__complete__by_dante_alighi.txt
# [2025-07-26 23:40:06,326] INFO: ✅ Tags added: 8637, Unique: 59
# [2025-07-26 23:40:06,329] INFO: 🚧 Step 18/7524: Processing 10053_la_vampire__by_paul_h__c__feval.txt
# [2025-07-26 23:40:07,599] INFO: ✅ Tags added: 3132, Unique: 59
# [2025-07-26 23:40:07,599] INFO: 🚧 Step 19/7524: Processing 10055_hamburgische_dramaturgie__by_gotthold_ep.txt
# [2025-07-26 23:40:09,516] INFO: ✅ Tags added: 5509, Unique: 59
# [2025-07-26 23:40:09,516] INFO: 🚧 Step 20/7524: Processing 10056_chinese_literature__by_anonymous.txt
# [2025-07-26 23:40:10,176] INFO: ✅ Tags added: 6174, Unique: 59
# [2025-07-26 23:40:10,176] INFO: 🚧 Step 21/7524: Processing 10058_the_divine_office__by_rev__e__j__quigley.txt
# [2025-07-26 23:40:10,711] INFO: ✅ Tags added: 4651, Unique: 59
# [2025-07-26 23:40:10,711] INFO: 🚧 Step 22/7524: Processing 1005_divine_comedy__hell__by_dante_alighieri.txt
# [2025-07-26 23:40:11,171] INFO: ✅ Tags added: 2721, Unique: 59
# [2025-07-26 23:40:11,173] INFO: 🚧 Step 23/7524: Processing 10069_account_of_the_romansh_language__by_jose.txt
# [2025-07-26 23:40:11,227] INFO: ✅ Tags added: 390, Unique: 53
# [2025-07-26 23:40:11,227] INFO: 🚧 Step 24/7524: Processing 1006_divine_comedy__purgatory__by_dante_aligh.txt
# [2025-07-26 23:40:11,687] INFO: ✅ Tags added: 2863, Unique: 59
# [2025-07-26 23:40:11,687] INFO: 🚧 Step 25/7524: Processing 10070_stories_of_great_americans_for_little_am.txt
# [2025-07-26 23:40:11,912] INFO: ✅ Tags added: 1577, Unique: 59
# [2025-07-26 23:40:11,912] INFO: 🚧 Step 26/7524: Processing 10075_a_narrative_of_the_life_and_adventures_o.txt
# [2025-07-26 23:40:11,977] INFO: ✅ Tags added: 533, Unique: 56
# [2025-07-26 23:40:11,977] INFO: 🚧 Step 27/7524: Processing 10076_lister_s_great_adventure__by_harold_bind.txt
# [2025-07-26 23:40:12,500] INFO: ✅ Tags added: 4256, Unique: 59
# [2025-07-26 23:40:12,500] INFO: 🚧 Step 28/7524: Processing 1007_divine_comedy__paradise__by_dante_alighi.txt
# [2025-07-26 23:40:12,940] INFO: ✅ Tags added: 2755, Unique: 59
# [2025-07-26 23:40:12,940] INFO: 🚧 Step 29/7524: Processing 10082_the_hampstead_mystery__by_john_r__watson.txt
# [2025-07-26 23:40:13,716] INFO: ✅ Tags added: 6173, Unique: 59
# [2025-07-26 23:40:13,716] INFO: 🚧 Step 30/7524: Processing 10089_elves_and_heroes__by_donald_a__mackenzie.txt
# [2025-07-26 23:40:13,871] INFO: ✅ Tags added: 1419, Unique: 59
# [2025-07-26 23:40:13,871] INFO: 🚧 Step 31/7524: Processing 1008_divine_comedy__complete__by_dante_alighi.txt
# [2025-07-26 23:40:15,605] INFO: ✅ Tags added: 10608, Unique: 59
# [2025-07-26 23:40:15,605] INFO: 🚧 Step 32/7524: Processing 10095_the_twilight_of_the_gods__and_other_tale.txt
# [2025-07-26 23:40:16,342] INFO: ✅ Tags added: 5462, Unique: 59
# [2025-07-26 23:40:16,342] INFO: 🚧 Step 33/7524: Processing 10096_the_trojan_women__by_euripides.txt
# [2025-07-26 23:40:16,495] INFO: ✅ Tags added: 1506, Unique: 59
# [2025-07-26 23:40:16,495] INFO: 🚧 Step 34/7524: Processing 10130_the_works_of_charles_and_mary_lamb__vol_.txt
# [2025-07-26 23:40:17,878] INFO: ✅ Tags added: 14366, Unique: 59
# [2025-07-26 23:40:17,878] INFO: 🚧 Step 35/7524: Processing 10148_the_merry_adventures_of_robin_hood__by_h.txt
# [2025-07-26 23:40:18,585] INFO: ✅ Tags added: 7361, Unique: 59
# [2025-07-26 23:40:18,585] INFO: 🚧 Step 36/7524: Processing 10214_introduction_to_the_philosophy_and_writi.txt
# [2025-07-26 23:40:18,853] INFO: ✅ Tags added: 2136, Unique: 59
# [2025-07-26 23:40:18,857] INFO: 🚧 Step 37/7524: Processing 10315_persian_literature__volume_1__comprising.txt
# [2025-07-26 23:40:20,170] INFO: ✅ Tags added: 11478, Unique: 59
# [2025-07-26 23:40:20,170] INFO: 🚧 Step 38/7524: Processing 10316_roy_blakeley_s_adventures_in_camp__by_pe.txt
# [2025-07-26 23:40:20,460] INFO: ✅ Tags added: 3007, Unique: 59
# [2025-07-26 23:40:20,460] INFO: 🚧 Step 39/7524: Processing 10335_children_s_rights__by_kate_douglas_wiggi.txt
# [2025-07-26 23:40:20,741] INFO: ✅ Tags added: 2362, Unique: 59
# [2025-07-26 23:40:20,742] INFO: 🚧 Step 40/7524: Processing 10360_kitty_s_class_day_and_other_stories__by_.txt
# [2025-07-26 23:40:21,277] INFO: ✅ Tags added: 4665, Unique: 59
# [2025-07-26 23:40:21,280] INFO: 🚧 Step 41/7524: Processing 10366_freedom_s_battle__by_mahatma_gandhi.txt
# [2025-07-26 23:40:21,788] INFO: ✅ Tags added: 4821, Unique: 59
# [2025-07-26 23:40:21,788] INFO: 🚧 Step 42/7524: Processing 10376_american_indian_stories__by_zitkala_sa.txt
# [2025-07-26 23:40:22,020] INFO: ✅ Tags added: 2121, Unique: 59
# [2025-07-26 23:40:22,020] INFO: 🚧 Step 43/7524: Processing 10380_bible_stories_and_religious_classics__by.txt
# [2025-07-26 23:40:23,028] INFO: ✅ Tags added: 11987, Unique: 59
# [2025-07-26 23:40:23,028] INFO: 🚧 Step 44/7524: Processing 10383_the_maternal_management_of_children__in_.txt
# [2025-07-26 23:40:23,433] INFO: ✅ Tags added: 3178, Unique: 59
# [2025-07-26 23:40:23,433] INFO: 🚧 Step 45/7524: Processing 10387_the_real_america_in_romance__volume_6__a.txt
# [2025-07-26 23:40:23,998] INFO: ✅ Tags added: 5643, Unique: 59
# [2025-07-26 23:40:23,998] INFO: 🚧 Step 46/7524: Processing 10398_the_american_child__by_elizabeth_mccrack.txt
# [2025-07-26 23:40:24,248] INFO: ✅ Tags added: 2106, Unique: 59
# [2025-07-26 23:40:24,248] INFO: 🚧 Step 47/7524: Processing 10440_tutt_and_mr__tutt__by_arthur_train.txt
# [2025-07-26 23:40:24,686] INFO: ✅ Tags added: 3847, Unique: 59
# [2025-07-26 23:40:24,686] INFO: 🚧 Step 48/7524: Processing 10446_the_green_flag__by_arthur_conan_doyle.txt
# [2025-07-26 23:40:25,311] INFO: ✅ Tags added: 4099, Unique: 59
# [2025-07-26 23:40:25,311] INFO: 🚧 Step 49/7524: Processing 10449_burnham_breaker__by_homer_greene.txt
# [2025-07-26 23:40:25,988] INFO: ✅ Tags added: 5986, Unique: 59
# [2025-07-26 23:40:25,988] INFO: 🚧 Step 50/7524: Processing 10454_tales_for_young_and_old__by_various.txt
# [2025-07-26 23:40:26,407] INFO: ✅ Tags added: 3927, Unique: 59
# [2025-07-26 23:40:26,407] INFO: 🚧 Step 51/7524: Processing 10459_the_celtic_twilight__by_w__b__yeats.txt
# [2025-07-26 23:40:26,715] INFO: ✅ Tags added: 2588, Unique: 59
# [2025-07-26 23:40:26,715] INFO: 🚧 Step 52/7524: Processing 10463_the_little_house_in_the_fairy_wood__by_e.txt
# [2025-07-26 23:40:26,935] INFO: ✅ Tags added: 2231, Unique: 59
# [2025-07-26 23:40:26,935] INFO: 🚧 Step 53/7524: Processing 10464_a_child_s_anti_slavery_book__by_various.txt
# [2025-07-26 23:40:27,080] INFO: ✅ Tags added: 1374, Unique: 59
# [2025-07-26 23:40:27,080] INFO: 🚧 Step 54/7524: Processing 10466_little_saint_elizabeth_and_other_stories.txt
# [2025-07-26 23:40:27,270] INFO: ✅ Tags added: 1819, Unique: 59
# [2025-07-26 23:40:27,270] INFO: 🚧 Step 55/7524: Processing 10472_arthurian_chronicles__roman_de_brut__by_.txt
# [2025-07-26 23:40:27,652] INFO: ✅ Tags added: 4705, Unique: 59
# [2025-07-26 23:40:27,652] INFO: 🚧 Step 56/7524: Processing 10483_short_stories_old_and_new__by_various.txt
# [2025-07-26 23:40:28,271] INFO: ✅ Tags added: 5901, Unique: 59
# [2025-07-26 23:40:28,271] INFO: 🚧 Step 57/7524: Processing 10490_the_golden_legend__by_henry_wadsworth_lo.txt
# [2025-07-26 23:40:28,563] INFO: ✅ Tags added: 2294, Unique: 59
# [2025-07-26 23:40:28,563] INFO: 🚧 Step 58/7524: Processing 10506_romance_de_lobos__comedia_barbara__by_ra.txt
# [2025-07-26 23:40:28,822] INFO: ✅ Tags added: 647, Unique: 59
# [2025-07-26 23:40:28,822] INFO: 🚧 Step 59/7524: Processing 10508_the_sorrows_of_a_show_girl__by_kenneth_m.txt
# [2025-07-26 23:40:29,087] INFO: ✅ Tags added: 1996, Unique: 59
# [2025-07-26 23:40:29,087] INFO: 🚧 Step 60/7524: Processing 10523_alcestis__by_euripides.txt
# [2025-07-26 23:40:29,234] INFO: ✅ Tags added: 1401, Unique: 59
# [2025-07-26 23:40:29,234] INFO: 🚧 Step 61/7524: Processing 10541_children_s_classics_in_dramatic_form__by.txt
# [2025-07-26 23:40:29,442] INFO: ✅ Tags added: 1765, Unique: 59
# [2025-07-26 23:40:29,442] INFO: 🚧 Step 62/7524: Processing 10548_the_westcotes__by_arthur_thomas_quiller_.txt
# [2025-07-26 23:40:29,710] INFO: ✅ Tags added: 2305, Unique: 59
# [2025-07-26 23:40:29,710] INFO: 🚧 Step 63/7524: Processing 10549_a_romance_of_the_republic__by_lydia_mari.txt
# [2025-07-26 23:40:30,626] INFO: ✅ Tags added: 8193, Unique: 59
# [2025-07-26 23:40:30,626] INFO: 🚧 Step 64/7524: Processing 10564_fairy_gold__by_w__w__jacobs.txt
# [2025-07-26 23:40:30,655] INFO: ✅ Tags added: 253, Unique: 40
# [2025-07-26 23:40:30,655] INFO: 🚧 Step 65/7524: Processing 10581_uncle_bernac__by_arthur_conan_doyle.txt
# [2025-07-26 23:40:31,008] INFO: ✅ Tags added: 3595, Unique: 59
# [2025-07-26 23:40:31,008] INFO: 🚧 Step 66/7524: Processing 10588_seeing_europe_with_famous_authors__volum.txt
# [2025-07-26 23:40:31,384] INFO: ✅ Tags added: 3197, Unique: 59
# [2025-07-26 23:40:31,384] INFO: 🚧 Step 67/7524: Processing 10592_adventures_in_friendship__by_david_grays.txt
# [2025-07-26 23:40:31,611] INFO: ✅ Tags added: 2076, Unique: 59
# [2025-07-26 23:40:31,612] INFO: 🚧 Step 68/7524: Processing 10605_adventures_in_contentment__by_david_gray.txt
# [2025-07-26 23:40:31,919] INFO: ✅ Tags added: 2720, Unique: 59
# [2025-07-26 23:40:31,919] INFO: 🚧 Step 69/7524: Processing 10608_the_turquoise_cup__and__the_desert__by_a.txt
# [2025-07-26 23:40:32,121] INFO: ✅ Tags added: 1983, Unique: 59
# [2025-07-26 23:40:32,121] INFO: 🚧 Step 70/7524: Processing 10624_three_john_silence_stories__by_algernon_.txt
# [2025-07-26 23:40:32,694] INFO: ✅ Tags added: 3867, Unique: 59
# [2025-07-26 23:40:32,694] INFO: 🚧 Step 71/7524: Processing 10659_three_more_john_silence_stories__by_alge.txt
# [2025-07-26 23:40:33,009] INFO: ✅ Tags added: 2742, Unique: 59
# [2025-07-26 23:40:33,009] INFO: 🚧 Step 72/7524: Processing 10661_selection_from_the_discourses_of_epictet.txt
# [2025-07-26 23:40:33,388] INFO: ✅ Tags added: 3090, Unique: 59
# [2025-07-26 23:40:33,388] INFO: 🚧 Step 73/7524: Processing 10665_life__letters__and_epicurean_philosophy_.txt
# [2025-07-26 23:40:33,989] INFO: ✅ Tags added: 5760, Unique: 59
# [2025-07-26 23:40:33,989] INFO: 🚧 Step 74/7524: Processing 10677_biographical_memorials_of_james_oglethor.txt
# [2025-07-26 23:40:34,713] INFO: ✅ Tags added: 5420, Unique: 59
# [2025-07-26 23:40:34,713] INFO: 🚧 Step 75/7524: Processing 10700_the_history_of_england_from_the_first_in.txt
# [2025-07-26 23:40:36,162] INFO: ✅ Tags added: 13394, Unique: 59
# [2025-07-26 23:40:36,162] INFO: 🚧 Step 76/7524: Processing 10714_the_art_of_literature__by_arthur_schopen.txt
# [2025-07-26 23:40:36,430] INFO: ✅ Tags added: 1992, Unique: 59
# [2025-07-26 23:40:36,430] INFO: 🚧 Step 77/7524: Processing 10715_counsels_and_maxims__by_arthur_schopenha.txt
# [2025-07-26 23:40:36,782] INFO: ✅ Tags added: 2477, Unique: 59
# [2025-07-26 23:40:36,782] INFO: 🚧 Step 78/7524: Processing 10716_the_epic__by_lascelles_abercrombie.txt
# [2025-07-26 23:40:36,957] INFO: ✅ Tags added: 999, Unique: 59
# [2025-07-26 23:40:36,957] INFO: 🚧 Step 79/7524: Processing 10731_the_essays_of_arthur_schopenhauer__the_a.txt
# [2025-07-26 23:40:37,196] INFO: ✅ Tags added: 1489, Unique: 59
# [2025-07-26 23:40:37,196] INFO: 🚧 Step 80/7524: Processing 10732_the_essays_of_arthur_schopenhauer__studi.txt
# [2025-07-26 23:40:37,428] INFO: ✅ Tags added: 1617, Unique: 59
# [2025-07-26 23:40:37,428] INFO: 🚧 Step 81/7524: Processing 10735_christmas_eve_on_lonesome_and_other_stor.txt
# [2025-07-26 23:40:37,599] INFO: ✅ Tags added: 1083, Unique: 58
# [2025-07-26 23:40:37,599] INFO: 🚧 Step 82/7524: Processing 10736_children_of_the_frost__by_jack_london.txt
# [2025-07-26 23:40:37,969] INFO: ✅ Tags added: 3045, Unique: 59
# [2025-07-26 23:40:37,969] INFO: 🚧 Step 83/7524: Processing 10739_the_essays_of_arthur_schopenhauer__by_ar.txt
# [2025-07-26 23:40:38,232] INFO: ✅ Tags added: 1619, Unique: 59
# [2025-07-26 23:40:38,232] INFO: 🚧 Step 84/7524: Processing 10741_essays_of_arthur_schopenhauer__the_wisdo.txt
# [2025-07-26 23:40:38,502] INFO: ✅ Tags added: 1911, Unique: 59
# [2025-07-26 23:40:38,502] INFO: 🚧 Step 85/7524: Processing 10744_men__women__and_ghosts__by_elizabeth_stu.txt
# [2025-07-26 23:40:39,041] INFO: ✅ Tags added: 4508, Unique: 59
# [2025-07-26 23:40:39,041] INFO: 🚧 Step 86/7524: Processing 10747_chantecler__by_edmond_rostand.txt
# [2025-07-26 23:40:39,294] INFO: ✅ Tags added: 1783, Unique: 59
# [2025-07-26 23:40:39,294] INFO: 🚧 Step 87/7524: Processing 10765_thrilling_adventures_by_land_and_sea__by.txt
# [2025-07-26 23:40:39,943] INFO: ✅ Tags added: 6000, Unique: 59
# [2025-07-26 23:40:39,943] INFO: 🚧 Step 88/7524: Processing 10771_philippine_folklore_stories__by_john_mau.txt
# [2025-07-26 23:40:40,023] INFO: ✅ Tags added: 821, Unique: 57
# [2025-07-26 23:40:40,023] INFO: 🚧 Step 89/7524: Processing 10773_ancient_and_modern_physics__by_thomas_e_.txt
# [2025-07-26 23:40:40,181] INFO: ✅ Tags added: 1175, Unique: 59
# [2025-07-26 23:40:40,197] INFO: 🚧 Step 90/7524: Processing 10775_le_horla_and_other_stories__by_guy_de_ma.txt
# [2025-07-26 23:40:40,752] INFO: ✅ Tags added: 1468, Unique: 59
# [2025-07-26 23:40:40,752] INFO: 🚧 Step 91/7524: Processing 10800_the_anatomy_of_melancholy__by_democritus.txt
# [2025-07-26 23:40:45,130] INFO: ✅ Tags added: 32014, Unique: 59
# [2025-07-26 23:40:45,130] INFO: 🚧 Step 92/7524: Processing 10806_the_sword_of_welleran_and_other_stories_.txt
# [2025-07-26 23:40:45,381] INFO: ✅ Tags added: 2510, Unique: 59
# [2025-07-26 23:40:45,381] INFO: 🚧 Step 93/7524: Processing 10814_legends__tales_and_poems__by_gustavo_ado.txt
# [2025-07-26 23:40:46,633] INFO: ✅ Tags added: 5284, Unique: 59
# [2025-07-26 23:40:46,633] INFO: 🚧 Step 94/7524: Processing 10824_un_tournoi_a_romans_en_1484__by_ulysse_c.txt
# [2025-07-26 23:40:46,745] INFO: ✅ Tags added: 250, Unique: 54
# [2025-07-26 23:40:46,745] INFO: 🚧 Step 95/7524: Processing 10828_roman_history__books_1_3__by_titus_liviu.txt
# [2025-07-26 23:40:47,489] INFO: ✅ Tags added: 7156, Unique: 59
# [2025-07-26 23:40:47,489] INFO: 🚧 Step 96/7524: Processing 10832_carnacki__the_ghost_finder__by_william_h.txt
# [2025-07-26 23:40:47,837] INFO: ✅ Tags added: 2949, Unique: 59
# [2025-07-26 23:40:47,837] INFO: 🚧 Step 97/7524: Processing 10833_the_essays_of_arthur_schopenhauer__relig.txt
# [2025-07-26 23:40:48,026] INFO: ✅ Tags added: 1555, Unique: 59
# [2025-07-26 23:40:48,026] INFO: 🚧 Step 98/7524: Processing 10835_dr__johnson_s_works__life__poems__and_ta.txt
# [2025-07-26 23:40:49,065] INFO: ✅ Tags added: 9193, Unique: 59
# [2025-07-26 23:40:49,065] INFO: 🚧 Step 99/7524: Processing 10837_the_soul_of_democracy__by_edward_howard_.txt
# [2025-07-26 23:40:49,261] INFO: ✅ Tags added: 1530, Unique: 59
# [2025-07-26 23:40:49,261] INFO: 🚧 Step 100/7524: Processing 10842_the_life_of_captain_james_cook__by_arthu.txt
# [2025-07-26 23:40:49,894] INFO: ✅ Tags added: 4960, Unique: 59
# [2025-07-26 23:40:49,896] INFO: 🚧 Step 101/7524: Processing 10847_the_maids_tragedy__by_francis_beaumont_a.txt
# [2025-07-26 23:40:50,179] INFO: ✅ Tags added: 2149, Unique: 59
# [2025-07-26 23:40:50,179] INFO: 🚧 Step 102/7524: Processing 10877_the_tragedies_of_the_medici__by_edgcumbe.txt
# [2025-07-26 23:40:50,690] INFO: ✅ Tags added: 4049, Unique: 59
# [2025-07-26 23:40:50,690] INFO: 🚧 Step 103/7524: Processing 10887_babylonian_and_assyrian_literature__by_a.txt
# [2025-07-26 23:40:51,505] INFO: ✅ Tags added: 8247, Unique: 59
# [2025-07-26 23:40:51,505] INFO: 🚧 Step 104/7524: Processing 10888_arthur_hamilton__and_his_dog__by_anonymo.txt
# [2025-07-26 23:40:51,569] INFO: ✅ Tags added: 744, Unique: 56
# [2025-07-26 23:40:51,569] INFO: 🚧 Step 105/7524: Processing 10889_the_life_and_romances_of_mrs__eliza_hayw.txt
# [2025-07-26 23:40:52,075] INFO: ✅ Tags added: 3700, Unique: 59
# [2025-07-26 23:40:52,075] INFO: 🚧 Step 106/7524: Processing 10891_algonquin_indian_tales__by_egerton_r__yo.txt
# [2025-07-26 23:40:52,505] INFO: ✅ Tags added: 3842, Unique: 59
# [2025-07-26 23:40:52,505] INFO: 🚧 Step 107/7524: Processing 10911_buried_alive__a_tale_of_these_days__by_a.txt
# [2025-07-26 23:40:52,949] INFO: ✅ Tags added: 3229, Unique: 59
# [2025-07-26 23:40:52,949] INFO: 🚧 Step 108/7524: Processing 10915_the_girl_s_cabinet_of_instructive_and_mo.txt
# [2025-07-26 23:40:52,961] INFO: ✅ Tags added: 177, Unique: 42
# [2025-07-26 23:40:52,961] INFO: 🚧 Step 109/7524: Processing 10916_parent_and_child_vol__3__child_study_and.txt
# [2025-07-26 23:40:53,235] INFO: ✅ Tags added: 2033, Unique: 59
# [2025-07-26 23:40:53,235] INFO: 🚧 Step 110/7524: Processing 1091_heroes_and_hero_worship__by_thomas_carly.txt
# [2025-07-26 23:40:53,841] INFO: ✅ Tags added: 5268, Unique: 59
# [2025-07-26 23:40:53,841] INFO: 🚧 Step 111/7524: Processing 10926_saxe_holm_s_stories__by_helen_hunt_jacks.txt
# [2025-07-26 23:40:54,499] INFO: ✅ Tags added: 6500, Unique: 59
# [2025-07-26 23:40:54,502] INFO: 🚧 Step 112/7524: Processing 10930_the_buccaneer_farmer__by_harold_bindloss.txt
# [2025-07-26 23:40:55,188] INFO: ✅ Tags added: 5517, Unique: 59
# [2025-07-26 23:40:55,188] INFO: 🚧 Step 113/7524: Processing 10935_the_wonderful_adventures_of_nils__by_sel.txt
# [2025-07-26 23:40:56,204] INFO: ✅ Tags added: 8908, Unique: 59
# [2025-07-26 23:40:56,204] INFO: 🚧 Step 114/7524: Processing 10941_jumalainen_naeytelmae__helvetti__by_dant.txt
# [2025-07-26 23:40:56,678] INFO: ✅ Tags added: 1072, Unique: 59
# [2025-07-26 23:40:56,678] INFO: 🚧 Step 115/7524: Processing 10947_the_best_american_humorous_short_stories.txt
# [2025-07-26 23:40:57,685] INFO: ✅ Tags added: 6097, Unique: 59
# [2025-07-26 23:40:57,685] INFO: 🚧 Step 116/7524: Processing 10948_the_stories_of_the_three_burglars__by_fr.txt
# [2025-07-26 23:40:57,887] INFO: ✅ Tags added: 1859, Unique: 59
# [2025-07-26 23:40:57,887] INFO: 🚧 Step 117/7524: Processing 10949_the_romance_of_zion_chapel__3rd__ed___by.txt
# [2025-07-26 23:40:58,177] INFO: ✅ Tags added: 2948, Unique: 59
# [2025-07-26 23:40:58,177] INFO: 🚧 Step 118/7524: Processing 10966_the_ghost_pirates__by_william_hope_hodgs.txt
# [2025-07-26 23:40:58,531] INFO: ✅ Tags added: 3041, Unique: 59
# [2025-07-26 23:40:58,531] INFO: 🚧 Step 119/7524: Processing 10981_child_s_new_story_book__anonymous.txt
# [2025-07-26 23:40:58,544] INFO: ✅ Tags added: 117, Unique: 32
# [2025-07-26 23:40:58,544] INFO: 🚧 Step 120/7524: Processing 10987_the_adventures_of_little_bewildered_henr.txt
# [2025-07-26 23:40:58,563] INFO: ✅ Tags added: 130, Unique: 38
# [2025-07-26 23:40:58,563] INFO: 🚧 Step 121/7524: Processing 10988_the_devil_s_admiral__by_frederick_ferdin.txt
# [2025-07-26 23:40:59,005] INFO: ✅ Tags added: 3767, Unique: 59
# [2025-07-26 23:40:59,005] INFO: 🚧 Step 122/7524: Processing 10999_tales_of_bengal__by_s__b__banerjea.txt
# [2025-07-26 23:40:59,388] INFO: ✅ Tags added: 3182, Unique: 59
# [2025-07-26 23:40:59,388] INFO: 🚧 Step 123/7524: Processing 11000_an_old_babylonian_version_of_the_gilgame.txt
# [2025-07-26 23:40:59,698] INFO: ✅ Tags added: 2009, Unique: 59
# [2025-07-26 23:40:59,698] INFO: 🚧 Step 124/7524: Processing 11008_antwerp_to_gallipoli__by_arthur_ruhl.txt
# [2025-07-26 23:41:00,210] INFO: ✅ Tags added: 4594, Unique: 59
# [2025-07-26 23:41:00,210] INFO: 🚧 Step 125/7524: Processing 11014_christmas_in_legend_and_story__by_elva_s.txt
# [2025-07-26 23:41:00,600] INFO: ✅ Tags added: 3558, Unique: 59
# [2025-07-26 23:41:00,616] INFO: 🚧 Step 126/7524: Processing 11016_port_of_adventure__by_charles_n__william.txt
# [2025-07-26 23:41:01,376] INFO: ✅ Tags added: 6213, Unique: 59
# [2025-07-26 23:41:01,376] INFO: 🚧 Step 127/7524: Processing 11027_grimm_s_fairy_stories__by_jacob_grimm_an.txt
# [2025-07-26 23:41:01,704] INFO: ✅ Tags added: 3915, Unique: 59
# [2025-07-26 23:41:01,704] INFO: 🚧 Step 128/7524: Processing 11028_philippine_folk_tales__by_carla_kern_bay.txt
# [2025-07-26 23:41:02,147] INFO: ✅ Tags added: 4058, Unique: 59
# [2025-07-26 23:41:02,147] INFO: 🚧 Step 129/7524: Processing 11029_american_hero_myths__by_daniel_g__brinto.txt
# [2025-07-26 23:41:02,659] INFO: ✅ Tags added: 4608, Unique: 59
# [2025-07-26 23:41:02,659] INFO: 🚧 Step 130/7524: Processing 11032_wilson_s_tales_of_the_borders_and_of_sco.txt
# [2025-07-26 23:41:03,140] INFO: ✅ Tags added: 4601, Unique: 59
# [2025-07-26 23:41:03,140] INFO: 🚧 Step 131/7524: Processing 11036_legendes_normandes__by_gaston_lavalley.txt
# [2025-07-26 23:41:03,756] INFO: ✅ Tags added: 1732, Unique: 59
# [2025-07-26 23:41:03,756] INFO: 🚧 Step 132/7524: Processing 11045_the_ghost_ship__by_richard_middleton.txt
# [2025-07-26 23:41:04,089] INFO: ✅ Tags added: 3003, Unique: 59
# [2025-07-26 23:41:04,089] INFO: 🚧 Step 133/7524: Processing 11053_minnie_s_sacrifice__by_frances_ellen_wat.txt
# [2025-07-26 23:41:04,276] INFO: ✅ Tags added: 1972, Unique: 59
# [2025-07-26 23:41:04,276] INFO: 🚧 Step 134/7524: Processing 11057_the_wife_of_his_youth_and_other_stories_.txt
# [2025-07-26 23:41:04,795] INFO: ✅ Tags added: 4545, Unique: 59
# [2025-07-26 23:41:04,795] INFO: 🚧 Step 135/7524: Processing 11066_graf_von_loeben_and_the_legend_of_lorele.txt
# [2025-07-26 23:41:04,890] INFO: ✅ Tags added: 639, Unique: 59
# [2025-07-26 23:41:04,890] INFO: 🚧 Step 136/7524: Processing 11068_the_spirit_of_the_age__by_william_hazlit.txt
# [2025-07-26 23:41:05,425] INFO: ✅ Tags added: 4247, Unique: 59
# [2025-07-26 23:41:05,425] INFO: 🚧 Step 137/7524: Processing 11072_jumalainen_naeytelmae__kiirastuli__by_da.txt
# [2025-07-26 23:41:05,941] INFO: ✅ Tags added: 1162, Unique: 59
# [2025-07-26 23:41:05,943] INFO: 🚧 Step 138/7524: Processing 11092_the_history_of_tom_thumb_and_other_stori.txt
# [2025-07-26 23:41:05,963] INFO: ✅ Tags added: 185, Unique: 39
# [2025-07-26 23:41:05,963] INFO: 🚧 Step 139/7524: Processing 11096_tales_of_ind__by_t__ramakrishna.txt
# [2025-07-26 23:41:06,120] INFO: ✅ Tags added: 1541, Unique: 59
# [2025-07-26 23:41:06,120] INFO: 🚧 Step 140/7524: Processing 11101_coleridge_s_ancient_mariner_and_select_p.txt
# [2025-07-26 23:41:06,391] INFO: ✅ Tags added: 2059, Unique: 59
# [2025-07-26 23:41:06,391] INFO: 🚧 Step 141/7524: Processing 11110_a_countess_from_canada__by_bessie_marcha.txt
# [2025-07-26 23:41:07,023] INFO: ✅ Tags added: 5902, Unique: 59
# [2025-07-26 23:41:07,023] INFO: 🚧 Step 142/7524: Processing 11129_uncle_humphrey_s_stories__by_various.txt
# [2025-07-26 23:41:07,081] INFO: ✅ Tags added: 577, Unique: 59
# [2025-07-26 23:41:07,081] INFO: 🚧 Step 143/7524: Processing 11144_somewhere_in_france_and_other_stories__b.txt
# [2025-07-26 23:41:07,380] INFO: ✅ Tags added: 2646, Unique: 59
# [2025-07-26 23:41:07,380] INFO: 🚧 Step 144/7524: Processing 11146_the_expedition_of_the_donner_party_and_i.txt
# [2025-07-26 23:41:07,980] INFO: ✅ Tags added: 5441, Unique: 59
# [2025-07-26 23:41:07,980] INFO: 🚧 Step 145/7524: Processing 1114_the_merchant_of_venice__by_william_shake.txt
# [2025-07-26 23:41:08,168] INFO: ✅ Tags added: 1450, Unique: 59
# [2025-07-26 23:41:08,168] INFO: 🚧 Step 146/7524: Processing 11153_no_hero__by_e__w__hornung.txt
# [2025-07-26 23:41:08,426] INFO: ✅ Tags added: 2122, Unique: 59
# [2025-07-26 23:41:08,426] INFO: 🚧 Step 147/7524: Processing 11156_bed_time_stories__buddy_and_brighteyes_p.txt
# [2025-07-26 23:41:08,667] INFO: ✅ Tags added: 1891, Unique: 59
# [2025-07-26 23:41:08,667] INFO: 🚧 Step 148/7524: Processing 11160_a_cotswold_village__by_j__arthur_gibbs.txt
# [2025-07-26 23:41:09,405] INFO: ✅ Tags added: 7136, Unique: 59
# [2025-07-26 23:41:09,405] INFO: 🚧 Step 149/7524: Processing 11165_wild_wings__a_romance_of_youth__by_marga.txt
# [2025-07-26 23:41:10,201] INFO: ✅ Tags added: 6429, Unique: 59
# [2025-07-26 23:41:10,201] INFO: 🚧 Step 150/7524: Processing 11166_for_gold_or_soul___by_lurana_w__sheldon.txt
# [2025-07-26 23:41:10,620] INFO: ✅ Tags added: 4464, Unique: 59
# [2025-07-26 23:41:10,620] INFO: 🚧 Step 151/7524: Processing 11167_deccan_nursery_tales__by_c__a__kincaid.txt
# [2025-07-26 23:41:10,789] INFO: ✅ Tags added: 2047, Unique: 57
# [2025-07-26 23:41:10,789] INFO: 🚧 Step 152/7524: Processing 11179_seeing_europe_with_famous_authors__vol__.txt
# [2025-07-26 23:41:11,138] INFO: ✅ Tags added: 3055, Unique: 59
# [2025-07-26 23:41:11,138] INFO: 🚧 Step 153/7524: Processing 11208_de_legende_en_de_heldhaftige__vroolijke_.txt
# [2025-07-26 23:41:12,423] INFO: ✅ Tags added: 6907, Unique: 59
# [2025-07-26 23:41:12,423] INFO: 🚧 Step 154/7524: Processing 11239_life_and_adventures_of_robinson_crusoe_o.txt
# [2025-07-26 23:41:13,133] INFO: ✅ Tags added: 5783, Unique: 59
# [2025-07-26 23:41:13,133] INFO: 🚧 Step 155/7524: Processing 11241_wee_ones__bible_stories__by_anonymous.txt
# [2025-07-26 23:41:13,181] INFO: ✅ Tags added: 442, Unique: 52
# [2025-07-26 23:41:13,181] INFO: 🚧 Step 156/7524: Processing 11247_the_exploits_of_brigadier_gerard__by_art.txt
# [2025-07-26 23:41:13,623] INFO: ✅ Tags added: 4470, Unique: 59
# [2025-07-26 23:41:13,638] INFO: 🚧 Step 157/7524: Processing 11252_martin_hewitt__investigator__by_arthur_m.txt
# [2025-07-26 23:41:13,985] INFO: ✅ Tags added: 3010, Unique: 59
# [2025-07-26 23:41:13,985] INFO: 🚧 Step 158/7524: Processing 11263_the_adventures_of_a_special_corresponden.txt
# [2025-07-26 23:41:14,472] INFO: ✅ Tags added: 3947, Unique: 59
# [2025-07-26 23:41:14,472] INFO: 🚧 Step 159/7524: Processing 11277_egyptian_ideas_of_the_future_life__by_e_.txt
# [2025-07-26 23:41:14,776] INFO: ✅ Tags added: 3151, Unique: 59
# [2025-07-26 23:41:14,776] INFO: 🚧 Step 160/7524: Processing 11278_folk_tales_of_napoleon__by_honore_de_bal.txt
# [2025-07-26 23:41:14,872] INFO: ✅ Tags added: 949, Unique: 58
# [2025-07-26 23:41:14,872] INFO: 🚧 Step 161/7524: Processing 11283_plays_of_gods_and_men__by_lord_dunsany.txt
# [2025-07-26 23:41:15,072] INFO: ✅ Tags added: 2118, Unique: 59
# [2025-07-26 23:41:15,072] INFO: 🚧 Step 162/7524: Processing 11308_the_book_of_enterprise_and_adventure__by.txt
# [2025-07-26 23:41:15,233] INFO: ✅ Tags added: 1380, Unique: 59
# [2025-07-26 23:41:15,233] INFO: 🚧 Step 163/7524: Processing 11310_hindu_tales_from_the_sanskrit__by_s__m__.txt
# [2025-07-26 23:41:15,529] INFO: ✅ Tags added: 2867, Unique: 59
# [2025-07-26 23:41:15,529] INFO: 🚧 Step 164/7524: Processing 11319_the_fairy_godmothers_and_other_tales__by.txt
# [2025-07-26 23:41:15,786] INFO: ✅ Tags added: 2447, Unique: 59
# [2025-07-26 23:41:15,786] INFO: 🚧 Step 165/7524: Processing 11334_wilson_s_tales_of_the_borders_and_of_sco.txt
# [2025-07-26 23:41:16,302] INFO: ✅ Tags added: 4605, Unique: 59
# [2025-07-26 23:41:16,302] INFO: 🚧 Step 166/7524: Processing 11339_aesop_s_fables__by_aesop.txt
# [2025-07-26 23:41:16,548] INFO: ✅ Tags added: 2424, Unique: 59
# [2025-07-26 23:41:16,548] INFO: 🚧 Step 167/7524: Processing 11346_the_saint_s_tragedy__by_charles_kingsley.txt
# [2025-07-26 23:41:16,977] INFO: ✅ Tags added: 3747, Unique: 59
# [2025-07-26 23:41:16,977] INFO: 🚧 Step 168/7524: Processing 11356_a_tale_of_one_city__the_new_birmingham__.txt
# [2025-07-26 23:41:17,413] INFO: ✅ Tags added: 2083, Unique: 64
# [2025-07-26 23:41:17,413] INFO: 🚧 Step 169/7524: Processing 11360_sacred_and_profane_love__by_e__arnold_be.txt
# [2025-07-26 23:41:17,828] INFO: ✅ Tags added: 3570, Unique: 59
# [2025-07-26 23:41:17,828] INFO: 🚧 Step 170/7524: Processing 11368_stories_of_inventors__by_russell_doubled.txt
# [2025-07-26 23:41:18,105] INFO: ✅ Tags added: 2026, Unique: 59
# [2025-07-26 23:41:18,105] INFO: 🚧 Step 171/7524: Processing 11396_faedra__by_herman_bang.txt
# [2025-07-26 23:41:18,700] INFO: ✅ Tags added: 2260, Unique: 59
# [2025-07-26 23:41:18,700] INFO: 🚧 Step 172/7524: Processing 11400_mystic_isles_of_the_south_seas__by_fredr.txt
# [2025-07-26 23:41:20,135] INFO: ✅ Tags added: 8993, Unique: 59
# [2025-07-26 23:41:20,137] INFO: 🚧 Step 173/7524: Processing 11413_the_refugees__by_arthur_conan_doyle.txt
# [2025-07-26 23:41:21,600] INFO: ✅ Tags added: 7791, Unique: 59
# [2025-07-26 23:41:21,600] INFO: 🚧 Step 174/7524: Processing 11431_character_sketches_of_romance__fiction_a.txt
# [2025-07-26 23:41:24,298] INFO: ✅ Tags added: 14581, Unique: 59
# [2025-07-26 23:41:24,298] INFO: 🚧 Step 175/7524: Processing 11436_stories_by_american_authors__vol__1__by_.txt
# [2025-07-26 23:41:24,736] INFO: ✅ Tags added: 2206, Unique: 59
# [2025-07-26 23:41:24,740] INFO: 🚧 Step 176/7524: Processing 11437_stories_by_american_authors__vol__5__by_.txt
# [2025-07-26 23:41:25,129] INFO: ✅ Tags added: 2406, Unique: 59
# [2025-07-26 23:41:25,129] INFO: 🚧 Step 177/7524: Processing 11440_tales_of_three_hemispheres__by_lord_duns.txt
# [2025-07-26 23:41:25,377] INFO: ✅ Tags added: 1947, Unique: 58
# [2025-07-26 23:41:25,377] INFO: 🚧 Step 178/7524: Processing 11451_the_rome_express__by_arthur_griffiths.txt
# [2025-07-26 23:41:25,884] INFO: ✅ Tags added: 1988, Unique: 59
# [2025-07-26 23:41:25,884] INFO: 🚧 Step 179/7524: Processing 11452_stories_by_american_authors__vol__6__by_.txt
# [2025-07-26 23:41:26,203] INFO: ✅ Tags added: 2352, Unique: 59
# [2025-07-26 23:41:26,205] INFO: 🚧 Step 180/7524: Processing 11474_deep_waters__part_4__sam_s_ghost__by_w__.txt
# [2025-07-26 23:41:26,239] INFO: ✅ Tags added: 182, Unique: 43
# [2025-07-26 23:41:26,241] INFO: 🚧 Step 181/7524: Processing 11496_poetry__by_arthur_thomas_quiller_couch.txt
# [2025-07-26 23:41:26,374] INFO: ✅ Tags added: 638, Unique: 58
# [2025-07-26 23:41:26,374] INFO: 🚧 Step 182/7524: Processing 11501_laughing_bill_hyde_and_other_stories__by.txt
# [2025-07-26 23:41:27,172] INFO: ✅ Tags added: 4685, Unique: 59
# [2025-07-26 23:41:27,174] INFO: 🚧 Step 183/7524: Processing 11512_o__henry_memorial_award_prize_stories_of.txt
# [2025-07-26 23:41:28,102] INFO: ✅ Tags added: 7135, Unique: 59
# [2025-07-26 23:41:28,102] INFO: 🚧 Step 184/7524: Processing 11514_balcony_stories__by_grace_e__king.txt
# [2025-07-26 23:41:28,379] INFO: ✅ Tags added: 2070, Unique: 59
# [2025-07-26 23:41:28,381] INFO: 🚧 Step 185/7524: Processing 11547_blackfoot_lodge_tales__by_george_bird_gr.txt
# [2025-07-26 23:41:29,132] INFO: ✅ Tags added: 6446, Unique: 59
# [2025-07-26 23:41:29,132] INFO: 🚧 Step 186/7524: Processing 11592_children_s_hour_with_red_riding_hood_and.txt
# [2025-07-26 23:41:29,163] INFO: ✅ Tags added: 216, Unique: 43
# [2025-07-26 23:41:29,163] INFO: 🚧 Step 187/7524: Processing 11603_the_house_of_cobwebs_and_other_stories__.txt
# [2025-07-26 23:41:29,910] INFO: ✅ Tags added: 5646, Unique: 59
# [2025-07-26 23:41:29,910] INFO: 🚧 Step 188/7524: Processing 11610_madam_crowl_s_ghost_and_the_dead_sexton_.txt
# [2025-07-26 23:41:30,005] INFO: ✅ Tags added: 826, Unique: 59
# [2025-07-26 23:41:30,008] INFO: 🚧 Step 189/7524: Processing 11623_the_dramatic_works_of_john_dryden__vol__.txt
# [2025-07-26 23:41:30,949] INFO: ✅ Tags added: 6779, Unique: 59
# [2025-07-26 23:41:30,949] INFO: 🚧 Step 190/7524: Processing 11633_parsifal__a_drama_by_wagner_as_retold_by.txt
# [2025-07-26 23:41:31,108] INFO: ✅ Tags added: 1347, Unique: 59
# [2025-07-26 23:41:31,108] INFO: 🚧 Step 191/7524: Processing 11655_fate_knocks_at_the_door__by_will_levingt.txt
# [2025-07-26 23:41:31,949] INFO: ✅ Tags added: 7084, Unique: 59
# [2025-07-26 23:41:31,949] INFO: 🚧 Step 192/7524: Processing 11656_the_great_shadow_and_other_napoleonic_ta.txt
# [2025-07-26 23:41:32,277] INFO: ✅ Tags added: 2668, Unique: 59
# [2025-07-26 23:41:32,277] INFO: 🚧 Step 193/7524: Processing 11658_williams_anthology__compiled_by_edwin_pa.txt
# [2025-07-26 23:41:32,688] INFO: ✅ Tags added: 3321, Unique: 59
# [2025-07-26 23:41:32,690] INFO: 🚧 Step 194/7524: Processing 11671_the_rudder_grangers_abroad_and_other_sto.txt
# [2025-07-26 23:41:33,097] INFO: ✅ Tags added: 3102, Unique: 59
# [2025-07-26 23:41:33,097] INFO: 🚧 Step 195/7524: Processing 11682_the_soul_of_the_war__by_philip_gibbs.txt
# [2025-07-26 23:41:34,209] INFO: ✅ Tags added: 9007, Unique: 59
# [2025-07-26 23:41:34,209] INFO: 🚧 Step 196/7524: Processing 11690_calvert_of_strathore__by_carter_goodloe.txt
# [2025-07-26 23:41:35,260] INFO: ✅ Tags added: 6169, Unique: 59
# [2025-07-26 23:41:35,260] INFO: 🚧 Step 197/7524: Processing 11696_the_food_of_the_gods_and_how_it_came_to_.txt
# [2025-07-26 23:41:35,898] INFO: ✅ Tags added: 4463, Unique: 59
# [2025-07-26 23:41:35,898] INFO: 🚧 Step 198/7524: Processing 11699_j__s__le_fanu_s_ghostly_tales__vol__1__b.txt
# [2025-07-26 23:41:36,019] INFO: ✅ Tags added: 995, Unique: 59
# [2025-07-26 23:41:36,019] INFO: 🚧 Step 199/7524: Processing 11700_j__s__le_fanu_s_ghostly_tales__vol__2__b.txt
# [2025-07-26 23:41:36,163] INFO: ✅ Tags added: 914, Unique: 56
# [2025-07-26 23:41:36,163] INFO: 🚧 Step 200/7524: Processing 11703_the_swiss_family_robinson__or_adventures.txt
# [2025-07-26 23:41:37,306] INFO: ✅ Tags added: 6904, Unique: 59
# [2025-07-26 23:41:37,306] INFO: 🚧 Step 201/7524: Processing 11721_o__henry_memorial_award_prize_stories_of.txt
# [2025-07-26 23:41:38,260] INFO: ✅ Tags added: 7051, Unique: 59
# [2025-07-26 23:41:38,260] INFO: 🚧 Step 202/7524: Processing 11738_hindoo_tales__translated_by_p__w__jacob.txt
# [2025-07-26 23:41:38,654] INFO: ✅ Tags added: 3825, Unique: 59
# [2025-07-26 23:41:38,654] INFO: 🚧 Step 203/7524: Processing 11750_j__s__le_fanu_s_ghostly_tales__vol__3__b.txt
# [2025-07-26 23:41:39,014] INFO: ✅ Tags added: 3122, Unique: 59
# [2025-07-26 23:41:39,014] INFO: 🚧 Step 204/7524: Processing 11859_isaac_t__hopper__by_l__maria_child.txt
# [2025-07-26 23:41:39,996] INFO: ✅ Tags added: 7529, Unique: 59
# [2025-07-26 23:41:39,996] INFO: 🚧 Step 205/7524: Processing 11866_the_life_and_most_surprising_adventures_.txt
# [2025-07-26 23:41:40,841] INFO: ✅ Tags added: 6911, Unique: 59
# [2025-07-26 23:41:40,842] INFO: 🚧 Step 206/7524: Processing 11870_the_country_of_the_blind__and_other_stor.txt
# [2025-07-26 23:41:42,030] INFO: ✅ Tags added: 9150, Unique: 59
# [2025-07-26 23:41:42,030] INFO: 🚧 Step 207/7524: Processing 11877_monkey_jack_and_other_stories__by_variou.txt
# [2025-07-26 23:41:42,058] INFO: ✅ Tags added: 192, Unique: 41
# [2025-07-26 23:41:42,058] INFO: 🚧 Step 208/7524: Processing 11894_the_mahabharata_of_krishna_dwaipayana_vy.txt
# [2025-07-26 23:41:43,139] INFO: ✅ Tags added: 12091, Unique: 59
# [2025-07-26 23:41:43,140] INFO: 🚧 Step 209/7524: Processing 11897_on_the_indian_sect_of_the_jainas__by_joh.txt
# [2025-07-26 23:41:43,371] INFO: ✅ Tags added: 977, Unique: 59
# [2025-07-26 23:41:43,372] INFO: 🚧 Step 210/7524: Processing 11898_seeing_europe_with_famous_authors__vol__.txt
# [2025-07-26 23:41:43,824] INFO: ✅ Tags added: 2945, Unique: 59
# [2025-07-26 23:41:43,825] INFO: 🚧 Step 211/7524: Processing 11911_the_silent_isle__by_arthur_christopher_b.txt
# [2025-07-26 23:41:44,649] INFO: ✅ Tags added: 5495, Unique: 59
# [2025-07-26 23:41:44,650] INFO: 🚧 Step 212/7524: Processing 11915_the_adventures_of_mr__mocker__by_thornto.txt
# [2025-07-26 23:41:44,748] INFO: ✅ Tags added: 885, Unique: 56
# [2025-07-26 23:41:44,749] INFO: 🚧 Step 213/7524: Processing 11930_more_fables__by_george_ade.txt
# [2025-07-26 23:41:44,893] INFO: ✅ Tags added: 1158, Unique: 59
# [2025-07-26 23:41:44,894] INFO: 🚧 Step 214/7524: Processing 11934_primitive_love_and_love_stories__by_henr.txt
# [2025-07-26 23:41:47,648] INFO: ✅ Tags added: 21835, Unique: 59
# [2025-07-26 23:41:47,650] INFO: 🚧 Step 215/7524: Processing 11935_mysticism_in_english_literature__by_caro.txt
# [2025-07-26 23:41:47,974] INFO: ✅ Tags added: 2403, Unique: 59
# [2025-07-26 23:41:47,974] INFO: 🚧 Step 216/7524: Processing 11938_folklore_of_the_santal_parganas__by_ceci.txt
# [2025-07-26 23:41:49,092] INFO: ✅ Tags added: 9912, Unique: 59
# [2025-07-26 23:41:49,094] INFO: 🚧 Step 217/7524: Processing 11945_essays_of_schopenhauer__by_arthur_schope.txt
# [2025-07-26 23:41:49,775] INFO: ✅ Tags added: 4017, Unique: 59
# [2025-07-26 23:41:49,778] INFO: 🚧 Step 218/7524: Processing 11949_master_tales_of_mystery__volume_3__colle.txt
# [2025-07-26 23:41:51,102] INFO: ✅ Tags added: 7706, Unique: 59
# [2025-07-26 23:41:51,103] INFO: 🚧 Step 219/7524: Processing 11977_chronicles_of_canada__vol__13_of_32__the.txt
# [2025-07-26 23:41:51,377] INFO: ✅ Tags added: 1573, Unique: 59
# [2025-07-26 23:41:51,377] INFO: 🚧 Step 220/7524: Processing 11987_by_advice_of_counsel__by_arthur_train.txt
# [2025-07-26 23:41:51,913] INFO: ✅ Tags added: 3823, Unique: 59
# [2025-07-26 23:41:51,914] INFO: 🚧 Step 221/7524: Processing 11990_shakespeare_s_insomnia__and_the_causes_t.txt
# [2025-07-26 23:41:52,004] INFO: ✅ Tags added: 560, Unique: 52
# [2025-07-26 23:41:52,004] INFO: 🚧 Step 222/7524: Processing 12005_les_chants_de_maldoror__by_comte_de_laut.txt
# [2025-07-26 23:41:53,049] INFO: ✅ Tags added: 2831, Unique: 59
# [2025-07-26 23:41:53,049] INFO: 🚧 Step 223/7524: Processing 12007_cousin_hatty_s_hymns_and_twilight_storie.txt
# [2025-07-26 23:41:53,146] INFO: ✅ Tags added: 597, Unique: 58
# [2025-07-26 23:41:53,146] INFO: 🚧 Step 224/7524: Processing 12016_the_merchant_of_berlin__by_l_muhlbach.txt
# [2025-07-26 23:41:54,215] INFO: ✅ Tags added: 8680, Unique: 59
# [2025-07-26 23:41:54,215] INFO: 🚧 Step 225/7524: Processing 12047_legends_of_the_madonna_as_represented_in.txt
# [2025-07-26 23:41:55,146] INFO: ✅ Tags added: 6803, Unique: 59
# [2025-07-26 23:41:55,146] INFO: 🚧 Step 226/7524: Processing 12058_the_mahabharata_of_krishna_dwaipayana_vy.txt
# [2025-07-26 23:41:55,652] INFO: ✅ Tags added: 5059, Unique: 59
# [2025-07-26 23:41:55,653] INFO: 🚧 Step 227/7524: Processing 12067_the_bee_man_of_orn_and_other_fanciful_ta.txt
# [2025-07-26 23:41:56,060] INFO: ✅ Tags added: 3805, Unique: 59
# [2025-07-26 23:41:56,064] INFO: 🚧 Step 228/7524: Processing 12069_joe_tilden_s_recipes_for_epicures__by_jo.txt
# [2025-07-26 23:41:56,163] INFO: ✅ Tags added: 635, Unique: 56
# [2025-07-26 23:41:56,164] INFO: 🚧 Step 229/7524: Processing 12086_eastern_shame_girl_and_others__by_charle.txt
# [2025-07-26 23:41:56,439] INFO: ✅ Tags added: 2266, Unique: 59
# [2025-07-26 23:41:56,439] INFO: 🚧 Step 230/7524: Processing 12094_o_henry_memorial_award_prize_stories_of_.txt
# [2025-07-26 23:41:57,374] INFO: ✅ Tags added: 6272, Unique: 59
# [2025-07-26 23:41:57,378] INFO: 🚧 Step 231/7524: Processing 12096_bushido__the_soul_of_japan__by_inazo_nit.txt
# [2025-07-26 23:41:57,724] INFO: ✅ Tags added: 2024, Unique: 59
# [2025-07-26 23:41:57,726] INFO: 🚧 Step 232/7524: Processing 1209_history_of_the_conquest_of_peru__by_will.txt
# [2025-07-26 23:41:59,404] INFO: ✅ Tags added: 12606, Unique: 59
# [2025-07-26 23:41:59,404] INFO: 🚧 Step 233/7524: Processing 12103_the_tale_of_mrs__tiggy_winkle__by_beatri.txt
# [2025-07-26 23:41:59,427] INFO: ✅ Tags added: 112, Unique: 38
# [2025-07-26 23:41:59,427] INFO: 🚧 Step 234/7524: Processing 12116_struwwelpeter__merry_stories_and_funny_p.txt
# [2025-07-26 23:41:59,458] INFO: ✅ Tags added: 155, Unique: 44
# [2025-07-26 23:41:59,463] INFO: 🚧 Step 235/7524: Processing 12137_la_legende_des_siecles__by_victor_hugo.txt
# [2025-07-26 23:42:00,269] INFO: ✅ Tags added: 2798, Unique: 59
# [2025-07-26 23:42:00,269] INFO: 🚧 Step 236/7524: Processing 12140_roman_farm_management__by_marcus_porcius.txt
# [2025-07-26 23:42:01,043] INFO: ✅ Tags added: 4960, Unique: 59
# [2025-07-26 23:42:01,043] INFO: 🚧 Step 237/7524: Processing 12144_the_continental_classics__vol__18__myste.txt
# [2025-07-26 23:42:01,929] INFO: ✅ Tags added: 7479, Unique: 59
# [2025-07-26 23:42:01,930] INFO: 🚧 Step 238/7524: Processing 12190_the_adventures_of_captain_horn__by_frank.txt
# [2025-07-26 23:42:02,843] INFO: ✅ Tags added: 6683, Unique: 59
# [2025-07-26 23:42:02,843] INFO: 🚧 Step 239/7524: Processing 12211_odd_craft__part_11__a_spirit_of_avarice_.txt
# [2025-07-26 23:42:02,882] INFO: ✅ Tags added: 288, Unique: 47
# [2025-07-26 23:42:02,883] INFO: 🚧 Step 240/7524: Processing 12218_pastoral_poetry_and_pastoral_drama__by_w.txt
# [2025-07-26 23:42:04,683] INFO: ✅ Tags added: 9587, Unique: 59
# [2025-07-26 23:42:04,696] INFO: 🚧 Step 241/7524: Processing 12219_ancient_nahuatl_poetry__by_daniel_g__bri.txt
# [2025-07-26 23:42:05,063] INFO: ✅ Tags added: 2425, Unique: 59
# [2025-07-26 23:42:05,063] INFO: 🚧 Step 242/7524: Processing 12225_tales_of_lonely_trails__by_zane_grey.txt
# [2025-07-26 23:42:06,019] INFO: ✅ Tags added: 6153, Unique: 59
# [2025-07-26 23:42:06,020] INFO: 🚧 Step 243/7524: Processing 12226_what_eight_million_women_want__by_rheta_.txt
# [2025-07-26 23:42:06,479] INFO: ✅ Tags added: 3730, Unique: 59
# [2025-07-26 23:42:06,480] INFO: 🚧 Step 244/7524: Processing 12227_child_s_first_picture_book__by_anonymous.txt
# [2025-07-26 23:42:06,491] INFO: ✅ Tags added: 54, Unique: 26
# [2025-07-26 23:42:06,492] INFO: 🚧 Step 245/7524: Processing 12250_contes_choisis_de_la_famille__by_les_fre.txt
# [2025-07-26 23:42:06,635] INFO: ✅ Tags added: 364, Unique: 57
# [2025-07-26 23:42:06,636] INFO: 🚧 Step 246/7524: Processing 12255_the_egyptian_conception_of_immortality__.txt
# [2025-07-26 23:42:06,731] INFO: ✅ Tags added: 751, Unique: 56
# [2025-07-26 23:42:06,732] INFO: 🚧 Step 247/7524: Processing 12264_father_payne__by_arthur_christopher_bens.txt
# [2025-07-26 23:42:07,679] INFO: ✅ Tags added: 6166, Unique: 59
# [2025-07-26 23:42:07,680] INFO: 🚧 Step 248/7524: Processing 12270_the_doomswoman__by_gertrude_franklin_hor.txt
# [2025-07-26 23:42:08,101] INFO: ✅ Tags added: 3084, Unique: 59
# [2025-07-26 23:42:08,103] INFO: 🚧 Step 249/7524: Processing 12277_the_delectable_duchy__by_arthur_thomas_q.txt
# [2025-07-26 23:42:08,564] INFO: ✅ Tags added: 3018, Unique: 59
# [2025-07-26 23:42:08,564] INFO: 🚧 Step 250/7524: Processing 12283_the_soul_of_a_child__by_edwin_bjorkman.txt
# [2025-07-26 23:42:09,266] INFO: ✅ Tags added: 4253, Unique: 59
# [2025-07-26 23:42:09,273] INFO: 🚧 Step 251/7524: Processing 12288_witchcraft_delusion_in_colonial_connecti.txt
# [2025-07-26 23:42:09,704] INFO: ✅ Tags added: 3043, Unique: 59
# [2025-07-26 23:42:09,705] INFO: 🚧 Step 252/7524: Processing 12293_old_cookery_books_and_ancient_cuisine__b.txt
# [2025-07-26 23:42:10,127] INFO: ✅ Tags added: 2442, Unique: 59
# [2025-07-26 23:42:10,127] INFO: 🚧 Step 253/7524: Processing 12303_fated_to_be_free__by_jean_ingelow.txt
# [2025-07-26 23:42:11,450] INFO: ✅ Tags added: 9337, Unique: 59
# [2025-07-26 23:42:11,450] INFO: 🚧 Step 254/7524: Processing 12309_love_affairs_of_the_courts_of_europe__by.txt
# [2025-07-26 23:42:12,274] INFO: ✅ Tags added: 5546, Unique: 59
# [2025-07-26 23:42:12,275] INFO: 🚧 Step 255/7524: Processing 12313_pictures_of_sweden__by_hans_christian_an.txt
# [2025-07-26 23:42:12,611] INFO: ✅ Tags added: 2822, Unique: 59
# [2025-07-26 23:42:12,612] INFO: 🚧 Step 256/7524: Processing 12315_shanty_the_blacksmith__a_tale_of_other_t.txt
# [2025-07-26 23:42:12,854] INFO: ✅ Tags added: 2035, Unique: 59
# [2025-07-26 23:42:12,855] INFO: 🚧 Step 257/7524: Processing 12316_true_tilda__by_arthur_thomas_quiller_cou.txt
# [2025-07-26 23:42:13,579] INFO: ✅ Tags added: 5079, Unique: 59
# [2025-07-26 23:42:13,581] INFO: 🚧 Step 258/7524: Processing 12321_rudimental_divine_science__by_mary_baker.txt
# [2025-07-26 23:42:13,619] INFO: ✅ Tags added: 268, Unique: 50
# [2025-07-26 23:42:13,621] INFO: 🚧 Step 259/7524: Processing 12333_the_mahabharata_of_krishna_dwaipayana_vy.txt
# [2025-07-26 23:42:15,120] INFO: ✅ Tags added: 13748, Unique: 59
# [2025-07-26 23:42:15,120] INFO: 🚧 Step 260/7524: Processing 12336_brown_wolf_and_other_jack_london_stories.txt
# [2025-07-26 23:42:15,571] INFO: ✅ Tags added: 3062, Unique: 59
# [2025-07-26 23:42:15,572] INFO: 🚧 Step 261/7524: Processing 12346_a_roman_singer__by_f__marion_crawford.txt
# [2025-07-26 23:42:16,321] INFO: ✅ Tags added: 5788, Unique: 59
# [2025-07-26 23:42:16,328] INFO: 🚧 Step 262/7524: Processing 12355_the_constitutional_development_of_japan_.txt
# [2025-07-26 23:42:16,453] INFO: ✅ Tags added: 895, Unique: 56
# [2025-07-26 23:42:16,461] INFO: 🚧 Step 263/7524: Processing 12364_the_united_states_in_the_light_of_prophe.txt
# [2025-07-26 23:42:16,745] INFO: ✅ Tags added: 2502, Unique: 59
# [2025-07-26 23:42:16,745] INFO: 🚧 Step 264/7524: Processing 12369_library_of_the_world_s_best_literature__.txt
# [2025-07-26 23:42:18,400] INFO: ✅ Tags added: 11707, Unique: 59
# [2025-07-26 23:42:18,401] INFO: 🚧 Step 265/7524: Processing 12370_bagh_o_bahar__or_tales_of_the_four_darwe.txt
# [2025-07-26 23:42:19,074] INFO: ✅ Tags added: 6291, Unique: 59
# [2025-07-26 23:42:19,075] INFO: 🚧 Step 266/7524: Processing 12380_two_thousand_miles_on_an_automobile__by_.txt
# [2025-07-26 23:42:19,697] INFO: ✅ Tags added: 4333, Unique: 59
# [2025-07-26 23:42:19,697] INFO: 🚧 Step 267/7524: Processing 12384_battle_pieces_and_aspects_of_the_war__by.txt
# [2025-07-26 23:42:20,119] INFO: ✅ Tags added: 2458, Unique: 59
# [2025-07-26 23:42:20,121] INFO: 🚧 Step 268/7524: Processing 1239_the_spirit_of_the_border__by_zane_grey.txt
# [2025-07-26 23:42:20,964] INFO: ✅ Tags added: 5913, Unique: 59
# [2025-07-26 23:42:20,965] INFO: 🚧 Step 269/7524: Processing 12404_seeing_europe_with_famous_authors__vol__.txt
# [2025-07-26 23:42:21,554] INFO: ✅ Tags added: 2907, Unique: 59
# [2025-07-26 23:42:21,555] INFO: 🚧 Step 270/7524: Processing 12417_fishin__jimmy__by_annie_trumbull_slosson.txt
# [2025-07-26 23:42:21,608] INFO: ✅ Tags added: 396, Unique: 51
# [2025-07-26 23:42:21,610] INFO: 🚧 Step 271/7524: Processing 12419_frontier_stories__by_bret_harte.txt
# [2025-07-26 23:42:22,858] INFO: ✅ Tags added: 8072, Unique: 59
# [2025-07-26 23:42:22,859] INFO: 🚧 Step 272/7524: Processing 12444_toaster_s_handbook__compiled_by_peggy_ed.txt
# [2025-07-26 23:42:24,087] INFO: ✅ Tags added: 9105, Unique: 59
# [2025-07-26 23:42:24,095] INFO: 🚧 Step 273/7524: Processing 12445_the_water_witch__or__the_skimmer_of_the_.txt
# [2025-07-26 23:42:25,622] INFO: ✅ Tags added: 9354, Unique: 59
# [2025-07-26 23:42:25,622] INFO: 🚧 Step 274/7524: Processing 12455_legends_of_the_middle_ages__by_h_a__guer.txt
# [2025-07-26 23:42:26,554] INFO: ✅ Tags added: 8817, Unique: 59
# [2025-07-26 23:42:26,555] INFO: 🚧 Step 275/7524: Processing 12458_the_talisman__by_george_borrow.txt
# [2025-07-26 23:42:26,575] INFO: ✅ Tags added: 139, Unique: 46
# [2025-07-26 23:42:26,576] INFO: 🚧 Step 276/7524: Processing 12481_hero_tales_of_the_far_north__by_jacob_a_.txt
# [2025-07-26 23:42:27,121] INFO: ✅ Tags added: 4154, Unique: 59
# [2025-07-26 23:42:27,122] INFO: 🚧 Step 277/7524: Processing 12509_the_moon_rock__by_arthur_j__rees.txt
# [2025-07-26 23:42:27,979] INFO: ✅ Tags added: 6633, Unique: 59
# [2025-07-26 23:42:27,980] INFO: 🚧 Step 278/7524: Processing 12518_the_adventures_of_a_forty_niner__by_dani.txt
# [2025-07-26 23:42:28,206] INFO: ✅ Tags added: 1751, Unique: 59
# ...
# [2025-07-27 00:56:21,727] INFO: ✅ Tags added: 6352, Unique: 59
# [2025-07-27 00:56:21,731] INFO: 🚧 Step 7426/7524: Processing The Danish History, Books I-IX.txt
# [2025-07-27 00:56:22,139] INFO: ✅ Tags added: 6839, Unique: 58
# [2025-07-27 00:56:22,144] INFO: 🚧 Step 7427/7524: Processing The Dark Door.txt
# [2025-07-27 00:56:22,198] INFO: ✅ Tags added: 356, Unique: 45
# [2025-07-27 00:56:22,201] INFO: 🚧 Step 7428/7524: Processing The Dark Goddess.txt
# [2025-07-27 00:56:22,236] INFO: ✅ Tags added: 256, Unique: 36
# [2025-07-27 00:56:22,239] INFO: 🚧 Step 7429/7524: Processing The Dark Other.txt
# [2025-07-27 00:56:22,498] INFO: ✅ Tags added: 2310, Unique: 59
# [2025-07-27 00:56:22,501] INFO: 🚧 Step 7430/7524: Processing The Defiant Agents.txt
# [2025-07-27 00:56:22,717] INFO: ✅ Tags added: 2553, Unique: 56
# [2025-07-27 00:56:22,720] INFO: 🚧 Step 7431/7524: Processing The Doomsman.txt
# [2025-07-27 00:56:22,993] INFO: ✅ Tags added: 3728, Unique: 57
# [2025-07-27 00:56:22,997] INFO: 🚧 Step 7432/7524: Processing The Door in the Wall, and Other Stories.txt
# [2025-07-27 00:56:23,370] INFO: ✅ Tags added: 1860, Unique: 58
# [2025-07-27 00:56:23,373] INFO: 🚧 Step 7433/7524: Processing The Doorway.txt
# [2025-07-27 00:56:23,396] INFO: ✅ Tags added: 95, Unique: 28
# [2025-07-27 00:56:23,400] INFO: 🚧 Step 7434/7524: Processing The Dunwich Horror.txt
# [2025-07-27 00:56:23,481] INFO: ✅ Tags added: 619, Unique: 48
# [2025-07-27 00:56:23,485] INFO: 🚧 Step 7435/7524: Processing The Egyptian Book of the dead.txt
# [2025-07-27 00:56:24,545] INFO: ✅ Tags added: 5406, Unique: 59
# [2025-07-27 00:56:24,548] INFO: 🚧 Step 7436/7524: Processing The Eyes Have It.txt
# [2025-07-27 00:56:24,573] INFO: ✅ Tags added: 51, Unique: 24
# [2025-07-27 00:56:24,577] INFO: 🚧 Step 7437/7524: Processing The fire of Asshurbanipal.txt
# [2025-07-27 00:56:24,636] INFO: ✅ Tags added: 451, Unique: 48
# [2025-07-27 00:56:24,639] INFO: 🚧 Step 7438/7524: Processing The Folk-Tales of the Magyars.txt
# [2025-07-27 00:56:25,428] INFO: ✅ Tags added: 7145, Unique: 58
# [2025-07-27 00:56:25,431] INFO: 🚧 Step 7439/7524: Processing The Glory of Ippling.txt
# [2025-07-27 00:56:25,467] INFO: ✅ Tags added: 232, Unique: 33
# [2025-07-27 00:56:25,471] INFO: 🚧 Step 7440/7524: Processing The Gods of Mars.txt
# [2025-07-27 00:56:26,080] INFO: ✅ Tags added: 4163, Unique: 58
# [2025-07-27 00:56:26,083] INFO: 🚧 Step 7441/7524: Processing The Golden Maiden, and other folk tales and fairy stories told in Armenia.txt
# [2025-07-27 00:56:26,333] INFO: ✅ Tags added: 3822, Unique: 55
# [2025-07-27 00:56:26,335] INFO: 🚧 Step 7442/7524: Processing The Hanging Stranger.txt
# [2025-07-27 00:56:26,376] INFO: ✅ Tags added: 225, Unique: 34
# [2025-07-27 00:56:26,380] INFO: 🚧 Step 7443/7524: Processing The haunter of the dark.txt
# [2025-07-27 00:56:26,432] INFO: ✅ Tags added: 390, Unique: 46
# [2025-07-27 00:56:26,436] INFO: 🚧 Step 7444/7524: Processing The Holes Around Mars.txt
# [2025-07-27 00:56:26,482] INFO: ✅ Tags added: 269, Unique: 45
# [2025-07-27 00:56:26,486] INFO: 🚧 Step 7445/7524: Processing The Hour of the Dragon.txt
# [2025-07-27 00:56:26,793] INFO: ✅ Tags added: 3889, Unique: 57
# [2025-07-27 00:56:26,797] INFO: 🚧 Step 7446/7524: Processing The House of the Wolfings.txt
# [2025-07-27 00:56:27,042] INFO: ✅ Tags added: 4309, Unique: 54
# [2025-07-27 00:56:27,045] INFO: 🚧 Step 7447/7524: Processing The House on the Borderland.txt
# [2025-07-27 00:56:27,205] INFO: ✅ Tags added: 1948, Unique: 50
# [2025-07-27 00:56:27,208] INFO: 🚧 Step 7448/7524: Processing The Hyborian Age.txt
# [2025-07-27 00:56:27,256] INFO: ✅ Tags added: 389, Unique: 42
# [2025-07-27 00:56:27,259] INFO: 🚧 Step 7449/7524: Processing The Invisible Man A Grotesque Romance.txt
# [2025-07-27 00:56:27,698] INFO: ✅ Tags added: 2217, Unique: 57
# [2025-07-27 00:56:27,701] INFO: 🚧 Step 7450/7524: Processing The island of Doctor Moreau.txt
# [2025-07-27 00:56:28,056] INFO: ✅ Tags added: 1925, Unique: 53
# [2025-07-27 00:56:28,060] INFO: 🚧 Step 7451/7524: Processing The Kama Sutra of Vatsyayana.txt
# [2025-07-27 00:56:28,311] INFO: ✅ Tags added: 2591, Unique: 58
# [2025-07-27 00:56:28,315] INFO: 🚧 Step 7452/7524: Processing The King in Yellow.txt
# [2025-07-27 00:56:28,932] INFO: ✅ Tags added: 3202, Unique: 58
# [2025-07-27 00:56:28,935] INFO: 🚧 Step 7453/7524: Processing The Land That Time Forgot.txt
# [2025-07-27 00:56:29,187] INFO: ✅ Tags added: 1335, Unique: 53
# [2025-07-27 00:56:29,190] INFO: 🚧 Step 7454/7524: Processing The Lani People.txt
# [2025-07-27 00:56:29,773] INFO: ✅ Tags added: 2712, Unique: 59
# [2025-07-27 00:56:29,776] INFO: 🚧 Step 7455/7524: Processing The Legends and Myths of Hawaii.txt
# [2025-07-27 00:56:30,368] INFO: ✅ Tags added: 9196, Unique: 58
# [2025-07-27 00:56:30,372] INFO: 🚧 Step 7456/7524: Processing The Legends of King Arthur and His Knights.txt
# [2025-07-27 00:56:30,677] INFO: ✅ Tags added: 5778, Unique: 53
# [2025-07-27 00:56:30,680] INFO: 🚧 Step 7457/7524: Processing The Literature of the Ancient Egyptians.txt
# [2025-07-27 00:56:31,342] INFO: ✅ Tags added: 3205, Unique: 58
# [2025-07-27 00:56:31,346] INFO: 🚧 Step 7458/7524: Processing The Lost Continent.txt
# [2025-07-27 00:56:31,616] INFO: ✅ Tags added: 1834, Unique: 56
# [2025-07-27 00:56:31,619] INFO: 🚧 Step 7459/7524: Processing The Lost World.txt
# [2025-07-27 00:56:31,873] INFO: ✅ Tags added: 2765, Unique: 58
# [2025-07-27 00:56:31,877] INFO: 🚧 Step 7460/7524: Processing The Mahabharata of Krishna-Dwaipayana Vyasa, Volume 1.txt
# [2025-07-27 00:56:37,730] INFO: ✅ Tags added: 21044, Unique: 58
# [2025-07-27 00:56:37,734] INFO: 🚧 Step 7461/7524: Processing The Mahabharata of Krishna-Dwaipayana Vyasa, Volume 2.txt
# [2025-07-27 00:56:43,616] INFO: ✅ Tags added: 17131, Unique: 59
# [2025-07-27 00:56:43,619] INFO: 🚧 Step 7462/7524: Processing The Mahabharata of Krishna-Dwaipayana Vyasa, Volume 3.txt
# [2025-07-27 00:56:45,322] INFO: ✅ Tags added: 21518, Unique: 59
# [2025-07-27 00:56:45,325] INFO: 🚧 Step 7463/7524: Processing The Mahabharata of Krishna-Dwaipayana Vyasa, Volume 4.txt
# [2025-07-27 00:56:46,342] INFO: ✅ Tags added: 12666, Unique: 57
# [2025-07-27 00:56:46,345] INFO: 🚧 Step 7464/7524: Processing The Man from Time.txt
# [2025-07-27 00:56:46,384] INFO: ✅ Tags added: 258, Unique: 40
# [2025-07-27 00:56:46,387] INFO: 🚧 Step 7465/7524: Processing The Man the Martians Made.txt
# [2025-07-27 00:56:46,434] INFO: ✅ Tags added: 339, Unique: 41
# [2025-07-27 00:56:46,437] INFO: 🚧 Step 7466/7524: Processing The Man Who Was Thursday A Nightmare.txt
# [2025-07-27 00:56:46,927] INFO: ✅ Tags added: 2692, Unique: 56
# [2025-07-27 00:56:46,931] INFO: 🚧 Step 7467/7524: Processing The Marching Morons.txt
# [2025-07-27 00:56:46,998] INFO: ✅ Tags added: 451, Unique: 49
# [2025-07-27 00:56:47,002] INFO: 🚧 Step 7468/7524: Processing The Merry Adventures of Robin Hood.txt
# [2025-07-27 00:56:47,369] INFO: ✅ Tags added: 5138, Unique: 53
# [2025-07-27 00:56:47,373] INFO: 🚧 Step 7469/7524: Processing The Metamorphoses of Ovid.txt
# [2025-07-27 00:56:48,334] INFO: ✅ Tags added: 4887, Unique: 59
# [2025-07-27 00:56:48,338] INFO: 🚧 Step 7470/7524: Processing The miniature menace.txt
# [2025-07-27 00:56:48,391] INFO: ✅ Tags added: 507, Unique: 42
# [2025-07-27 00:56:48,394] INFO: 🚧 Step 7471/7524: Processing The Misplaced Battleship.txt
# [2025-07-27 00:56:48,449] INFO: ✅ Tags added: 459, Unique: 42
# [2025-07-27 00:56:48,451] INFO: 🚧 Step 7472/7524: Processing The Most Sentimental Man.txt
# [2025-07-27 00:56:48,484] INFO: ✅ Tags added: 161, Unique: 36
# [2025-07-27 00:56:48,487] INFO: 🚧 Step 7473/7524: Processing The Mysterious Island.txt
# [2025-07-27 00:56:49,916] INFO: ✅ Tags added: 9105, Unique: 59
# [2025-07-27 00:56:49,919] INFO: 🚧 Step 7474/7524: Processing The Night Land.txt
# [2025-07-27 00:56:50,477] INFO: ✅ Tags added: 7014, Unique: 55
# [2025-07-27 00:56:50,480] INFO: 🚧 Step 7475/7524: Processing The Night of the Long Knives.txt
# [2025-07-27 00:56:50,656] INFO: ✅ Tags added: 1244, Unique: 55
# [2025-07-27 00:56:50,661] INFO: 🚧 Step 7476/7524: Processing The Orkneyinga Saga.txt
# [2025-07-27 00:56:52,074] INFO: ✅ Tags added: 5599, Unique: 59
# [2025-07-27 00:56:52,078] INFO: 🚧 Step 7477/7524: Processing The People of the Black Circle.txt
# [2025-07-27 00:56:52,215] INFO: ✅ Tags added: 1582, Unique: 56
# [2025-07-27 00:56:52,218] INFO: 🚧 Step 7478/7524: Processing The Piebald Hippogriff.txt
# [2025-07-27 00:56:52,240] INFO: ✅ Tags added: 81, Unique: 22
# [2025-07-27 00:56:52,243] INFO: 🚧 Step 7479/7524: Processing The Planet Savers.txt
# [2025-07-27 00:56:52,357] INFO: ✅ Tags added: 1192, Unique: 52
# [2025-07-27 00:56:52,359] INFO: 🚧 Step 7480/7524: Processing The Putnam Tradition.txt
# [2025-07-27 00:56:52,385] INFO: ✅ Tags added: 138, Unique: 29
# [2025-07-27 00:56:52,388] INFO: 🚧 Step 7481/7524: Processing The Skull.txt
# [2025-07-27 00:56:52,443] INFO: ✅ Tags added: 395, Unique: 49
# [2025-07-27 00:56:52,446] INFO: 🚧 Step 7482/7524: Processing The Sky Trap.txt
# [2025-07-27 00:56:52,485] INFO: ✅ Tags added: 240, Unique: 35
# [2025-07-27 00:56:52,488] INFO: 🚧 Step 7483/7524: Processing The Slayer of Souls.txt
# [2025-07-27 00:56:53,232] INFO: ✅ Tags added: 3340, Unique: 59
# [2025-07-27 00:56:53,235] INFO: 🚧 Step 7484/7524: Processing The Sorrows of Satan.txt
# [2025-07-27 00:56:54,026] INFO: ✅ Tags added: 6469, Unique: 59
# [2025-07-27 00:56:54,029] INFO: 🚧 Step 7485/7524: Processing The Sound of Silence.txt
# [2025-07-27 00:56:54,068] INFO: ✅ Tags added: 217, Unique: 36
# [2025-07-27 00:56:54,071] INFO: 🚧 Step 7486/7524: Processing The Stolen Bacillus and Other Incidents.txt
# [2025-07-27 00:56:54,290] INFO: ✅ Tags added: 2132, Unique: 59
# [2025-07-27 00:56:54,293] INFO: 🚧 Step 7487/7524: Processing The Story of the Three Little Pigs.txt
# [2025-07-27 00:56:54,315] INFO: ✅ Tags added: 75, Unique: 16
# [2025-07-27 00:56:54,318] INFO: 🚧 Step 7488/7524: Processing The Tempest.txt
# [2025-07-27 00:56:54,559] INFO: ✅ Tags added: 969, Unique: 59
# [2025-07-27 00:56:54,562] INFO: 🚧 Step 7489/7524: Processing The Three Impostors; or, The Transmutations.txt
# [2025-07-27 00:56:54,768] INFO: ✅ Tags added: 1964, Unique: 57
# [2025-07-27 00:56:54,771] INFO: 🚧 Step 7490/7524: Processing The Time Machine.txt
# [2025-07-27 00:56:55,059] INFO: ✅ Tags added: 1097, Unique: 50
# [2025-07-27 00:56:55,059] INFO: 🚧 Step 7491/7524: Processing The Time Traders.txt
# [2025-07-27 00:56:55,321] INFO: ✅ Tags added: 2621, Unique: 56
# [2025-07-27 00:56:55,321] INFO: 🚧 Step 7492/7524: Processing The Undersea Tube.txt
# [2025-07-27 00:56:55,360] INFO: ✅ Tags added: 207, Unique: 38
# [2025-07-27 00:56:55,360] INFO: 🚧 Step 7493/7524: Processing The Vampyre; a Tale.txt
# [2025-07-27 00:56:55,407] INFO: ✅ Tags added: 406, Unique: 49
# [2025-07-27 00:56:55,413] INFO: 🚧 Step 7494/7524: Processing The Variable Man.txt
# [2025-07-27 00:56:55,552] INFO: ✅ Tags added: 1069, Unique: 55
# [2025-07-27 00:56:55,553] INFO: 🚧 Step 7495/7524: Processing The Vibration Wasps.txt
# [2025-07-27 00:56:55,601] INFO: ✅ Tags added: 283, Unique: 42
# [2025-07-27 00:56:55,605] INFO: 🚧 Step 7496/7524: Processing The Vilbar Party.txt
# [2025-07-27 00:56:55,638] INFO: ✅ Tags added: 149, Unique: 34
# [2025-07-27 00:56:55,641] INFO: 🚧 Step 7497/7524: Processing The Violet Fairy Book.txt
# [2025-07-27 00:56:56,388] INFO: ✅ Tags added: 5325, Unique: 56
# [2025-07-27 00:56:56,388] INFO: 🚧 Step 7498/7524: Processing The Vortex Blaster.txt
# [2025-07-27 00:56:56,453] INFO: ✅ Tags added: 245, Unique: 40
# [2025-07-27 00:56:56,457] INFO: 🚧 Step 7499/7524: Processing The War of the Worlds.txt
# [2025-07-27 00:56:56,922] INFO: ✅ Tags added: 2350, Unique: 56
# [2025-07-27 00:56:56,924] INFO: 🚧 Step 7500/7524: Processing The warlord of Mars.txt
# [2025-07-27 00:56:57,271] INFO: ✅ Tags added: 2890, Unique: 55
# [2025-07-27 00:56:57,271] INFO: 🚧 Step 7501/7524: Processing The Wendigo.txt
# [2025-07-27 00:56:57,372] INFO: ✅ Tags added: 796, Unique: 49
# [2025-07-27 00:56:57,375] INFO: 🚧 Step 7502/7524: Processing The Wind in the Willows.txt
# [2025-07-27 00:56:57,847] INFO: ✅ Tags added: 2508, Unique: 50
# [2025-07-27 00:56:57,849] INFO: 🚧 Step 7503/7524: Processing The Wonderful Wizard of Oz.txt
# [2025-07-27 00:56:58,011] INFO: ✅ Tags added: 2175, Unique: 51
# [2025-07-27 00:56:58,011] INFO: 🚧 Step 7504/7524: Processing The Works of Edgar Allan Poe — Volume 1.txt
# [2025-07-27 00:56:58,707] INFO: ✅ Tags added: 2698, Unique: 58
# [2025-07-27 00:56:58,707] INFO: 🚧 Step 7505/7524: Processing The Works of Edgar Allan Poe — Volume 2.txt
# [2025-07-27 00:56:59,466] INFO: ✅ Tags added: 3289, Unique: 55
# [2025-07-27 00:56:59,466] INFO: 🚧 Step 7506/7524: Processing The Works of Edgar Allan Poe, The Raven Edition.txt
# [2025-07-27 00:57:02,969] INFO: ✅ Tags added: 14034, Unique: 59
# [2025-07-27 00:57:02,969] INFO: 🚧 Step 7507/7524: Processing The World Set Free.txt
# [2025-07-27 00:57:03,652] INFO: ✅ Tags added: 2591, Unique: 59
# [2025-07-27 00:57:03,652] INFO: 🚧 Step 7508/7524: Processing Thin Edge.txt
# [2025-07-27 00:57:03,715] INFO: ✅ Tags added: 397, Unique: 41
# [2025-07-27 00:57:03,715] INFO: 🚧 Step 7509/7524: Processing Through the Looking-Glass.txt
# [2025-07-27 00:57:04,062] INFO: ✅ Tags added: 2123, Unique: 49
# [2025-07-27 00:57:04,062] INFO: 🚧 Step 7510/7524: Processing Thuvia, Maid of Mars.txt
# [2025-07-27 00:57:04,444] INFO: ✅ Tags added: 2818, Unique: 57
# [2025-07-27 00:57:04,446] INFO: 🚧 Step 7511/7524: Processing Time Crime.txt
# [2025-07-27 00:57:04,606] INFO: ✅ Tags added: 1683, Unique: 54
# [2025-07-27 00:57:04,606] INFO: 🚧 Step 7512/7524: Processing train.txt
# [2025-07-27 00:57:04,768] INFO: ✅ Tags added: 58, Unique: 56
# [2025-07-27 00:57:04,770] INFO: 🚧 Step 7513/7524: Processing Translations of Shakuntala and Other Works.txt
# [2025-07-27 00:57:05,152] INFO: ✅ Tags added: 4369, Unique: 59
# [2025-07-27 00:57:05,154] INFO: 🚧 Step 7514/7524: Processing Triplanetary.txt
# [2025-07-27 00:57:05,345] INFO: ✅ Tags added: 2090, Unique: 54
# [2025-07-27 00:57:05,345] INFO: 🚧 Step 7515/7524: Processing Twelve Stories and a Dream.txt
# [2025-07-27 00:57:05,905] INFO: ✅ Tags added: 2959, Unique: 56
# [2025-07-27 00:57:05,912] INFO: 🚧 Step 7516/7524: Processing Twenty Thousand Leagues under the Sea.txt
# [2025-07-27 00:57:06,820] INFO: ✅ Tags added: 4125, Unique: 59
# [2025-07-27 00:57:06,820] INFO: 🚧 Step 7517/7524: Processing Twenty Thousand Leagues Under the Seas An Underwater Tour of the World.txt
# [2025-07-27 00:57:08,042] INFO: ✅ Tags added: 6029, Unique: 59
# [2025-07-27 00:57:08,042] INFO: 🚧 Step 7518/7524: Processing Ultima Thule.txt
# [2025-07-27 00:57:08,322] INFO: ✅ Tags added: 1243, Unique: 57
# [2025-07-27 00:57:08,325] INFO: 🚧 Step 7519/7524: Processing Upanishads.txt
# [2025-07-27 00:57:08,407] INFO: ✅ Tags added: 937, Unique: 44
# [2025-07-27 00:57:08,407] INFO: 🚧 Step 7520/7524: Processing val.txt
# [2025-07-27 00:57:08,459] INFO: ✅ Tags added: 49, Unique: 47
# [2025-07-27 00:57:08,462] INFO: 🚧 Step 7521/7524: Processing Vikram and the VampireClassic Hindu Tales of Adventure, Magic, and Romance.txt
# [2025-07-27 00:57:09,082] INFO: ✅ Tags added: 4089, Unique: 55
# [2025-07-27 00:57:09,085] INFO: 🚧 Step 7522/7524: Processing With the Night Mail A Story of 2000 A.D..txt
# [2025-07-27 00:57:09,166] INFO: ✅ Tags added: 611, Unique: 55
# [2025-07-27 00:57:09,166] INFO: 🚧 Step 7523/7524: Processing Wizard.txt
# [2025-07-27 00:57:09,212] INFO: ✅ Tags added: 433, Unique: 46
# [2025-07-27 00:57:09,221] INFO: 🚧 Step 7524/7524: Processing Year of the Big Thaw.txt
# [2025-07-27 00:57:09,251] INFO: ✅ Tags added: 127, Unique: 27
# [2025-07-27 00:57:09,751] INFO: 📈 Generating tag frequency bar plot...
# [2025-07-27 00:57:10,989] INFO: 🌡️ Generating tag density heatmap...
# [2025-07-27 00:58:23,043] INFO:
# 🎯 PHASE 2 TAGGING + VISUALIZATION COMPLETE
# [2025-07-27 00:58:23,169] INFO: 📊 Tag matrix CSV saved to: C:\Users\ayush\OneDrive\Desktop\Stories\tag_matrix.csv
# [2025-07-27 00:58:23,179] INFO: 📈 Entropy CSV saved to: C:\Users\ayush\OneDrive\Desktop\Stories\tag_entropy.csv
# [2025-07-27 00:58:23,186] INFO: 📝 Summary log saved to: C:\Users\ayush\OneDrive\Desktop\Stories\tagging_summary.txt
# [2025-07-27 00:58:23,191] INFO: 🖼️ Visuals saved to: C:\Users\ayush\OneDrive\Desktop\Stories\tag_frequency_plot.png, C:\Users\ayush\OneDrive\Desktop\Stories\tag_density_heatmap.png

# %%
from pathlib import Path
for file in Path("tagged_phase2").glob("*.txt"):
    content = file.read_text(encoding="utf-8")
    if "#chapter_start" not in content or "#chapter_end" not in content:
        print(f"❌ Missing block tags: {file.name}")

# %%
from pathlib import Path
import logging
import random
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import hashlib
import json

# ======================= CONFIGURATION =======================
BASE_DIR = Path(r"C:\Users\ayush\OneDrive\Desktop\Stories")
TAGGED_DIR = BASE_DIR / "tagged_phase2"
PHASE3_DIR = BASE_DIR / "split_phase3"
PHASE3_DIR.mkdir(parents=True, exist_ok=True)

TRAIN_PATH = PHASE3_DIR / "train.txt"
VAL_PATH = PHASE3_DIR / "val.txt"
META_CSV = PHASE3_DIR / "split_metadata.csv"
TRAIN_FILES = PHASE3_DIR / "train_files.csv"
VAL_FILES = PHASE3_DIR / "val_files.csv"
BALANCE_REPORT = PHASE3_DIR / "split_balance_report.txt"
BALANCE_PLOT = PHASE3_DIR / "tag_balance_val_vs_train.png"
PHASE3_LOG = PHASE3_DIR / "phase3_split.log"

SPLIT_RATIO = 0.95
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

logging.basicConfig(
    filename=str(PHASE3_LOG),
    level=logging.INFO,
    format='[%(asctime)s] %(levelname)s: %(message)s',
    filemode='w'
)
console = logging.StreamHandler()
console.setLevel(logging.INFO)
formatter = logging.Formatter("[%(asctime)s] %(levelname)s: %(message)s")
console.setFormatter(formatter)
logging.getLogger().addHandler(console)
logger = logging.getLogger()

# ======================= HELPERS =======================
def hash_block(text):
    return hashlib.md5(text.encode("utf-8")).hexdigest()

def parse_chapter_blocks(file_path):
    with open(file_path, encoding='utf-8') as f:
        content = f.read()
    blocks = []
    block_lines = []
    in_block = False
    for line in content.splitlines():
        if line.strip() == "#chapter_start":
            block_lines = [line]
            in_block = True
        elif line.strip() == "#chapter_end":
            block_lines.append(line)
            blocks.append("\n".join(block_lines))
            in_block = False
        elif in_block:
            block_lines.append(line)
    return blocks

def extract_metadata(block, filename):
    lines = block.splitlines()
    tags = set(l.strip() for l in lines if l.startswith("#") and not l in ["#chapter_start", "#chapter_end"])
    tag_counts = Counter(tags)
    token_count = len(block.split())
    return {
        "filename": filename,
        "block_hash": hash_block(block),
        "tokens": token_count,
        "entropy": len(tags),
        "tags": list(tags),
        "tag_counts": json.dumps(tag_counts),
        "text": block
    }

# ======================= MAIN PIPELINE =======================
def main():
    all_files = sorted(TAGGED_DIR.glob("*.txt"))
    block_records = []
    logger.info(f"📂 Total files to parse: {len(all_files)}")

    for idx, file in enumerate(all_files, 1):
        logger.info(f"🔍 Parsing file {idx}/{len(all_files)}: {file.name}")
        try:
            blocks = parse_chapter_blocks(file)
            for block in blocks:
                meta = extract_metadata(block, file.name)
                block_records.append(meta)
        except Exception as e:
            logger.error(f"❌ Failed to parse {file.name}: {e}")

    df = pd.DataFrame(block_records)
    df.to_csv(META_CSV, index=False)
    logger.info(f"📊 Metadata CSV saved: {META_CSV}")

    # Stratified shuffling based on entropy
    df = df.sort_values("entropy")
    bucketed = []
    BUCKETS = 5
    bucket_size = len(df) // BUCKETS
    for i in range(BUCKETS):
        start = i * bucket_size
        end = (i + 1) * bucket_size if i < BUCKETS - 1 else len(df)
        bucket = df.iloc[start:end].sample(frac=1, random_state=RANDOM_SEED)
        bucketed.append(bucket)
    df_shuffled = pd.concat(bucketed).reset_index(drop=True)

    total_tokens = df_shuffled["tokens"].sum()
    train_tokens_target = total_tokens * SPLIT_RATIO
    cum_tokens, train_idx = 0, 0
    for i, row in df_shuffled.iterrows():
        cum_tokens += row["tokens"]
        if cum_tokens >= train_tokens_target:
            train_idx = i
            break

    df_train = df_shuffled.iloc[:train_idx+1]
    df_val = df_shuffled.iloc[train_idx+1:]

    with open(TRAIN_PATH, 'w', encoding='utf-8') as f:
        f.write("\n\n".join(df_train["text"]))
    with open(VAL_PATH, 'w', encoding='utf-8') as f:
        f.write("\n\n".join(df_val["text"]))

    df_train[["filename", "block_hash"]].to_csv(TRAIN_FILES, index=False)
    df_val[["filename", "block_hash"]].to_csv(VAL_FILES, index=False)

    # Tag balance
    def flatten_tags(tag_list):
        return [tag for sublist in tag_list for tag in sublist]
    train_tag_freq = Counter(flatten_tags(df_train["tags"]))
    val_tag_freq = Counter(flatten_tags(df_val["tags"]))

    all_tags = sorted(set(train_tag_freq.keys()).union(set(val_tag_freq.keys())))
    balance_df = pd.DataFrame({
        "tag": all_tags,
        "train_count": [train_tag_freq.get(t, 0) for t in all_tags],
        "val_count": [val_tag_freq.get(t, 0) for t in all_tags]
    })
    balance_df.to_csv(PHASE3_DIR / "tag_balance.csv", index=False)

    # Plot tag comparison
    balance_df.set_index("tag").plot(kind="bar", figsize=(14, 6), title="Tag Balance: Train vs Val")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(BALANCE_PLOT)
    plt.close()

    # Summary Log
    with open(BALANCE_REPORT, 'w', encoding='utf-8') as f:
        f.write(f"Total Blocks: {len(df)}\n")
        f.write(f"Train Blocks: {len(df_train)}, Tokens: {df_train['tokens'].sum()}\n")
        f.write(f"Val Blocks:   {len(df_val)}, Tokens: {df_val['tokens'].sum()}\n")
        f.write(f"Train Mean Entropy: {df_train['entropy'].mean():.2f}\n")
        f.write(f"Val Mean Entropy:   {df_val['entropy'].mean():.2f}\n")
        f.write("\nMissing Tags in Val:\n")
        missing_tags = [t for t in all_tags if val_tag_freq.get(t, 0) == 0]
        for t in missing_tags:
            f.write(f"❌ {t}\n")

    logger.info("\n🎯 PHASE 3 SEMANTIC SPLIT COMPLETE")
    logger.info(f"📂 Train set saved: {TRAIN_PATH}")
    logger.info(f"📂 Val set saved: {VAL_PATH}")
    logger.info(f"📊 Metadata: {META_CSV}")
    logger.info(f"🧠 Balance report: {BALANCE_REPORT}")
    logger.info(f"🖼️ Tag Plot: {BALANCE_PLOT}")

if __name__ == "__main__":
    main()
# Out:
# [2025-07-27 01:06:42,955] INFO: 📂 Total files to parse: 7524
# [2025-07-27 01:06:42,955] INFO: 📂 Total files to parse: 7524
# [2025-07-27 01:06:42,955] INFO: 🔍 Parsing file 1/7524: 01 Harry Potter and the Sorcerers Stone.txt
# [2025-07-27 01:06:42,955] INFO: 🔍 Parsing file 1/7524: 01 Harry Potter and the Sorcerers Stone.txt
# [2025-07-27 01:06:43,032] INFO: 🔍 Parsing file 2/7524: 02 Harry Potter and the Chamber of Secrets.txt
# [2025-07-27 01:06:43,032] INFO: 🔍 Parsing file 2/7524: 02 Harry Potter and the Chamber of Secrets.txt
# [2025-07-27 01:06:43,074] INFO: 🔍 Parsing file 3/7524: 03 Harry Potter and the Prisoner of Azkaban.txt
# [2025-07-27 01:06:43,074] INFO: 🔍 Parsing file 3/7524: 03 Harry Potter and the Prisoner of Azkaban.txt
# [2025-07-27 01:06:43,108] INFO: 🔍 Parsing file 4/7524: 04 Harry Potter and the Goblet of Fire.txt
# [2025-07-27 01:06:43,108] INFO: 🔍 Parsing file 4/7524: 04 Harry Potter and the Goblet of Fire.txt
# [2025-07-27 01:06:43,142] INFO: 🔍 Parsing file 5/7524: 05 Harry Potter and the Order of the Phoenix.txt
# [2025-07-27 01:06:43,142] INFO: 🔍 Parsing file 5/7524: 05 Harry Potter and the Order of the Phoenix.txt
# [2025-07-27 01:06:43,222] INFO: 🔍 Parsing file 6/7524: 06 Harry Potter and the Half-Blood Prince.txt
# [2025-07-27 01:06:43,222] INFO: 🔍 Parsing file 6/7524: 06 Harry Potter and the Half-Blood Prince.txt
# [2025-07-27 01:06:43,267] INFO: 🔍 Parsing file 7/7524: 07 Harry Potter and the Deathly Hallows.txt
# [2025-07-27 01:06:43,267] INFO: 🔍 Parsing file 7/7524: 07 Harry Potter and the Deathly Hallows.txt
# [2025-07-27 01:06:43,315] INFO: 🔍 Parsing file 8/7524: 1000 Mythological Characters Briefly Described.txt
# [2025-07-27 01:06:43,315] INFO: 🔍 Parsing file 8/7524: 1000 Mythological Characters Briefly Described.txt
# [2025-07-27 01:06:43,341] INFO: 🔍 Parsing file 9/7524: 10004_the_warriors__by_anna_robertson_brown_li.txt
# [2025-07-27 01:06:43,341] INFO: 🔍 Parsing file 9/7524: 10004_the_warriors__by_anna_robertson_brown_li.txt
# [2025-07-27 01:06:43,360] INFO: 🔍 Parsing file 10/7524: 10011_365_foreign_dishes__by_unknown_author.txt
# [2025-07-27 01:06:43,360] INFO: 🔍 Parsing file 10/7524: 10011_365_foreign_dishes__by_unknown_author.txt
# [2025-07-27 01:06:43,381] INFO: 🔍 Parsing file 11/7524: 1001_divine_comedy__inferno__by_dante_alighie.txt
# [2025-07-27 01:06:43,381] INFO: 🔍 Parsing file 11/7524: 1001_divine_comedy__inferno__by_dante_alighie.txt
# [2025-07-27 01:06:43,407] INFO: 🔍 Parsing file 12/7524: 1002_divine_comedy__purgatory__by_dante_aligh.txt
# [2025-07-27 01:06:43,407] INFO: 🔍 Parsing file 12/7524: 1002_divine_comedy__purgatory__by_dante_aligh.txt
# [2025-07-27 01:06:43,431] INFO: 🔍 Parsing file 13/7524: 1003_divine_comedy__paradise__by_dante_alighi.txt
# [2025-07-27 01:06:43,431] INFO: 🔍 Parsing file 13/7524: 1003_divine_comedy__paradise__by_dante_alighi.txt
# [2025-07-27 01:06:43,451] INFO: 🔍 Parsing file 14/7524: 10042_the_child_under_eight__by_e__r__murray_a.txt
# [2025-07-27 01:06:43,451] INFO: 🔍 Parsing file 14/7524: 10042_the_child_under_eight__by_e__r__murray_a.txt
# [2025-07-27 01:06:43,480] INFO: 🔍 Parsing file 15/7524: 10044_chronicles_of_canada__volume_12_of_32__t.txt
# [2025-07-27 01:06:43,480] INFO: 🔍 Parsing file 15/7524: 10044_chronicles_of_canada__volume_12_of_32__t.txt
# [2025-07-27 01:06:43,510] INFO: 🔍 Parsing file 16/7524: 10046_salute_to_adventurers__by_john_buchan.txt
# [2025-07-27 01:06:43,510] INFO: 🔍 Parsing file 16/7524: 10046_salute_to_adventurers__by_john_buchan.txt
# [2025-07-27 01:06:43,537] INFO: 🔍 Parsing file 17/7524: 1004_divine_comedy__complete__by_dante_alighi.txt
# [2025-07-27 01:06:43,537] INFO: 🔍 Parsing file 17/7524: 1004_divine_comedy__complete__by_dante_alighi.txt
# [2025-07-27 01:06:43,580] INFO: 🔍 Parsing file 18/7524: 10053_la_vampire__by_paul_h__c__feval.txt
# [2025-07-27 01:06:43,580] INFO: 🔍 Parsing file 18/7524: 10053_la_vampire__by_paul_h__c__feval.txt
# [2025-07-27 01:06:43,614] INFO: 🔍 Parsing file 19/7524: 10055_hamburgische_dramaturgie__by_gotthold_ep.txt
# [2025-07-27 01:06:43,614] INFO: 🔍 Parsing file 19/7524: 10055_hamburgische_dramaturgie__by_gotthold_ep.txt
# [2025-07-27 01:06:43,663] INFO: 🔍 Parsing file 20/7524: 10056_chinese_literature__by_anonymous.txt
# [2025-07-27 01:06:43,663] INFO: 🔍 Parsing file 20/7524: 10056_chinese_literature__by_anonymous.txt
# [2025-07-27 01:06:43,701] INFO: 🔍 Parsing file 21/7524: 10058_the_divine_office__by_rev__e__j__quigley.txt
# [2025-07-27 01:06:43,701] INFO: 🔍 Parsing file 21/7524: 10058_the_divine_office__by_rev__e__j__quigley.txt
# [2025-07-27 01:06:43,722] INFO: 🔍 Parsing file 22/7524: 1005_divine_comedy__hell__by_dante_alighieri.txt
# [2025-07-27 01:06:43,722] INFO: 🔍 Parsing file 22/7524: 1005_divine_comedy__hell__by_dante_alighieri.txt
# [2025-07-27 01:06:43,750] INFO: 🔍 Parsing file 23/7524: 10069_account_of_the_romansh_language__by_jose.txt
# [2025-07-27 01:06:43,750] INFO: 🔍 Parsing file 23/7524: 10069_account_of_the_romansh_language__by_jose.txt
# [2025-07-27 01:06:43,768] INFO: 🔍 Parsing file 24/7524: 1006_divine_comedy__purgatory__by_dante_aligh.txt
# [2025-07-27 01:06:43,768] INFO: 🔍 Parsing file 24/7524: 1006_divine_comedy__purgatory__by_dante_aligh.txt
# [2025-07-27 01:06:43,788] INFO: 🔍 Parsing file 25/7524: 10070_stories_of_great_americans_for_little_am.txt
# [2025-07-27 01:06:43,788] INFO: 🔍 Parsing file 25/7524: 10070_stories_of_great_americans_for_little_am.txt
# [2025-07-27 01:06:43,812] INFO: 🔍 Parsing file 26/7524: 10075_a_narrative_of_the_life_and_adventures_o.txt
# [2025-07-27 01:06:43,812] INFO: 🔍 Parsing file 26/7524: 10075_a_narrative_of_the_life_and_adventures_o.txt
# [2025-07-27 01:06:43,830] INFO: 🔍 Parsing file 27/7524: 10076_lister_s_great_adventure__by_harold_bind.txt
# [2025-07-27 01:06:43,830] INFO: 🔍 Parsing file 27/7524: 10076_lister_s_great_adventure__by_harold_bind.txt
# [2025-07-27 01:06:43,861] INFO: 🔍 Parsing file 28/7524: 1007_divine_comedy__paradise__by_dante_alighi.txt
# [2025-07-27 01:06:43,861] INFO: 🔍 Parsing file 28/7524: 1007_divine_comedy__paradise__by_dante_alighi.txt
# [2025-07-27 01:06:43,882] INFO: 🔍 Parsing file 29/7524: 10082_the_hampstead_mystery__by_john_r__watson.txt
# [2025-07-27 01:06:43,882] INFO: 🔍 Parsing file 29/7524: 10082_the_hampstead_mystery__by_john_r__watson.txt
# [2025-07-27 01:06:43,920] INFO: 🔍 Parsing file 30/7524: 10089_elves_and_heroes__by_donald_a__mackenzie.txt
# [2025-07-27 01:06:43,920] INFO: 🔍 Parsing file 30/7524: 10089_elves_and_heroes__by_donald_a__mackenzie.txt
# [2025-07-27 01:06:43,934] INFO: 🔍 Parsing file 31/7524: 1008_divine_comedy__complete__by_dante_alighi.txt
# [2025-07-27 01:06:43,934] INFO: 🔍 Parsing file 31/7524: 1008_divine_comedy__complete__by_dante_alighi.txt
# [2025-07-27 01:06:43,985] INFO: 🔍 Parsing file 32/7524: 10095_the_twilight_of_the_gods__and_other_tale.txt
# [2025-07-27 01:06:43,985] INFO: 🔍 Parsing file 32/7524: 10095_the_twilight_of_the_gods__and_other_tale.txt
# [2025-07-27 01:06:44,018] INFO: 🔍 Parsing file 33/7524: 10096_the_trojan_women__by_euripides.txt
# [2025-07-27 01:06:44,018] INFO: 🔍 Parsing file 33/7524: 10096_the_trojan_women__by_euripides.txt
# [2025-07-27 01:06:44,042] INFO: 🔍 Parsing file 34/7524: 10130_the_works_of_charles_and_mary_lamb__vol_.txt
# [2025-07-27 01:06:44,042] INFO: 🔍 Parsing file 34/7524: 10130_the_works_of_charles_and_mary_lamb__vol_.txt
# [2025-07-27 01:06:44,103] INFO: 🔍 Parsing file 35/7524: 10148_the_merry_adventures_of_robin_hood__by_h.txt
# [2025-07-27 01:06:44,103] INFO: 🔍 Parsing file 35/7524: 10148_the_merry_adventures_of_robin_hood__by_h.txt
# [2025-07-27 01:06:44,137] INFO: 🔍 Parsing file 36/7524: 10214_introduction_to_the_philosophy_and_writi.txt
# [2025-07-27 01:06:44,137] INFO: 🔍 Parsing file 36/7524: 10214_introduction_to_the_philosophy_and_writi.txt
# [2025-07-27 01:06:44,173] INFO: 🔍 Parsing file 37/7524: 10315_persian_literature__volume_1__comprising.txt
# [2025-07-27 01:06:44,173] INFO: 🔍 Parsing file 37/7524: 10315_persian_literature__volume_1__comprising.txt
# [2025-07-27 01:06:44,214] INFO: 🔍 Parsing file 38/7524: 10316_roy_blakeley_s_adventures_in_camp__by_pe.txt
# [2025-07-27 01:06:44,214] INFO: 🔍 Parsing file 38/7524: 10316_roy_blakeley_s_adventures_in_camp__by_pe.txt
# [2025-07-27 01:06:44,247] INFO: 🔍 Parsing file 39/7524: 10335_children_s_rights__by_kate_douglas_wiggi.txt
# [2025-07-27 01:06:44,247] INFO: 🔍 Parsing file 39/7524: 10335_children_s_rights__by_kate_douglas_wiggi.txt
# [2025-07-27 01:06:44,275] INFO: 🔍 Parsing file 40/7524: 10360_kitty_s_class_day_and_other_stories__by_.txt
# [2025-07-27 01:06:44,275] INFO: 🔍 Parsing file 40/7524: 10360_kitty_s_class_day_and_other_stories__by_.txt
# [2025-07-27 01:06:44,312] INFO: 🔍 Parsing file 41/7524: 10366_freedom_s_battle__by_mahatma_gandhi.txt
# [2025-07-27 01:06:44,312] INFO: 🔍 Parsing file 41/7524: 10366_freedom_s_battle__by_mahatma_gandhi.txt
# [2025-07-27 01:06:44,344] INFO: 🔍 Parsing file 42/7524: 10376_american_indian_stories__by_zitkala_sa.txt
# [2025-07-27 01:06:44,344] INFO: 🔍 Parsing file 42/7524: 10376_american_indian_stories__by_zitkala_sa.txt
# [2025-07-27 01:06:44,365] INFO: 🔍 Parsing file 43/7524: 10380_bible_stories_and_religious_classics__by.txt
# [2025-07-27 01:06:44,365] INFO: 🔍 Parsing file 43/7524: 10380_bible_stories_and_religious_classics__by.txt
# [2025-07-27 01:06:44,430] INFO: 🔍 Parsing file 44/7524: 10383_the_maternal_management_of_children__in_.txt
# [2025-07-27 01:06:44,430] INFO: 🔍 Parsing file 44/7524: 10383_the_maternal_management_of_children__in_.txt
# [2025-07-27 01:06:44,458] INFO: 🔍 Parsing file 45/7524: 10387_the_real_america_in_romance__volume_6__a.txt
# [2025-07-27 01:06:44,458] INFO: 🔍 Parsing file 45/7524: 10387_the_real_america_in_romance__volume_6__a.txt
# [2025-07-27 01:06:44,489] INFO: 🔍 Parsing file 46/7524: 10398_the_american_child__by_elizabeth_mccrack.txt
# [2025-07-27 01:06:44,489] INFO: 🔍 Parsing file 46/7524: 10398_the_american_child__by_elizabeth_mccrack.txt
# [2025-07-27 01:06:44,505] INFO: 🔍 Parsing file 47/7524: 10440_tutt_and_mr__tutt__by_arthur_train.txt
# [2025-07-27 01:06:44,505] INFO: 🔍 Parsing file 47/7524: 10440_tutt_and_mr__tutt__by_arthur_train.txt
# [2025-07-27 01:06:44,540] INFO: 🔍 Parsing file 48/7524: 10446_the_green_flag__by_arthur_conan_doyle.txt
# [2025-07-27 01:06:44,540] INFO: 🔍 Parsing file 48/7524: 10446_the_green_flag__by_arthur_conan_doyle.txt
# [2025-07-27 01:06:44,575] INFO: 🔍 Parsing file 49/7524: 10449_burnham_breaker__by_homer_greene.txt
# [2025-07-27 01:06:44,575] INFO: 🔍 Parsing file 49/7524: 10449_burnham_breaker__by_homer_greene.txt
# [2025-07-27 01:06:44,608] INFO: 🔍 Parsing file 50/7524: 10454_tales_for_young_and_old__by_various.txt
# [2025-07-27 01:06:44,608] INFO: 🔍 Parsing file 50/7524: 10454_tales_for_young_and_old__by_various.txt
# [2025-07-27 01:06:44,646] INFO: 🔍 Parsing file 51/7524: 10459_the_celtic_twilight__by_w__b__yeats.txt
# [2025-07-27 01:06:44,646] INFO: 🔍 Parsing file 51/7524: 10459_the_celtic_twilight__by_w__b__yeats.txt
# [2025-07-27 01:06:44,670] INFO: 🔍 Parsing file 52/7524: 10463_the_little_house_in_the_fairy_wood__by_e.txt
# [2025-07-27 01:06:44,670] INFO: 🔍 Parsing file 52/7524: 10463_the_little_house_in_the_fairy_wood__by_e.txt
# [2025-07-27 01:06:44,690] INFO: 🔍 Parsing file 53/7524: 10464_a_child_s_anti_slavery_book__by_various.txt
# [2025-07-27 01:06:44,690] INFO: 🔍 Parsing file 53/7524: 10464_a_child_s_anti_slavery_book__by_various.txt
# [2025-07-27 01:06:44,714] INFO: 🔍 Parsing file 54/7524: 10466_little_saint_elizabeth_and_other_stories.txt
# [2025-07-27 01:06:44,714] INFO: 🔍 Parsing file 54/7524: 10466_little_saint_elizabeth_and_other_stories.txt
# [2025-07-27 01:06:44,739] INFO: 🔍 Parsing file 55/7524: 10472_arthurian_chronicles__roman_de_brut__by_.txt
# [2025-07-27 01:06:44,739] INFO: 🔍 Parsing file 55/7524: 10472_arthurian_chronicles__roman_de_brut__by_.txt
# [2025-07-27 01:06:44,762] INFO: 🔍 Parsing file 56/7524: 10483_short_stories_old_and_new__by_various.txt
# [2025-07-27 01:06:44,762] INFO: 🔍 Parsing file 56/7524: 10483_short_stories_old_and_new__by_various.txt
# [2025-07-27 01:06:44,812] INFO: 🔍 Parsing file 57/7524: 10490_the_golden_legend__by_henry_wadsworth_lo.txt
# [2025-07-27 01:06:44,812] INFO: 🔍 Parsing file 57/7524: 10490_the_golden_legend__by_henry_wadsworth_lo.txt
# [2025-07-27 01:06:44,839] INFO: 🔍 Parsing file 58/7524: 10506_romance_de_lobos__comedia_barbara__by_ra.txt
# [2025-07-27 01:06:44,839] INFO: 🔍 Parsing file 58/7524: 10506_romance_de_lobos__comedia_barbara__by_ra.txt
# [2025-07-27 01:06:44,866] INFO: 🔍 Parsing file 59/7524: 10508_the_sorrows_of_a_show_girl__by_kenneth_m.txt
# [2025-07-27 01:06:44,866] INFO: 🔍 Parsing file 59/7524: 10508_the_sorrows_of_a_show_girl__by_kenneth_m.txt
# [2025-07-27 01:06:44,886] INFO: 🔍 Parsing file 60/7524: 10523_alcestis__by_euripides.txt
# [2025-07-27 01:06:44,886] INFO: 🔍 Parsing file 60/7524: 10523_alcestis__by_euripides.txt
# [2025-07-27 01:06:44,906] INFO: 🔍 Parsing file 61/7524: 10541_children_s_classics_in_dramatic_form__by.txt
# [2025-07-27 01:06:44,906] INFO: 🔍 Parsing file 61/7524: 10541_children_s_classics_in_dramatic_form__by.txt
# [2025-07-27 01:06:44,932] INFO: 🔍 Parsing file 62/7524: 10548_the_westcotes__by_arthur_thomas_quiller_.txt
# [2025-07-27 01:06:44,932] INFO: 🔍 Parsing file 62/7524: 10548_the_westcotes__by_arthur_thomas_quiller_.txt
# [2025-07-27 01:06:44,962] INFO: 🔍 Parsing file 63/7524: 10549_a_romance_of_the_republic__by_lydia_mari.txt
# [2025-07-27 01:06:44,962] INFO: 🔍 Parsing file 63/7524: 10549_a_romance_of_the_republic__by_lydia_mari.txt
# [2025-07-27 01:06:45,003] INFO: 🔍 Parsing file 64/7524: 10564_fairy_gold__by_w__w__jacobs.txt
# [2025-07-27 01:06:45,003] INFO: 🔍 Parsing file 64/7524: 10564_fairy_gold__by_w__w__jacobs.txt
# [2025-07-27 01:06:45,032] INFO: 🔍 Parsing file 65/7524: 10581_uncle_bernac__by_arthur_conan_doyle.txt
# [2025-07-27 01:06:45,032] INFO: 🔍 Parsing file 65/7524: 10581_uncle_bernac__by_arthur_conan_doyle.txt
# [2025-07-27 01:06:45,072] INFO: 🔍 Parsing file 66/7524: 10588_seeing_europe_with_famous_authors__volum.txt
# [2025-07-27 01:06:45,072] INFO: 🔍 Parsing file 66/7524: 10588_seeing_europe_with_famous_authors__volum.txt
# [2025-07-27 01:06:45,102] INFO: 🔍 Parsing file 67/7524: 10592_adventures_in_friendship__by_david_grays.txt
# [2025-07-27 01:06:45,102] INFO: 🔍 Parsing file 67/7524: 10592_adventures_in_friendship__by_david_grays.txt
# [2025-07-27 01:06:45,129] INFO: 🔍 Parsing file 68/7524: 10605_adventures_in_contentment__by_david_gray.txt
# [2025-07-27 01:06:45,129] INFO: 🔍 Parsing file 68/7524: 10605_adventures_in_contentment__by_david_gray.txt
# [2025-07-27 01:06:45,164] INFO: 🔍 Parsing file 69/7524: 10608_the_turquoise_cup__and__the_desert__by_a.txt
# [2025-07-27 01:06:45,164] INFO: 🔍 Parsing file 69/7524: 10608_the_turquoise_cup__and__the_desert__by_a.txt
# [2025-07-27 01:06:45,182] INFO: 🔍 Parsing file 70/7524: 10624_three_john_silence_stories__by_algernon_.txt
# [2025-07-27 01:06:45,182] INFO: 🔍 Parsing file 70/7524: 10624_three_john_silence_stories__by_algernon_.txt
# [2025-07-27 01:06:45,221] INFO: 🔍 Parsing file 71/7524: 10659_three_more_john_silence_stories__by_alge.txt
# [2025-07-27 01:06:45,221] INFO: 🔍 Parsing file 71/7524: 10659_three_more_john_silence_stories__by_alge.txt
# [2025-07-27 01:06:45,242] INFO: 🔍 Parsing file 72/7524: 10661_selection_from_the_discourses_of_epictet.txt
# [2025-07-27 01:06:45,242] INFO: 🔍 Parsing file 72/7524: 10661_selection_from_the_discourses_of_epictet.txt
# [2025-07-27 01:06:45,268] INFO: 🔍 Parsing file 73/7524: 10665_life__letters__and_epicurean_philosophy_.txt
# [2025-07-27 01:06:45,268] INFO: 🔍 Parsing file 73/7524: 10665_life__letters__and_epicurean_philosophy_.txt
# [2025-07-27 01:06:45,302] INFO: 🔍 Parsing file 74/7524: 10677_biographical_memorials_of_james_oglethor.txt
# [2025-07-27 01:06:45,302] INFO: 🔍 Parsing file 74/7524: 10677_biographical_memorials_of_james_oglethor.txt
# [2025-07-27 01:06:45,333] INFO: 🔍 Parsing file 75/7524: 10700_the_history_of_england_from_the_first_in.txt
# [2025-07-27 01:06:45,333] INFO: 🔍 Parsing file 75/7524: 10700_the_history_of_england_from_the_first_in.txt
# [2025-07-27 01:06:45,378] INFO: 🔍 Parsing file 76/7524: 10714_the_art_of_literature__by_arthur_schopen.txt
# [2025-07-27 01:06:45,378] INFO: 🔍 Parsing file 76/7524: 10714_the_art_of_literature__by_arthur_schopen.txt
# [2025-07-27 01:06:45,399] INFO: 🔍 Parsing file 77/7524: 10715_counsels_and_maxims__by_arthur_schopenha.txt
# [2025-07-27 01:06:45,399] INFO: 🔍 Parsing file 77/7524: 10715_counsels_and_maxims__by_arthur_schopenha.txt
# [2025-07-27 01:06:45,421] INFO: 🔍 Parsing file 78/7524: 10716_the_epic__by_lascelles_abercrombie.txt
# [2025-07-27 01:06:45,421] INFO: 🔍 Parsing file 78/7524: 10716_the_epic__by_lascelles_abercrombie.txt
# [2025-07-27 01:06:45,434] INFO: 🔍 Parsing file 79/7524: 10731_the_essays_of_arthur_schopenhauer__the_a.txt
# [2025-07-27 01:06:45,434] INFO: 🔍 Parsing file 79/7524: 10731_the_essays_of_arthur_schopenhauer__the_a.txt
# [2025-07-27 01:06:45,460] INFO: 🔍 Parsing file 80/7524: 10732_the_essays_of_arthur_schopenhauer__studi.txt
# [2025-07-27 01:06:45,460] INFO: 🔍 Parsing file 80/7524: 10732_the_essays_of_arthur_schopenhauer__studi.txt
# [2025-07-27 01:06:45,480] INFO: 🔍 Parsing file 81/7524: 10735_christmas_eve_on_lonesome_and_other_stor.txt
# [2025-07-27 01:06:45,480] INFO: 🔍 Parsing file 81/7524: 10735_christmas_eve_on_lonesome_and_other_stor.txt
# [2025-07-27 01:06:45,500] INFO: 🔍 Parsing file 82/7524: 10736_children_of_the_frost__by_jack_london.txt
# [2025-07-27 01:06:45,500] INFO: 🔍 Parsing file 82/7524: 10736_children_of_the_frost__by_jack_london.txt
# [2025-07-27 01:06:45,525] INFO: 🔍 Parsing file 83/7524: 10739_the_essays_of_arthur_schopenhauer__by_ar.txt
# [2025-07-27 01:06:45,525] INFO: 🔍 Parsing file 83/7524: 10739_the_essays_of_arthur_schopenhauer__by_ar.txt
# [2025-07-27 01:06:45,538] INFO: 🔍 Parsing file 84/7524: 10741_essays_of_arthur_schopenhauer__the_wisdo.txt
# [2025-07-27 01:06:45,538] INFO: 🔍 Parsing file 84/7524: 10741_essays_of_arthur_schopenhauer__the_wisdo.txt
# [2025-07-27 01:06:45,563] INFO: 🔍 Parsing file 85/7524: 10744_men__women__and_ghosts__by_elizabeth_stu.txt
# [2025-07-27 01:06:45,563] INFO: 🔍 Parsing file 85/7524: 10744_men__women__and_ghosts__by_elizabeth_stu.txt
# [2025-07-27 01:06:45,600] INFO: 🔍 Parsing file 86/7524: 10747_chantecler__by_edmond_rostand.txt
# [2025-07-27 01:06:45,600] INFO: 🔍 Parsing file 86/7524: 10747_chantecler__by_edmond_rostand.txt
# [2025-07-27 01:06:45,628] INFO: 🔍 Parsing file 87/7524: 10765_thrilling_adventures_by_land_and_sea__by.txt
# [2025-07-27 01:06:45,628] INFO: 🔍 Parsing file 87/7524: 10765_thrilling_adventures_by_land_and_sea__by.txt
# [2025-07-27 01:06:45,669] INFO: 🔍 Parsing file 88/7524: 10771_philippine_folklore_stories__by_john_mau.txt
# [2025-07-27 01:06:45,669] INFO: 🔍 Parsing file 88/7524: 10771_philippine_folklore_stories__by_john_mau.txt
# [2025-07-27 01:06:45,686] INFO: 🔍 Parsing file 89/7524: 10773_ancient_and_modern_physics__by_thomas_e_.txt
# [2025-07-27 01:06:45,686] INFO: 🔍 Parsing file 89/7524: 10773_ancient_and_modern_physics__by_thomas_e_.txt
# [2025-07-27 01:06:45,707] INFO: 🔍 Parsing file 90/7524: 10775_le_horla_and_other_stories__by_guy_de_ma.txt
# [2025-07-27 01:06:45,707] INFO: 🔍 Parsing file 90/7524: 10775_le_horla_and_other_stories__by_guy_de_ma.txt
# [2025-07-27 01:06:45,726] INFO: 🔍 Parsing file 91/7524: 10800_the_anatomy_of_melancholy__by_democritus.txt
# [2025-07-27 01:06:45,726] INFO: 🔍 Parsing file 91/7524: 10800_the_anatomy_of_melancholy__by_democritus.txt
# [2025-07-27 01:06:45,827] INFO: 🔍 Parsing file 92/7524: 10806_the_sword_of_welleran_and_other_stories_.txt
# [2025-07-27 01:06:45,827] INFO: 🔍 Parsing file 92/7524: 10806_the_sword_of_welleran_and_other_stories_.txt
# [2025-07-27 01:06:45,852] INFO: 🔍 Parsing file 93/7524: 10814_legends__tales_and_poems__by_gustavo_ado.txt
# [2025-07-27 01:06:45,852] INFO: 🔍 Parsing file 93/7524: 10814_legends__tales_and_poems__by_gustavo_ado.txt
# [2025-07-27 01:06:45,885] INFO: 🔍 Parsing file 94/7524: 10824_un_tournoi_a_romans_en_1484__by_ulysse_c.txt
# [2025-07-27 01:06:45,885] INFO: 🔍 Parsing file 94/7524: 10824_un_tournoi_a_romans_en_1484__by_ulysse_c.txt
# [2025-07-27 01:06:45,908] INFO: 🔍 Parsing file 95/7524: 10828_roman_history__books_1_3__by_titus_liviu.txt
# [2025-07-27 01:06:45,908] INFO: 🔍 Parsing file 95/7524: 10828_roman_history__books_1_3__by_titus_liviu.txt
# [2025-07-27 01:06:45,940] INFO: 🔍 Parsing file 96/7524: 10832_carnacki__the_ghost_finder__by_william_h.txt
# [2025-07-27 01:06:45,940] INFO: 🔍 Parsing file 96/7524: 10832_carnacki__the_ghost_finder__by_william_h.txt
# [2025-07-27 01:06:45,976] INFO: 🔍 Parsing file 97/7524: 10833_the_essays_of_arthur_schopenhauer__relig.txt
# [2025-07-27 01:06:45,976] INFO: 🔍 Parsing file 97/7524: 10833_the_essays_of_arthur_schopenhauer__relig.txt
# [2025-07-27 01:06:45,995] INFO: 🔍 Parsing file 98/7524: 10835_dr__johnson_s_works__life__poems__and_ta.txt
# [2025-07-27 01:06:45,995] INFO: 🔍 Parsing file 98/7524: 10835_dr__johnson_s_works__life__poems__and_ta.txt
# [2025-07-27 01:06:46,034] INFO: 🔍 Parsing file 99/7524: 10837_the_soul_of_democracy__by_edward_howard_.txt
# [2025-07-27 01:06:46,034] INFO: 🔍 Parsing file 99/7524: 10837_the_soul_of_democracy__by_edward_howard_.txt
# [2025-07-27 01:06:46,052] INFO: 🔍 Parsing file 100/7524: 10842_the_life_of_captain_james_cook__by_arthu.txt
# [2025-07-27 01:06:46,052] INFO: 🔍 Parsing file 100/7524: 10842_the_life_of_captain_james_cook__by_arthu.txt
# [2025-07-27 01:06:46,082] INFO: 🔍 Parsing file 101/7524: 10847_the_maids_tragedy__by_francis_beaumont_a.txt
# [2025-07-27 01:06:46,082] INFO: 🔍 Parsing file 101/7524: 10847_the_maids_tragedy__by_francis_beaumont_a.txt
# [2025-07-27 01:06:46,094] INFO: 🔍 Parsing file 102/7524: 10877_the_tragedies_of_the_medici__by_edgcumbe.txt
# [2025-07-27 01:06:46,094] INFO: 🔍 Parsing file 102/7524: 10877_the_tragedies_of_the_medici__by_edgcumbe.txt
# [2025-07-27 01:06:46,121] INFO: 🔍 Parsing file 103/7524: 10887_babylonian_and_assyrian_literature__by_a.txt
# [2025-07-27 01:06:46,121] INFO: 🔍 Parsing file 103/7524: 10887_babylonian_and_assyrian_literature__by_a.txt
# [2025-07-27 01:06:46,154] INFO: 🔍 Parsing file 104/7524: 10888_arthur_hamilton__and_his_dog__by_anonymo.txt
# [2025-07-27 01:06:46,154] INFO: 🔍 Parsing file 104/7524: 10888_arthur_hamilton__and_his_dog__by_anonymo.txt
# [2025-07-27 01:06:46,170] INFO: 🔍 Parsing file 105/7524: 10889_the_life_and_romances_of_mrs__eliza_hayw.txt
# [2025-07-27 01:06:46,170] INFO: 🔍 Parsing file 105/7524: 10889_the_life_and_romances_of_mrs__eliza_hayw.txt
# [2025-07-27 01:06:46,193] INFO: 🔍 Parsing file 106/7524: 10891_algonquin_indian_tales__by_egerton_r__yo.txt
# [2025-07-27 01:06:46,193] INFO: 🔍 Parsing file 106/7524: 10891_algonquin_indian_tales__by_egerton_r__yo.txt
# [2025-07-27 01:06:46,225] INFO: 🔍 Parsing file 107/7524: 10911_buried_alive__a_tale_of_these_days__by_a.txt
# [2025-07-27 01:06:46,225] INFO: 🔍 Parsing file 107/7524: 10911_buried_alive__a_tale_of_these_days__by_a.txt
# [2025-07-27 01:06:46,257] INFO: 🔍 Parsing file 108/7524: 10915_the_girl_s_cabinet_of_instructive_and_mo.txt
# [2025-07-27 01:06:46,257] INFO: 🔍 Parsing file 108/7524: 10915_the_girl_s_cabinet_of_instructive_and_mo.txt
# [2025-07-27 01:06:46,281] INFO: 🔍 Parsing file 109/7524: 10916_parent_and_child_vol__3__child_study_and.txt
# [2025-07-27 01:06:46,281] INFO: 🔍 Parsing file 109/7524: 10916_parent_and_child_vol__3__child_study_and.txt
# [2025-07-27 01:06:46,305] INFO: 🔍 Parsing file 110/7524: 1091_heroes_and_hero_worship__by_thomas_carly.txt
# [2025-07-27 01:06:46,305] INFO: 🔍 Parsing file 110/7524: 1091_heroes_and_hero_worship__by_thomas_carly.txt
# [2025-07-27 01:06:46,329] INFO: 🔍 Parsing file 111/7524: 10926_saxe_holm_s_stories__by_helen_hunt_jacks.txt
# [2025-07-27 01:06:46,329] INFO: 🔍 Parsing file 111/7524: 10926_saxe_holm_s_stories__by_helen_hunt_jacks.txt
# [2025-07-27 01:06:46,375] INFO: 🔍 Parsing file 112/7524: 10930_the_buccaneer_farmer__by_harold_bindloss.txt
# [2025-07-27 01:06:46,375] INFO: 🔍 Parsing file 112/7524: 10930_the_buccaneer_farmer__by_harold_bindloss.txt
# [2025-07-27 01:06:46,403] INFO: 🔍 Parsing file 113/7524: 10935_the_wonderful_adventures_of_nils__by_sel.txt
# [2025-07-27 01:06:46,403] INFO: 🔍 Parsing file 113/7524: 10935_the_wonderful_adventures_of_nils__by_sel.txt
# [2025-07-27 01:06:46,427] INFO: 🔍 Parsing file 114/7524: 10941_jumalainen_naeytelmae__helvetti__by_dant.txt
# [2025-07-27 01:06:46,427] INFO: 🔍 Parsing file 114/7524: 10941_jumalainen_naeytelmae__helvetti__by_dant.txt
# [2025-07-27 01:06:46,451] INFO: 🔍 Parsing file 115/7524: 10947_the_best_american_humorous_short_stories.txt
# [2025-07-27 01:06:46,451] INFO: 🔍 Parsing file 115/7524: 10947_the_best_american_humorous_short_stories.txt
# [2025-07-27 01:06:46,483] INFO: 🔍 Parsing file 116/7524: 10948_the_stories_of_the_three_burglars__by_fr.txt
# [2025-07-27 01:06:46,483] INFO: 🔍 Parsing file 116/7524: 10948_the_stories_of_the_three_burglars__by_fr.txt
# [2025-07-27 01:06:46,501] INFO: 🔍 Parsing file 117/7524: 10949_the_romance_of_zion_chapel__3rd__ed___by.txt
# [2025-07-27 01:06:46,501] INFO: 🔍 Parsing file 117/7524: 10949_the_romance_of_zion_chapel__3rd__ed___by.txt
# [2025-07-27 01:06:46,524] INFO: 🔍 Parsing file 118/7524: 10966_the_ghost_pirates__by_william_hope_hodgs.txt
# [2025-07-27 01:06:46,524] INFO: 🔍 Parsing file 118/7524: 10966_the_ghost_pirates__by_william_hope_hodgs.txt
# [2025-07-27 01:06:46,547] INFO: 🔍 Parsing file 119/7524: 10981_child_s_new_story_book__anonymous.txt
# [2025-07-27 01:06:46,547] INFO: 🔍 Parsing file 119/7524: 10981_child_s_new_story_book__anonymous.txt
# [2025-07-27 01:06:46,560] INFO: 🔍 Parsing file 120/7524: 10987_the_adventures_of_little_bewildered_henr.txt
# [2025-07-27 01:06:46,560] INFO: 🔍 Parsing file 120/7524: 10987_the_adventures_of_little_bewildered_henr.txt
# [2025-07-27 01:06:46,573] INFO: 🔍 Parsing file 121/7524: 10988_the_devil_s_admiral__by_frederick_ferdin.txt
# [2025-07-27 01:06:46,573] INFO: 🔍 Parsing file 121/7524: 10988_the_devil_s_admiral__by_frederick_ferdin.txt
# [2025-07-27 01:06:46,609] INFO: 🔍 Parsing file 122/7524: 10999_tales_of_bengal__by_s__b__banerjea.txt
# [2025-07-27 01:06:46,609] INFO: 🔍 Parsing file 122/7524: 10999_tales_of_bengal__by_s__b__banerjea.txt
# [2025-07-27 01:06:46,628] INFO: 🔍 Parsing file 123/7524: 11000_an_old_babylonian_version_of_the_gilgame.txt
# [2025-07-27 01:06:46,628] INFO: 🔍 Parsing file 123/7524: 11000_an_old_babylonian_version_of_the_gilgame.txt
# [2025-07-27 01:06:46,656] INFO: 🔍 Parsing file 124/7524: 11008_antwerp_to_gallipoli__by_arthur_ruhl.txt
# [2025-07-27 01:06:46,656] INFO: 🔍 Parsing file 124/7524: 11008_antwerp_to_gallipoli__by_arthur_ruhl.txt
# [2025-07-27 01:06:46,707] INFO: 🔍 Parsing file 125/7524: 11014_christmas_in_legend_and_story__by_elva_s.txt
# [2025-07-27 01:06:46,707] INFO: 🔍 Parsing file 125/7524: 11014_christmas_in_legend_and_story__by_elva_s.txt
# [2025-07-27 01:06:46,730] INFO: 🔍 Parsing file 126/7524: 11016_port_of_adventure__by_charles_n__william.txt
# [2025-07-27 01:06:46,730] INFO: 🔍 Parsing file 126/7524: 11016_port_of_adventure__by_charles_n__william.txt
# [2025-07-27 01:06:46,774] INFO: 🔍 Parsing file 127/7524: 11027_grimm_s_fairy_stories__by_jacob_grimm_an.txt
# [2025-07-27 01:06:46,774] INFO: 🔍 Parsing file 127/7524: 11027_grimm_s_fairy_stories__by_jacob_grimm_an.txt
# [2025-07-27 01:06:46,795] INFO: 🔍 Parsing file 128/7524: 11028_philippine_folk_tales__by_carla_kern_bay.txt
# [2025-07-27 01:06:46,795] INFO: 🔍 Parsing file 128/7524: 11028_philippine_folk_tales__by_carla_kern_bay.txt
# [2025-07-27 01:06:46,820] INFO: 🔍 Parsing file 129/7524: 11029_american_hero_myths__by_daniel_g__brinto.txt
# [2025-07-27 01:06:46,820] INFO: 🔍 Parsing file 129/7524: 11029_american_hero_myths__by_daniel_g__brinto.txt
# [2025-07-27 01:06:46,843] INFO: 🔍 Parsing file 130/7524: 11032_wilson_s_tales_of_the_borders_and_of_sco.txt
# [2025-07-27 01:06:46,843] INFO: 🔍 Parsing file 130/7524: 11032_wilson_s_tales_of_the_borders_and_of_sco.txt
# [2025-07-27 01:06:46,876] INFO: 🔍 Parsing file 131/7524: 11036_legendes_normandes__by_gaston_lavalley.txt
# [2025-07-27 01:06:46,876] INFO: 🔍 Parsing file 131/7524: 11036_legendes_normandes__by_gaston_lavalley.txt
# [2025-07-27 01:06:46,899] INFO: 🔍 Parsing file 132/7524: 11045_the_ghost_ship__by_richard_middleton.txt
# [2025-07-27 01:06:46,899] INFO: 🔍 Parsing file 132/7524: 11045_the_ghost_ship__by_richard_middleton.txt
# [2025-07-27 01:06:46,923] INFO: 🔍 Parsing file 133/7524: 11053_minnie_s_sacrifice__by_frances_ellen_wat.txt
# [2025-07-27 01:06:46,923] INFO: 🔍 Parsing file 133/7524: 11053_minnie_s_sacrifice__by_frances_ellen_wat.txt
# [2025-07-27 01:06:46,944] INFO: 🔍 Parsing file 134/7524: 11057_the_wife_of_his_youth_and_other_stories_.txt
# [2025-07-27 01:06:46,944] INFO: 🔍 Parsing file 134/7524: 11057_the_wife_of_his_youth_and_other_stories_.txt
# [2025-07-27 01:06:46,970] INFO: 🔍 Parsing file 135/7524: 11066_graf_von_loeben_and_the_legend_of_lorele.txt
# [2025-07-27 01:06:46,970] INFO: 🔍 Parsing file 135/7524: 11066_graf_von_loeben_and_the_legend_of_lorele.txt
# [2025-07-27 01:06:46,989] INFO: 🔍 Parsing file 136/7524: 11068_the_spirit_of_the_age__by_william_hazlit.txt
# [2025-07-27 01:06:46,989] INFO: 🔍 Parsing file 136/7524: 11068_the_spirit_of_the_age__by_william_hazlit.txt
# [2025-07-27 01:06:47,018] INFO: 🔍 Parsing file 137/7524: 11072_jumalainen_naeytelmae__kiirastuli__by_da.txt
# [2025-07-27 01:06:47,018] INFO: 🔍 Parsing file 137/7524: 11072_jumalainen_naeytelmae__kiirastuli__by_da.txt
# [2025-07-27 01:06:47,044] INFO: 🔍 Parsing file 138/7524: 11092_the_history_of_tom_thumb_and_other_stori.txt
# [2025-07-27 01:06:47,044] INFO: 🔍 Parsing file 138/7524: 11092_the_history_of_tom_thumb_and_other_stori.txt
# [2025-07-27 01:06:47,057] INFO: 🔍 Parsing file 139/7524: 11096_tales_of_ind__by_t__ramakrishna.txt
# [2025-07-27 01:06:47,057] INFO: 🔍 Parsing file 139/7524: 11096_tales_of_ind__by_t__ramakrishna.txt
# [2025-07-27 01:06:47,083] INFO: 🔍 Parsing file 140/7524: 11101_coleridge_s_ancient_mariner_and_select_p.txt
# [2025-07-27 01:06:47,083] INFO: 🔍 Parsing file 140/7524: 11101_coleridge_s_ancient_mariner_and_select_p.txt
# [2025-07-27 01:06:47,103] INFO: 🔍 Parsing file 141/7524: 11110_a_countess_from_canada__by_bessie_marcha.txt
# [2025-07-27 01:06:47,103] INFO: 🔍 Parsing file 141/7524: 11110_a_countess_from_canada__by_bessie_marcha.txt
# [2025-07-27 01:06:47,152] INFO: 🔍 Parsing file 142/7524: 11129_uncle_humphrey_s_stories__by_various.txt
# [2025-07-27 01:06:47,152] INFO: 🔍 Parsing file 142/7524: 11129_uncle_humphrey_s_stories__by_various.txt
# [2025-07-27 01:06:47,178] INFO: 🔍 Parsing file 143/7524: 11144_somewhere_in_france_and_other_stories__b.txt
# [2025-07-27 01:06:47,178] INFO: 🔍 Parsing file 143/7524: 11144_somewhere_in_france_and_other_stories__b.txt
# [2025-07-27 01:06:47,196] INFO: 🔍 Parsing file 144/7524: 11146_the_expedition_of_the_donner_party_and_i.txt
# [2025-07-27 01:06:47,196] INFO: 🔍 Parsing file 144/7524: 11146_the_expedition_of_the_donner_party_and_i.txt
# [2025-07-27 01:06:47,222] INFO: 🔍 Parsing file 145/7524: 1114_the_merchant_of_venice__by_william_shake.txt
# [2025-07-27 01:06:47,222] INFO: 🔍 Parsing file 145/7524: 1114_the_merchant_of_venice__by_william_shake.txt
# [2025-07-27 01:06:47,240] INFO: 🔍 Parsing file 146/7524: 11153_no_hero__by_e__w__hornung.txt
# [2025-07-27 01:06:47,240] INFO: 🔍 Parsing file 146/7524: 11153_no_hero__by_e__w__hornung.txt
# [2025-07-27 01:06:47,266] INFO: 🔍 Parsing file 147/7524: 11156_bed_time_stories__buddy_and_brighteyes_p.txt
# [2025-07-27 01:06:47,266] INFO: 🔍 Parsing file 147/7524: 11156_bed_time_stories__buddy_and_brighteyes_p.txt
# [2025-07-27 01:06:47,283] INFO: 🔍 Parsing file 148/7524: 11160_a_cotswold_village__by_j__arthur_gibbs.txt
# [2025-07-27 01:06:47,283] INFO: 🔍 Parsing file 148/7524: 11160_a_cotswold_village__by_j__arthur_gibbs.txt
# [2025-07-27 01:06:47,310] INFO: 🔍 Parsing file 149/7524: 11165_wild_wings__a_romance_of_youth__by_marga.txt
# [2025-07-27 01:06:47,310] INFO: 🔍 Parsing file 149/7524: 11165_wild_wings__a_romance_of_youth__by_marga.txt
# [2025-07-27 01:06:47,340] INFO: 🔍 Parsing file 150/7524: 11166_for_gold_or_soul___by_lurana_w__sheldon.txt
# [2025-07-27 01:06:47,340] INFO: 🔍 Parsing file 150/7524: 11166_for_gold_or_soul___by_lurana_w__sheldon.txt
# [2025-07-27 01:06:47,357] INFO: 🔍 Parsing file 151/7524: 11167_deccan_nursery_tales__by_c__a__kincaid.txt
# [2025-07-27 01:06:47,357] INFO: 🔍 Parsing file 151/7524: 11167_deccan_nursery_tales__by_c__a__kincaid.txt
# [2025-07-27 01:06:47,381] INFO: 🔍 Parsing file 152/7524: 11179_seeing_europe_with_famous_authors__vol__.txt
# [2025-07-27 01:06:47,381] INFO: 🔍 Parsing file 152/7524: 11179_seeing_europe_with_famous_authors__vol__.txt
# [2025-07-27 01:06:47,404] INFO: 🔍 Parsing file 153/7524: 11208_de_legende_en_de_heldhaftige__vroolijke_.txt
# [2025-07-27 01:06:47,404] INFO: 🔍 Parsing file 153/7524: 11208_de_legende_en_de_heldhaftige__vroolijke_.txt
# [2025-07-27 01:06:47,470] INFO: 🔍 Parsing file 154/7524: 11239_life_and_adventures_of_robinson_crusoe_o.txt
# [2025-07-27 01:06:47,470] INFO: 🔍 Parsing file 154/7524: 11239_life_and_adventures_of_robinson_crusoe_o.txt
# [2025-07-27 01:06:47,518] INFO: 🔍 Parsing file 155/7524: 11241_wee_ones__bible_stories__by_anonymous.txt
# [2025-07-27 01:06:47,518] INFO: 🔍 Parsing file 155/7524: 11241_wee_ones__bible_stories__by_anonymous.txt
# [2025-07-27 01:06:47,535] INFO: 🔍 Parsing file 156/7524: 11247_the_exploits_of_brigadier_gerard__by_art.txt
# [2025-07-27 01:06:47,535] INFO: 🔍 Parsing file 156/7524: 11247_the_exploits_of_brigadier_gerard__by_art.txt
# [2025-07-27 01:06:47,585] INFO: 🔍 Parsing file 157/7524: 11252_martin_hewitt__investigator__by_arthur_m.txt
# [2025-07-27 01:06:47,585] INFO: 🔍 Parsing file 157/7524: 11252_martin_hewitt__investigator__by_arthur_m.txt
# [2025-07-27 01:06:47,629] INFO: 🔍 Parsing file 158/7524: 11263_the_adventures_of_a_special_corresponden.txt
# [2025-07-27 01:06:47,629] INFO: 🔍 Parsing file 158/7524: 11263_the_adventures_of_a_special_corresponden.txt
# [2025-07-27 01:06:47,659] INFO: 🔍 Parsing file 159/7524: 11277_egyptian_ideas_of_the_future_life__by_e_.txt
# [2025-07-27 01:06:47,659] INFO: 🔍 Parsing file 159/7524: 11277_egyptian_ideas_of_the_future_life__by_e_.txt
# [2025-07-27 01:06:47,679] INFO: 🔍 Parsing file 160/7524: 11278_folk_tales_of_napoleon__by_honore_de_bal.txt
# [2025-07-27 01:06:47,679] INFO: 🔍 Parsing file 160/7524: 11278_folk_tales_of_napoleon__by_honore_de_bal.txt
# [2025-07-27 01:06:47,694] INFO: 🔍 Parsing file 161/7524: 11283_plays_of_gods_and_men__by_lord_dunsany.txt
# [2025-07-27 01:06:47,694] INFO: 🔍 Parsing file 161/7524: 11283_plays_of_gods_and_men__by_lord_dunsany.txt
# [2025-07-27 01:06:47,710] INFO: 🔍 Parsing file 162/7524: 11308_the_book_of_enterprise_and_adventure__by.txt
# [2025-07-27 01:06:47,710] INFO: 🔍 Parsing file 162/7524: 11308_the_book_of_enterprise_and_adventure__by.txt
# [2025-07-27 01:06:47,730] INFO: 🔍 Parsing file 163/7524: 11310_hindu_tales_from_the_sanskrit__by_s__m__.txt
# [2025-07-27 01:06:47,730] INFO: 🔍 Parsing file 163/7524: 11310_hindu_tales_from_the_sanskrit__by_s__m__.txt
# [2025-07-27 01:06:47,751] INFO: 🔍 Parsing file 164/7524: 11319_the_fairy_godmothers_and_other_tales__by.txt
# [2025-07-27 01:06:47,751] INFO: 🔍 Parsing file 164/7524: 11319_the_fairy_godmothers_and_other_tales__by.txt
# [2025-07-27 01:06:47,771] INFO: 🔍 Parsing file 165/7524: 11334_wilson_s_tales_of_the_borders_and_of_sco.txt
# [2025-07-27 01:06:47,771] INFO: 🔍 Parsing file 165/7524: 11334_wilson_s_tales_of_the_borders_and_of_sco.txt
# [2025-07-27 01:06:47,808] INFO: 🔍 Parsing file 166/7524: 11339_aesop_s_fables__by_aesop.txt
# [2025-07-27 01:06:47,808] INFO: 🔍 Parsing file 166/7524: 11339_aesop_s_fables__by_aesop.txt
# [2025-07-27 01:06:47,827] INFO: 🔍 Parsing file 167/7524: 11346_the_saint_s_tragedy__by_charles_kingsley.txt
# [2025-07-27 01:06:47,827] INFO: 🔍 Parsing file 167/7524: 11346_the_saint_s_tragedy__by_charles_kingsley.txt
# [2025-07-27 01:06:47,858] INFO: 🔍 Parsing file 168/7524: 11356_a_tale_of_one_city__the_new_birmingham__.txt
# [2025-07-27 01:06:47,858] INFO: 🔍 Parsing file 168/7524: 11356_a_tale_of_one_city__the_new_birmingham__.txt
# [2025-07-27 01:06:47,881] INFO: 🔍 Parsing file 169/7524: 11360_sacred_and_profane_love__by_e__arnold_be.txt
# [2025-07-27 01:06:47,881] INFO: 🔍 Parsing file 169/7524: 11360_sacred_and_profane_love__by_e__arnold_be.txt
# [2025-07-27 01:06:47,915] INFO: 🔍 Parsing file 170/7524: 11368_stories_of_inventors__by_russell_doubled.txt
# [2025-07-27 01:06:47,915] INFO: 🔍 Parsing file 170/7524: 11368_stories_of_inventors__by_russell_doubled.txt
# [2025-07-27 01:06:47,939] INFO: 🔍 Parsing file 171/7524: 11396_faedra__by_herman_bang.txt
# [2025-07-27 01:06:47,939] INFO: 🔍 Parsing file 171/7524: 11396_faedra__by_herman_bang.txt
# [2025-07-27 01:06:47,964] INFO: 🔍 Parsing file 172/7524: 11400_mystic_isles_of_the_south_seas__by_fredr.txt
# [2025-07-27 01:06:47,964] INFO: 🔍 Parsing file 172/7524: 11400_mystic_isles_of_the_south_seas__by_fredr.txt
# [2025-07-27 01:06:48,000] INFO: 🔍 Parsing file 173/7524: 11413_the_refugees__by_arthur_conan_doyle.txt
# [2025-07-27 01:06:48,000] INFO: 🔍 Parsing file 173/7524: 11413_the_refugees__by_arthur_conan_doyle.txt
# [2025-07-27 01:06:48,043] INFO: 🔍 Parsing file 174/7524: 11431_character_sketches_of_romance__fiction_a.txt
# [2025-07-27 01:06:48,043] INFO: 🔍 Parsing file 174/7524: 11431_character_sketches_of_romance__fiction_a.txt
# [2025-07-27 01:06:48,092] INFO: 🔍 Parsing file 175/7524: 11436_stories_by_american_authors__vol__1__by_.txt
# [2025-07-27 01:06:48,092] INFO: 🔍 Parsing file 175/7524: 11436_stories_by_american_authors__vol__1__by_.txt
# [2025-07-27 01:06:48,111] INFO: 🔍 Parsing file 176/7524: 11437_stories_by_american_authors__vol__5__by_.txt
# [2025-07-27 01:06:48,111] INFO: 🔍 Parsing file 176/7524: 11437_stories_by_american_authors__vol__5__by_.txt
# [2025-07-27 01:06:48,135] INFO: 🔍 Parsing file 177/7524: 11440_tales_of_three_hemispheres__by_lord_duns.txt
# [2025-07-27 01:06:48,135] INFO: 🔍 Parsing file 177/7524: 11440_tales_of_three_hemispheres__by_lord_duns.txt
# [2025-07-27 01:06:48,152] INFO: 🔍 Parsing file 178/7524: 11451_the_rome_express__by_arthur_griffiths.txt
# [2025-07-27 01:06:48,152] INFO: 🔍 Parsing file 178/7524: 11451_the_rome_express__by_arthur_griffiths.txt
# [2025-07-27 01:06:48,173] INFO: 🔍 Parsing file 179/7524: 11452_stories_by_american_authors__vol__6__by_.txt
# [2025-07-27 01:06:48,173] INFO: 🔍 Parsing file 179/7524: 11452_stories_by_american_authors__vol__6__by_.txt
# [2025-07-27 01:06:48,202] INFO: 🔍 Parsing file 180/7524: 11474_deep_waters__part_4__sam_s_ghost__by_w__.txt
# [2025-07-27 01:06:48,202] INFO: 🔍 Parsing file 180/7524: 11474_deep_waters__part_4__sam_s_ghost__by_w__.txt
# [2025-07-27 01:06:48,222] INFO: 🔍 Parsing file 181/7524: 11496_poetry__by_arthur_thomas_quiller_couch.txt
# [2025-07-27 01:06:48,222] INFO: 🔍 Parsing file 181/7524: 11496_poetry__by_arthur_thomas_quiller_couch.txt
# [2025-07-27 01:06:48,240] INFO: 🔍 Parsing file 182/7524: 11501_laughing_bill_hyde_and_other_stories__by.txt
# [2025-07-27 01:06:48,240] INFO: 🔍 Parsing file 182/7524: 11501_laughing_bill_hyde_and_other_stories__by.txt
# [2025-07-27 01:06:48,265] INFO: 🔍 Parsing file 183/7524: 11512_o__henry_memorial_award_prize_stories_of.txt
# [2025-07-27 01:06:48,265] INFO: 🔍 Parsing file 183/7524: 11512_o__henry_memorial_award_prize_stories_of.txt
# [2025-07-27 01:06:48,299] INFO: 🔍 Parsing file 184/7524: 11514_balcony_stories__by_grace_e__king.txt
# [2025-07-27 01:06:48,299] INFO: 🔍 Parsing file 184/7524: 11514_balcony_stories__by_grace_e__king.txt
# [2025-07-27 01:06:48,317] INFO: 🔍 Parsing file 185/7524: 11547_blackfoot_lodge_tales__by_george_bird_gr.txt
# [2025-07-27 01:06:48,317] INFO: 🔍 Parsing file 185/7524: 11547_blackfoot_lodge_tales__by_george_bird_gr.txt
# [2025-07-27 01:06:48,345] INFO: 🔍 Parsing file 186/7524: 11592_children_s_hour_with_red_riding_hood_and.txt
# [2025-07-27 01:06:48,345] INFO: 🔍 Parsing file 186/7524: 11592_children_s_hour_with_red_riding_hood_and.txt
# [2025-07-27 01:06:48,365] INFO: 🔍 Parsing file 187/7524: 11603_the_house_of_cobwebs_and_other_stories__.txt
# [2025-07-27 01:06:48,365] INFO: 🔍 Parsing file 187/7524: 11603_the_house_of_cobwebs_and_other_stories__.txt
# [2025-07-27 01:06:48,415] INFO: 🔍 Parsing file 188/7524: 11610_madam_crowl_s_ghost_and_the_dead_sexton_.txt
# [2025-07-27 01:06:48,415] INFO: 🔍 Parsing file 188/7524: 11610_madam_crowl_s_ghost_and_the_dead_sexton_.txt
# [2025-07-27 01:06:48,457] INFO: 🔍 Parsing file 189/7524: 11623_the_dramatic_works_of_john_dryden__vol__.txt
# [2025-07-27 01:06:48,457] INFO: 🔍 Parsing file 189/7524: 11623_the_dramatic_works_of_john_dryden__vol__.txt
# [2025-07-27 01:06:48,493] INFO: 🔍 Parsing file 190/7524: 11633_parsifal__a_drama_by_wagner_as_retold_by.txt
# [2025-07-27 01:06:48,493] INFO: 🔍 Parsing file 190/7524: 11633_parsifal__a_drama_by_wagner_as_retold_by.txt
# [2025-07-27 01:06:48,518] INFO: 🔍 Parsing file 191/7524: 11655_fate_knocks_at_the_door__by_will_levingt.txt
# [2025-07-27 01:06:48,518] INFO: 🔍 Parsing file 191/7524: 11655_fate_knocks_at_the_door__by_will_levingt.txt
# [2025-07-27 01:06:48,545] INFO: 🔍 Parsing file 192/7524: 11656_the_great_shadow_and_other_napoleonic_ta.txt
# [2025-07-27 01:06:48,545] INFO: 🔍 Parsing file 192/7524: 11656_the_great_shadow_and_other_napoleonic_ta.txt
# [2025-07-27 01:06:48,563] INFO: 🔍 Parsing file 193/7524: 11658_williams_anthology__compiled_by_edwin_pa.txt
# [2025-07-27 01:06:48,563] INFO: 🔍 Parsing file 193/7524: 11658_williams_anthology__compiled_by_edwin_pa.txt
# [2025-07-27 01:06:48,583] INFO: 🔍 Parsing file 194/7524: 11671_the_rudder_grangers_abroad_and_other_sto.txt
# [2025-07-27 01:06:48,583] INFO: 🔍 Parsing file 194/7524: 11671_the_rudder_grangers_abroad_and_other_sto.txt
# [2025-07-27 01:06:48,602] INFO: 🔍 Parsing file 195/7524: 11682_the_soul_of_the_war__by_philip_gibbs.txt
# [2025-07-27 01:06:48,602] INFO: 🔍 Parsing file 195/7524: 11682_the_soul_of_the_war__by_philip_gibbs.txt
# [2025-07-27 01:06:48,637] INFO: 🔍 Parsing file 196/7524: 11690_calvert_of_strathore__by_carter_goodloe.txt
# [2025-07-27 01:06:48,637] INFO: 🔍 Parsing file 196/7524: 11690_calvert_of_strathore__by_carter_goodloe.txt
# [2025-07-27 01:06:48,664] INFO: 🔍 Parsing file 197/7524: 11696_the_food_of_the_gods_and_how_it_came_to_.txt
# [2025-07-27 01:06:48,664] INFO: 🔍 Parsing file 197/7524: 11696_the_food_of_the_gods_and_how_it_came_to_.txt
# [2025-07-27 01:06:48,687] INFO: 🔍 Parsing file 198/7524: 11699_j__s__le_fanu_s_ghostly_tales__vol__1__b.txt
# [2025-07-27 01:06:48,687] INFO: 🔍 Parsing file 198/7524: 11699_j__s__le_fanu_s_ghostly_tales__vol__1__b.txt
# [2025-07-27 01:06:48,703] INFO: 🔍 Parsing file 199/7524: 11700_j__s__le_fanu_s_ghostly_tales__vol__2__b.txt
# [2025-07-27 01:06:48,703] INFO: 🔍 Parsing file 199/7524: 11700_j__s__le_fanu_s_ghostly_tales__vol__2__b.txt
# [2025-07-27 01:06:48,724] INFO: 🔍 Parsing file 200/7524: 11703_the_swiss_family_robinson__or_adventures.txt
# [2025-07-27 01:06:48,724] INFO: 🔍 Parsing file 200/7524: 11703_the_swiss_family_robinson__or_adventures.txt
# [2025-07-27 01:06:48,754] INFO: 🔍 Parsing file 201/7524: 11721_o__henry_memorial_award_prize_stories_of.txt
# [2025-07-27 01:06:48,754] INFO: 🔍 Parsing file 201/7524: 11721_o__henry_memorial_award_prize_stories_of.txt
# [2025-07-27 01:06:48,804] INFO: 🔍 Parsing file 202/7524: 11738_hindoo_tales__translated_by_p__w__jacob.txt
# [2025-07-27 01:06:48,804] INFO: 🔍 Parsing file 202/7524: 11738_hindoo_tales__translated_by_p__w__jacob.txt
# [2025-07-27 01:06:48,836] INFO: 🔍 Parsing file 203/7524: 11750_j__s__le_fanu_s_ghostly_tales__vol__3__b.txt
# [2025-07-27 01:06:48,836] INFO: 🔍 Parsing file 203/7524: 11750_j__s__le_fanu_s_ghostly_tales__vol__3__b.txt
# [2025-07-27 01:06:48,862] INFO: 🔍 Parsing file 204/7524: 11859_isaac_t__hopper__by_l__maria_child.txt
# [2025-07-27 01:06:48,862] INFO: 🔍 Parsing file 204/7524: 11859_isaac_t__hopper__by_l__maria_child.txt
# [2025-07-27 01:06:48,892] INFO: 🔍 Parsing file 205/7524: 11866_the_life_and_most_surprising_adventures_.txt
# [2025-07-27 01:06:48,892] INFO: 🔍 Parsing file 205/7524: 11866_the_life_and_most_surprising_adventures_.txt
# [2025-07-27 01:06:48,922] INFO: 🔍 Parsing file 206/7524: 11870_the_country_of_the_blind__and_other_stor.txt
# [2025-07-27 01:06:48,922] INFO: 🔍 Parsing file 206/7524: 11870_the_country_of_the_blind__and_other_stor.txt
# [2025-07-27 01:06:48,951] INFO: 🔍 Parsing file 207/7524: 11877_monkey_jack_and_other_stories__by_variou.txt
# [2025-07-27 01:06:48,951] INFO: 🔍 Parsing file 207/7524: 11877_monkey_jack_and_other_stories__by_variou.txt
# [2025-07-27 01:06:48,976] INFO: 🔍 Parsing file 208/7524: 11894_the_mahabharata_of_krishna_dwaipayana_vy.txt
# [2025-07-27 01:06:48,976] INFO: 🔍 Parsing file 208/7524: 11894_the_mahabharata_of_krishna_dwaipayana_vy.txt
# [2025-07-27 01:06:49,013] INFO: 🔍 Parsing file 209/7524: 11897_on_the_indian_sect_of_the_jainas__by_joh.txt
# [2025-07-27 01:06:49,013] INFO: 🔍 Parsing file 209/7524: 11897_on_the_indian_sect_of_the_jainas__by_joh.txt
# [2025-07-27 01:06:49,033] INFO: 🔍 Parsing file 210/7524: 11898_seeing_europe_with_famous_authors__vol__.txt
# [2025-07-27 01:06:49,033] INFO: 🔍 Parsing file 210/7524: 11898_seeing_europe_with_famous_authors__vol__.txt
# [2025-07-27 01:06:49,058] INFO: 🔍 Parsing file 211/7524: 11911_the_silent_isle__by_arthur_christopher_b.txt
# [2025-07-27 01:06:49,058] INFO: 🔍 Parsing file 211/7524: 11911_the_silent_isle__by_arthur_christopher_b.txt
# [2025-07-27 01:06:49,082] INFO: 🔍 Parsing file 212/7524: 11915_the_adventures_of_mr__mocker__by_thornto.txt
# [2025-07-27 01:06:49,082] INFO: 🔍 Parsing file 212/7524: 11915_the_adventures_of_mr__mocker__by_thornto.txt
# [2025-07-27 01:06:49,106] INFO: 🔍 Parsing file 213/7524: 11930_more_fables__by_george_ade.txt
# [2025-07-27 01:06:49,106] INFO: 🔍 Parsing file 213/7524: 11930_more_fables__by_george_ade.txt
# [2025-07-27 01:06:49,126] INFO: 🔍 Parsing file 214/7524: 11934_primitive_love_and_love_stories__by_henr.txt
# [2025-07-27 01:06:49,126] INFO: 🔍 Parsing file 214/7524: 11934_primitive_love_and_love_stories__by_henr.txt
# [2025-07-27 01:06:49,199] INFO: 🔍 Parsing file 215/7524: 11935_mysticism_in_english_literature__by_caro.txt
# [2025-07-27 01:06:49,199] INFO: 🔍 Parsing file 215/7524: 11935_mysticism_in_english_literature__by_caro.txt
# [2025-07-27 01:06:49,229] INFO: 🔍 Parsing file 216/7524: 11938_folklore_of_the_santal_parganas__by_ceci.txt
# [2025-07-27 01:06:49,229] INFO: 🔍 Parsing file 216/7524: 11938_folklore_of_the_santal_parganas__by_ceci.txt
# [2025-07-27 01:06:49,267] INFO: 🔍 Parsing file 217/7524: 11945_essays_of_schopenhauer__by_arthur_schope.txt
# [2025-07-27 01:06:49,267] INFO: 🔍 Parsing file 217/7524: 11945_essays_of_schopenhauer__by_arthur_schope.txt
# [2025-07-27 01:06:49,291] INFO: 🔍 Parsing file 218/7524: 11949_master_tales_of_mystery__volume_3__colle.txt
# [2025-07-27 01:06:49,291] INFO: 🔍 Parsing file 218/7524: 11949_master_tales_of_mystery__volume_3__colle.txt
# [2025-07-27 01:06:49,340] INFO: 🔍 Parsing file 219/7524: 11977_chronicles_of_canada__vol__13_of_32__the.txt
# [2025-07-27 01:06:49,340] INFO: 🔍 Parsing file 219/7524: 11977_chronicles_of_canada__vol__13_of_32__the.txt
# [2025-07-27 01:06:49,357] INFO: 🔍 Parsing file 220/7524: 11987_by_advice_of_counsel__by_arthur_train.txt
# [2025-07-27 01:06:49,357] INFO: 🔍 Parsing file 220/7524: 11987_by_advice_of_counsel__by_arthur_train.txt
# [2025-07-27 01:06:49,383] INFO: 🔍 Parsing file 221/7524: 11990_shakespeare_s_insomnia__and_the_causes_t.txt
# [2025-07-27 01:06:49,383] INFO: 🔍 Parsing file 221/7524: 11990_shakespeare_s_insomnia__and_the_causes_t.txt
# [2025-07-27 01:06:49,397] INFO: 🔍 Parsing file 222/7524: 12005_les_chants_de_maldoror__by_comte_de_laut.txt
# [2025-07-27 01:06:49,397] INFO: 🔍 Parsing file 222/7524: 12005_les_chants_de_maldoror__by_comte_de_laut.txt
# [2025-07-27 01:06:49,423] INFO: 🔍 Parsing file 223/7524: 12007_cousin_hatty_s_hymns_and_twilight_storie.txt
# [2025-07-27 01:06:49,423] INFO: 🔍 Parsing file 223/7524: 12007_cousin_hatty_s_hymns_and_twilight_storie.txt
# [2025-07-27 01:06:49,445] INFO: 🔍 Parsing file 224/7524: 12016_the_merchant_of_berlin__by_l_muhlbach.txt
# [2025-07-27 01:06:49,445] INFO: 🔍 Parsing file 224/7524: 12016_the_merchant_of_berlin__by_l_muhlbach.txt
# [2025-07-27 01:06:49,476] INFO: 🔍 Parsing file 225/7524: 12047_legends_of_the_madonna_as_represented_in.txt
# [2025-07-27 01:06:49,476] INFO: 🔍 Parsing file 225/7524: 12047_legends_of_the_madonna_as_represented_in.txt
# [2025-07-27 01:06:49,518] INFO: 🔍 Parsing file 226/7524: 12058_the_mahabharata_of_krishna_dwaipayana_vy.txt
# ...
# [2025-07-27 01:07:51,555] INFO: 🔍 Parsing file 2419/7524: 3086_original_short_stories__vol__10_of_13__b.txt
# [2025-07-27 01:07:51,555] INFO: 🔍 Parsing file 2419/7524: 3086_original_short_stories__vol__10_of_13__b.txt
# [2025-07-27 01:07:51,576] INFO: 🔍 Parsing file 2420/7524: 30871_legends___romances_of_brittany__by_lewis.txt
# [2025-07-27 01:07:51,576] INFO: 🔍 Parsing file 2420/7524: 30871_legends___romances_of_brittany__by_lewis.txt
# [2025-07-27 01:07:51,607] INFO: 🔍 Parsing file 2421/7524: 30876_eternal_life__by_henry_drummond.txt
# [2025-07-27 01:07:51,607] INFO: 🔍 Parsing file 2421/7524: 30876_eternal_life__by_henry_drummond.txt
# [2025-07-27 01:07:51,624] INFO: 🔍 Parsing file 2422/7524: 3087_original_short_stories__vol__11_of_13__b.txt
# [2025-07-27 01:07:51,624] INFO: 🔍 Parsing file 2422/7524: 3087_original_short_stories__vol__11_of_13__b.txt
# [2025-07-27 01:07:51,641] INFO: 🔍 Parsing file 2423/7524: 3088_original_short_stories__vol__12_of_13__b.txt
# [2025-07-27 01:07:51,641] INFO: 🔍 Parsing file 2423/7524: 3088_original_short_stories__vol__12_of_13__b.txt
# [2025-07-27 01:07:51,658] INFO: 🔍 Parsing file 2424/7524: 30896_when_ghost_meets_ghost__by_william_frend.txt
# [2025-07-27 01:07:51,658] INFO: 🔍 Parsing file 2424/7524: 30896_when_ghost_meets_ghost__by_william_frend.txt
# [2025-07-27 01:07:51,729] INFO: 🔍 Parsing file 2425/7524: 3089_original_short_stories__vol__13_of_13__b.txt
# [2025-07-27 01:07:51,729] INFO: 🔍 Parsing file 2425/7524: 3089_original_short_stories__vol__13_of_13__b.txt
# [2025-07-27 01:07:51,753] INFO: 🔍 Parsing file 2426/7524: 3090_original_short_stories__complete__by_guy.txt
# [2025-07-27 01:07:51,753] INFO: 🔍 Parsing file 2426/7524: 3090_original_short_stories__complete__by_guy.txt
# [2025-07-27 01:07:51,850] INFO: 🔍 Parsing file 2427/7524: 3092_the_conquest_of_new_france__a_chronicle_.txt
# [2025-07-27 01:07:51,850] INFO: 🔍 Parsing file 2427/7524: 3092_the_conquest_of_new_france__a_chronicle_.txt
# [2025-07-27 01:07:51,873] INFO: 🔍 Parsing file 2428/7524: 3093_the_eve_of_the_revolution__a_chronicle_o.txt
# [2025-07-27 01:07:51,873] INFO: 🔍 Parsing file 2428/7524: 3093_the_eve_of_the_revolution__a_chronicle_o.txt
# [2025-07-27 01:07:51,897] INFO: 🔍 Parsing file 2429/7524: 30953_the_boy_scout_and_other_stories_for_boys.txt
# [2025-07-27 01:07:51,897] INFO: 🔍 Parsing file 2429/7524: 30953_the_boy_scout_and_other_stories_for_boys.txt
# [2025-07-27 01:07:51,918] INFO: 🔍 Parsing file 2430/7524: 30969_the_big_five_motorcycle_boys_on_the_batt.txt
# [2025-07-27 01:07:51,918] INFO: 🔍 Parsing file 2430/7524: 30969_the_big_five_motorcycle_boys_on_the_batt.txt
# [2025-07-27 01:07:51,941] INFO: 🔍 Parsing file 2431/7524: 30970_miss_cayley_s_adventures__by_grant_allen.txt
# [2025-07-27 01:07:51,941] INFO: 🔍 Parsing file 2431/7524: 30970_miss_cayley_s_adventures__by_grant_allen.txt
# [2025-07-27 01:07:51,987] INFO: 🔍 Parsing file 2432/7524: 30982_an_introduction_to_shakespeare__by_n__ma.txt
# [2025-07-27 01:07:51,987] INFO: 🔍 Parsing file 2432/7524: 30982_an_introduction_to_shakespeare__by_n__ma.txt
# [2025-07-27 01:07:52,045] INFO: 🔍 Parsing file 2433/7524: 30987_porto_rico__by_arthur_d__hall.txt
# [2025-07-27 01:07:52,045] INFO: 🔍 Parsing file 2433/7524: 30987_porto_rico__by_arthur_d__hall.txt
# [2025-07-27 01:07:52,074] INFO: 🔍 Parsing file 2434/7524: 30989_mystery_ranch_by_arthur_chapman.txt
# [2025-07-27 01:07:52,074] INFO: 🔍 Parsing file 2434/7524: 30989_mystery_ranch_by_arthur_chapman.txt
# [2025-07-27 01:07:52,099] INFO: 🔍 Parsing file 2435/7524: 3098_the_paths_of_inland_commerce__a_chronicl.txt
# [2025-07-27 01:07:52,099] INFO: 🔍 Parsing file 2435/7524: 3098_the_paths_of_inland_commerce__a_chronicl.txt
# [2025-07-27 01:07:52,122] INFO: 🔍 Parsing file 2436/7524: 30995_indian_methodist_hymn_book__by_various.txt
# [2025-07-27 01:07:52,122] INFO: 🔍 Parsing file 2436/7524: 30995_indian_methodist_hymn_book__by_various.txt
# [2025-07-27 01:07:52,146] INFO: 🔍 Parsing file 2437/7524: 3099_the_old_merchant_marine__a_chronicle_of_.txt
# [2025-07-27 01:07:52,146] INFO: 🔍 Parsing file 2437/7524: 3099_the_old_merchant_marine__a_chronicle_of_.txt
# [2025-07-27 01:07:52,165] INFO: 🔍 Parsing file 2438/7524: 31006_the_author_s_printing_and_publishing_ass.txt
# [2025-07-27 01:07:52,165] INFO: 🔍 Parsing file 2438/7524: 31006_the_author_s_printing_and_publishing_ass.txt
# [2025-07-27 01:07:52,183] INFO: 🔍 Parsing file 2439/7524: 31019_four_ghost_stories__by_mrs__molesworth.txt
# [2025-07-27 01:07:52,183] INFO: 🔍 Parsing file 2439/7524: 31019_four_ghost_stories__by_mrs__molesworth.txt
# [2025-07-27 01:07:52,204] INFO: 🔍 Parsing file 2440/7524: 31053_the_history_of_the_devil__by_daniel_defo.txt
# [2025-07-27 01:07:52,204] INFO: 🔍 Parsing file 2440/7524: 31053_the_history_of_the_devil__by_daniel_defo.txt
# [2025-07-27 01:07:52,240] INFO: 🔍 Parsing file 2441/7524: 31064_stories_by_american_authors__volume_2__b.txt
# [2025-07-27 01:07:52,240] INFO: 🔍 Parsing file 2441/7524: 31064_stories_by_american_authors__volume_2__b.txt
# [2025-07-27 01:07:52,260] INFO: 🔍 Parsing file 2442/7524: 31082_the_mermaid_of_druid_lake_and_other_stor.txt
# [2025-07-27 01:07:52,260] INFO: 🔍 Parsing file 2442/7524: 31082_the_mermaid_of_druid_lake_and_other_stor.txt
# [2025-07-27 01:07:52,277] INFO: 🔍 Parsing file 2443/7524: 31092_hero_stories_from_american_history_.txt
# [2025-07-27 01:07:52,277] INFO: 🔍 Parsing file 2443/7524: 31092_hero_stories_from_american_history_.txt
# [2025-07-27 01:07:52,302] INFO: 🔍 Parsing file 2444/7524: 31095_stories_by_american_authors__volume_3__b.txt
# [2025-07-27 01:07:52,302] INFO: 🔍 Parsing file 2444/7524: 31095_stories_by_american_authors__volume_3__b.txt
# [2025-07-27 01:07:52,323] INFO: 🔍 Parsing file 2445/7524: 31103_a_christmas_greeting__by_hans_christian_.txt
# [2025-07-27 01:07:52,323] INFO: 🔍 Parsing file 2445/7524: 31103_a_christmas_greeting__by_hans_christian_.txt
# [2025-07-27 01:07:52,340] INFO: 🔍 Parsing file 2446/7524: 31117_le_chanteur_parisien__by_louis_ange_pito.txt
# [2025-07-27 01:07:52,340] INFO: 🔍 Parsing file 2446/7524: 31117_le_chanteur_parisien__by_louis_ange_pito.txt
# [2025-07-27 01:07:52,357] INFO: 🔍 Parsing file 2447/7524: 31120_hoe_men_schilder_wordt__by_hendrik_consc.txt
# [2025-07-27 01:07:52,357] INFO: 🔍 Parsing file 2447/7524: 31120_hoe_men_schilder_wordt__by_hendrik_consc.txt
# [2025-07-27 01:07:52,379] INFO: 🔍 Parsing file 2448/7524: 31122_the_mystery_of_witch_face_mountain_and_o.txt
# [2025-07-27 01:07:52,379] INFO: 🔍 Parsing file 2448/7524: 31122_the_mystery_of_witch_face_mountain_and_o.txt
# [2025-07-27 01:07:52,412] INFO: 🔍 Parsing file 2449/7524: 31126_een_midzomernachtdroom__by_william_shake.txt
# [2025-07-27 01:07:52,412] INFO: 🔍 Parsing file 2449/7524: 31126_een_midzomernachtdroom__by_william_shake.txt
# [2025-07-27 01:07:52,437] INFO: 🔍 Parsing file 2450/7524: 31131_boys__book_of_indian_warriors__by_edwin_.txt
# [2025-07-27 01:07:52,437] INFO: 🔍 Parsing file 2450/7524: 31131_boys__book_of_indian_warriors__by_edwin_.txt
# [2025-07-27 01:07:52,470] INFO: 🔍 Parsing file 2451/7524: 31133_home_life_of_great_authors__by_hattie_ty.txt
# [2025-07-27 01:07:52,470] INFO: 🔍 Parsing file 2451/7524: 31133_home_life_of_great_authors__by_hattie_ty.txt
# [2025-07-27 01:07:52,501] INFO: 🔍 Parsing file 2452/7524: 31134_stories_by_american_authors__volume_7__b.txt
# [2025-07-27 01:07:52,501] INFO: 🔍 Parsing file 2452/7524: 31134_stories_by_american_authors__volume_7__b.txt
# [2025-07-27 01:07:52,523] INFO: 🔍 Parsing file 2453/7524: 31135_the_adventures_of_the_eleven_cuff_button.txt
# [2025-07-27 01:07:52,523] INFO: 🔍 Parsing file 2453/7524: 31135_the_adventures_of_the_eleven_cuff_button.txt
# [2025-07-27 01:07:52,543] INFO: 🔍 Parsing file 2454/7524: 31146_stories_by_american_authors__volume_8__b.txt
# [2025-07-27 01:07:52,543] INFO: 🔍 Parsing file 2454/7524: 31146_stories_by_american_authors__volume_8__b.txt
# [2025-07-27 01:07:52,562] INFO: 🔍 Parsing file 2455/7524: 31151_the_english_novel_in_the_time_of_shakesp.txt
# [2025-07-27 01:07:52,562] INFO: 🔍 Parsing file 2455/7524: 31151_the_english_novel_in_the_time_of_shakesp.txt
# [2025-07-27 01:07:52,601] INFO: 🔍 Parsing file 2456/7524: 31167_the_old_willow_tree_and_other_stories__b.txt
# [2025-07-27 01:07:52,601] INFO: 🔍 Parsing file 2456/7524: 31167_the_old_willow_tree_and_other_stories__b.txt
# [2025-07-27 01:07:52,631] INFO: 🔍 Parsing file 2457/7524: 31168_astounding_stories__july__1931__by_vario.txt
# [2025-07-27 01:07:52,631] INFO: 🔍 Parsing file 2457/7524: 31168_astounding_stories__july__1931__by_vario.txt
# [2025-07-27 01:07:52,670] INFO: 🔍 Parsing file 2458/7524: 31177_ritual_conformity__by_unknown.txt
# [2025-07-27 01:07:52,670] INFO: 🔍 Parsing file 2458/7524: 31177_ritual_conformity__by_unknown.txt
# [2025-07-27 01:07:52,687] INFO: 🔍 Parsing file 2459/7524: 31178_thoughts_on_african_colonization__by_wil.txt
# [2025-07-27 01:07:52,687] INFO: 🔍 Parsing file 2459/7524: 31178_thoughts_on_african_colonization__by_wil.txt
# [2025-07-27 01:07:52,719] INFO: 🔍 Parsing file 2460/7524: 31180_ellen_middleton__a_tale__by_georgiana_fu.txt
# [2025-07-27 01:07:52,719] INFO: 🔍 Parsing file 2460/7524: 31180_ellen_middleton__a_tale__by_georgiana_fu.txt
# [2025-07-27 01:07:52,758] INFO: 🔍 Parsing file 2461/7524: 31183_rembrandt__with_a_complete_list_of_his_e.txt
# [2025-07-27 01:07:52,758] INFO: 🔍 Parsing file 2461/7524: 31183_rembrandt__with_a_complete_list_of_his_e.txt
# [2025-07-27 01:07:52,773] INFO: 🔍 Parsing file 2462/7524: 31189_the_monster_and_other_stories__by_stephe.txt
# [2025-07-27 01:07:52,773] INFO: 🔍 Parsing file 2462/7524: 31189_the_monster_and_other_stories__by_stephe.txt
# [2025-07-27 01:07:52,794] INFO: 🔍 Parsing file 2463/7524: 31194_stories_by_american_authors__volume_9__b.txt
# [2025-07-27 01:07:52,794] INFO: 🔍 Parsing file 2463/7524: 31194_stories_by_american_authors__volume_9__b.txt
# [2025-07-27 01:07:52,823] INFO: 🔍 Parsing file 2464/7524: 31198_legenden_en_romances_van_spanje__by_lewi.txt
# [2025-07-27 01:07:52,823] INFO: 🔍 Parsing file 2464/7524: 31198_legenden_en_romances_van_spanje__by_lewi.txt
# [2025-07-27 01:07:52,867] INFO: 🔍 Parsing file 2465/7524: 31201_the_brown_fairy_book__by_andrew_lang.txt
# [2025-07-27 01:07:52,867] INFO: 🔍 Parsing file 2465/7524: 31201_the_brown_fairy_book__by_andrew_lang.txt
# [2025-07-27 01:07:52,901] INFO: 🔍 Parsing file 2466/7524: 31209_indian_fairy_tales__by_anonymous.txt
# [2025-07-27 01:07:52,901] INFO: 🔍 Parsing file 2466/7524: 31209_indian_fairy_tales__by_anonymous.txt
# [2025-07-27 01:07:52,935] INFO: 🔍 Parsing file 2467/7524: 31217_household_papers_and_stories__by_harriet.txt
# [2025-07-27 01:07:52,935] INFO: 🔍 Parsing file 2467/7524: 31217_household_papers_and_stories__by_harriet.txt
# [2025-07-27 01:07:52,975] INFO: 🔍 Parsing file 2468/7524: 31227_stories_by_american_authors__volume_10__.txt
# [2025-07-27 01:07:52,975] INFO: 🔍 Parsing file 2468/7524: 31227_stories_by_american_authors__volume_10__.txt
# [2025-07-27 01:07:52,998] INFO: 🔍 Parsing file 2469/7524: 31247_camilla__a_tale_of_a_violin__by_charles_.txt
# [2025-07-27 01:07:52,998] INFO: 🔍 Parsing file 2469/7524: 31247_camilla__a_tale_of_a_violin__by_charles_.txt
# [2025-07-27 01:07:53,019] INFO: 🔍 Parsing file 2470/7524: 3124_the_people_for_whom_shakespeare_wrote__b.txt
# [2025-07-27 01:07:53,019] INFO: 🔍 Parsing file 2470/7524: 3124_the_people_for_whom_shakespeare_wrote__b.txt
# [2025-07-27 01:07:53,040] INFO: 🔍 Parsing file 2471/7524: 31269_upon_the_tree_tops__by_olive_thorne_mill.txt
# [2025-07-27 01:07:53,040] INFO: 🔍 Parsing file 2471/7524: 31269_upon_the_tree_tops__by_olive_thorne_mill.txt
# [2025-07-27 01:07:53,059] INFO: 🔍 Parsing file 2472/7524: 31326_the_wealth_of_echindul__by_noel_miller_l.txt
# [2025-07-27 01:07:53,059] INFO: 🔍 Parsing file 2472/7524: 31326_the_wealth_of_echindul__by_noel_miller_l.txt
# [2025-07-27 01:07:53,076] INFO: 🔍 Parsing file 2473/7524: 31341_apparitions__or__the_mystery_of_ghosts__.txt
# [2025-07-27 01:07:53,076] INFO: 🔍 Parsing file 2473/7524: 31341_apparitions__or__the_mystery_of_ghosts__.txt
# [2025-07-27 01:07:53,098] INFO: 🔍 Parsing file 2474/7524: 31351_record_of_study_in_aboriginal_american_l.txt
# [2025-07-27 01:07:53,098] INFO: 🔍 Parsing file 2474/7524: 31351_record_of_study_in_aboriginal_american_l.txt
# [2025-07-27 01:07:53,114] INFO: 🔍 Parsing file 2475/7524: 31366_a_little_dusky_hero__by_harriot_t__comst.txt
# [2025-07-27 01:07:53,114] INFO: 🔍 Parsing file 2475/7524: 31366_a_little_dusky_hero__by_harriot_t__comst.txt
# [2025-07-27 01:07:53,138] INFO: 🔍 Parsing file 2476/7524: 31374_the_dramatist__or_stop_him_who_can___by_.txt
# [2025-07-27 01:07:53,138] INFO: 🔍 Parsing file 2476/7524: 31374_the_dramatist__or_stop_him_who_can___by_.txt
# [2025-07-27 01:07:53,157] INFO: 🔍 Parsing file 2477/7524: 31377_weird_tales__vol__1__by_e__t__a__hoffman.txt
# [2025-07-27 01:07:53,157] INFO: 🔍 Parsing file 2477/7524: 31377_weird_tales__vol__1__by_e__t__a__hoffman.txt
# [2025-07-27 01:07:53,189] INFO: 🔍 Parsing file 2478/7524: 31395_railway_adventures_and_anecdotes.txt
# [2025-07-27 01:07:53,189] INFO: 🔍 Parsing file 2478/7524: 31395_railway_adventures_and_anecdotes.txt
# [2025-07-27 01:07:53,224] INFO: 🔍 Parsing file 2479/7524: 31400_critias__hipparchus__the_rival_lovers__b.txt
# [2025-07-27 01:07:53,224] INFO: 🔍 Parsing file 2479/7524: 31400_critias__hipparchus__the_rival_lovers__b.txt
# [2025-07-27 01:07:53,240] INFO: 🔍 Parsing file 2480/7524: 31401_saint_dimitrios__by_platon_rodokanakis.txt
# [2025-07-27 01:07:53,240] INFO: 🔍 Parsing file 2480/7524: 31401_saint_dimitrios__by_platon_rodokanakis.txt
# [2025-07-27 01:07:53,255] INFO: 🔍 Parsing file 2481/7524: 31402_euthydemus__by_plato.txt
# [2025-07-27 01:07:53,255] INFO: 🔍 Parsing file 2481/7524: 31402_euthydemus__by_plato.txt
# [2025-07-27 01:07:53,272] INFO: 🔍 Parsing file 2482/7524: 31404_myths__by_ioannis_vilaras.txt
# [2025-07-27 01:07:53,272] INFO: 🔍 Parsing file 2482/7524: 31404_myths__by_ioannis_vilaras.txt
# [2025-07-27 01:07:53,290] INFO: 🔍 Parsing file 2483/7524: 31405_the_tempest__by_william_shakespeare.txt
# [2025-07-27 01:07:53,290] INFO: 🔍 Parsing file 2483/7524: 31405_the_tempest__by_william_shakespeare.txt
# [2025-07-27 01:07:53,314] INFO: 🔍 Parsing file 2484/7524: 31411_stories_pictures_tell__by_flora_l__carpe.txt
# [2025-07-27 01:07:53,314] INFO: 🔍 Parsing file 2484/7524: 31411_stories_pictures_tell__by_flora_l__carpe.txt
# [2025-07-27 01:07:53,333] INFO: 🔍 Parsing file 2485/7524: 31412_old_and_new_london__by_walter_thornbury.txt
# [2025-07-27 01:07:53,333] INFO: 🔍 Parsing file 2485/7524: 31412_old_and_new_london__by_walter_thornbury.txt
# [2025-07-27 01:07:53,412] INFO: 🔍 Parsing file 2486/7524: 31416_the_immortal_moment__by_may_sinclair.txt
# [2025-07-27 01:07:53,412] INFO: 🔍 Parsing file 2486/7524: 31416_the_immortal_moment__by_may_sinclair.txt
# [2025-07-27 01:14:49,791] INFO:
# 🎯 PHASE 3 SEMANTIC SPLIT COMPLETE
# [2025-07-27 01:14:49,791] INFO:
# 🎯 PHASE 3 SEMANTIC SPLIT COMPLETE
# [2025-07-27 01:14:49,795] INFO: 📂 Train set saved: C:\Users\ayush\OneDrive\Desktop\Stories\split_phase3\train.txt
# [2025-07-27 01:14:49,795] INFO: 📂 Train set saved: C:\Users\ayush\OneDrive\Desktop\Stories\split_phase3\train.txt
# [2025-07-27 01:14:49,802] INFO: 📂 Val set saved: C:\Users\ayush\OneDrive\Desktop\Stories\split_phase3\val.txt
# [2025-07-27 01:14:49,802] INFO: 📂 Val set saved: C:\Users\ayush\OneDrive\Desktop\Stories\split_phase3\val.txt
# [2025-07-27 01:14:49,807] INFO: 📊 Metadata: C:\Users\ayush\OneDrive\Desktop\Stories\split_phase3\split_metadata.csv
# [2025-07-27 01:14:49,807] INFO: 📊 Metadata: C:\Users\ayush\OneDrive\Desktop\Stories\split_phase3\split_metadata.csv
# [2025-07-27 01:14:49,811] INFO: 🧠 Balance report: C:\Users\ayush\OneDrive\Desktop\Stories\split_phase3\split_balance_report.txt
# [2025-07-27 01:14:49,811] INFO: 🧠 Balance report: C:\Users\ayush\OneDrive\Desktop\Stories\split_phase3\split_balance_report.txt
# [2025-07-27 01:14:49,819] INFO: 🖼️ Tag Plot: C:\Users\ayush\OneDrive\Desktop\Stories\split_phase3\tag_balance_val_vs_train.png
# [2025-07-27 01:14:49,819] INFO: 🖼️ Tag Plot: C:\Users\ayush\OneDrive\Desktop\Stories\split_phase3\tag_balance_val_vs_train.png
